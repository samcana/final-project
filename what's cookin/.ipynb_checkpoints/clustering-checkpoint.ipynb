# %%
import pandas as pd
import numpy as np
import json
import re
from nltk.tokenize import RegexpTokenizer, word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dataML = pd.read_pickle(r'bareMLdata.pkl')

# %%
dataML
# Out:
#                    cuisine                                   ingredients_list  \
# 0                  Mexican  [tortillas, extra virgin olive oil, garlic, mo...
# 1     South Indian Recipes  [sesame (gingelly) oil, mustard seeds, curry l...
# 2                  Mexican  [extra virgin olive oil, pineapple, white onio...
# 3                Karnataka  [arhar dal (split toor dal), turmeric powder (...
# 4     North Indian Recipes  [rajma (large kidney beans), cashew nuts, sult...
# ...                    ...                                                ...
# 7967       Italian Recipes  [spirali pasta, onions, tomato, green zucchini...
# 7968            Hyderabadi  [arhar dal (split toor dal), tomato, turmeric ...
# 7969             Karnataka  [turmeric powder (haldi), sugar, salt, fresh c...
# 7970                Indian  [beetroot, amla (nellikai/ gooseberry), mint l...
# 7971            Tamil Nadu  [cauliflower (gobi), pearl onions (sambar onio...
#
#                                   seperated_ingredients  \
# 0     tortillas,extra virgin olive oil,garlic,mozzar...
# 1     sesame gingelly oil,mustard seeds,curry leaves...
# 2     extra virgin olive oil,pineapple,white onion,r...
# 3     arhar dal split toor dal,turmeric powder haldi...
# 4     rajma large kidney beans,cashew nuts,sultana r...
# ...                                                 ...
# 7967  spirali pasta,onions,tomato,green zucchini,car...
# 7968  arhar dal split toor dal,tomato,turmeric powde...
# 7969  turmeric powder haldi,sugar,salt,fresh coconut...
# 7970  beetroot,amla nellikai/ gooseberry,mint leaves...
# 7971  cauliflower gobi,pearl onions sambar onions,ga...
#
#                                             ingredients
# 0     tortillas extra virgin olive oil garlic mozzar...
# 1     sesame gingelly oil mustard seeds curry leaves...
# 2     extra virgin olive oil pineapple white onion r...
# 3     arhar dal split toor dal turmeric powder haldi...
# 4     rajma large kidney beans cashew nuts sultana r...
# ...                                                 ...
# 7967  spirali pasta onions tomato green zucchini car...
# 7968  arhar dal split toor dal tomato turmeric powde...
# 7969  turmeric powder haldi sugar salt fresh coconut...
# 7970  beetroot amla nellikai/ gooseberry mint leaves...
# 7971  cauliflower gobi pearl onions sambar onions ga...
#
# [7922 rows x 4 columns]

# %%
dataML.isna().sum()
# Out:
# cuisine                  0
# ingredients_list         0
# seperated_ingredients    0
# dtype: int64

# %%
dataML = dataML.dropna()

# %%
dataML.shape
# Out:
# (7922, 3)

# %%
dataML['ingredients'] = dataML['ingredients_list'].apply(lambda x: ' '.join(x))
# Out:
# <ipython-input-78-9f9618371ba2>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Define a function to perform both stemming and tokenization
def tokenizer(text):
    
    # Tokenize by sentence, then by word
    tokens = [word for text in sent_tokenize(text) for word in word_tokenize(text)]
    
       
    # Filter out raw tokens to remove noise
    filtered_tokens = [token for token in tokens if re.match(r'[A-ZÄÖÜ][a-zäöüß]+', token)]
    
    return filtered_tokens

# %%
tfidf_vectorizer = TfidfVectorizer(tokenizer=tokenizer,lowercase=False)

# %%
tfidf_vectorizer
# Out:
# TfidfVectorizer(lowercase=False,
#                 tokenizer=<function tokenizer at 0x7fb0e917b8b0>)

# %%
[x for x in dataML['ingredients']]
# Out:
# ['tortillas extra virgin olive oil garlic mozzarella cheese red yellow or green bell pepper (capsicum) onions kalmatta olives button mushrooms',
#  'sesame (gingelly) oil mustard seeds curry leaves garlic pearl onions (sambar onions) tomato tamarind turmeric powder (haldi) salt jaggery',
#  'extra virgin olive oil pineapple white onion red yellow and green bell peppers (capsicum) pickled jalapenos coriander (dhania) leaves mint leaves (pudina) salt lemon juice paprika powder',
#  'arhar dal (split toor dal) turmeric powder (haldi) salt dry red chilli mustard seeds asafoetida (hing) curry leaves coriander (dhania) leaves',
#  'rajma (large kidney beans) cashew nuts sultana raisins asafoetida (hing) cumin seeds (jeera) gram flour (besan) red chilli powder coriander (dhania) leaves poppy seeds fresh cream milk water salt saffron strands',
#  'barnyard millet oil bay leaf (tej patta) cardamom (elaichi) pods/seeds cloves (laung) cinnamon stick (dalchini) star anise curry leaves green chilli garlic ginger onions button mushrooms salt coriander (dhania) powder black pepper powder coriander (dhania) leaves mint leaves (pudina)',
#  'coriander (dhania) leaves tahini lemon juice extra virgin olive oil honey ginger salt',
#  'avarekalu / lilva beans rice turmeric powder (haldi) asafoetida (hing) green chilli curry leaves mustard seeds white urad dal (split) lemon juice coriander (dhania) leaves onion salt',
#  'whole wheat flour sooji (semolina/ rava) ajwain (carom seeds) salt extra virgin olive oil carrot (gajjar) green bell pepper (capsicum) cabbage (patta gobi/ muttaikose) ginger garlic green chilli spring onion greens salt black pepper powder',
#  'butter (unsalted) caster sugar whole eggs all purpose flour (maida) salt baking powder canned pineapple (preserved & tinned) canned cherries',
#  'cashew nuts onions ginger garlic green chilli green peas (matar) butter (salted) bay leaf (tej patta) turmeric powder (haldi) kashmiri red chilli powder coriander powder (dhania) salt tomato sugar fresh cream kasuri methi (dried fenugreek leaves) coriander (dhania) leaves',
#  'butter (salted) garlic green chilli onion green capsicum cooked rice sweet corn all purpose flour (maida) mint leaves (pudina) mozzarella cheese black pepper powder oil salt all purpose flour (maida) water whole wheat bread crumbs mixed herbs (dried) red chilli flakes',
#  'shrimps butter (salted) orange color lemon juice honey black pepper powder garlic ginger fresh thyme leaves',
#  'oil kokum (malabar tamarind) green chilli jaggery salt coriander (dhania) leaves fresh coconut onion garlic cumin seeds (jeera) coriander (dhania) seeds dry red chilli turmeric powder (haldi)',
#  'ripe bananas sesame seeds (til seeds) sesame seeds (til seeds) oil chilled water all purpose flour (maida) corn flour oil baking powder sugar water',
#  'mango (ripe) tomato onion rajma (large kidney beans) pickled jalapenos mint leaves (pudina) lemon juice coriander (dhania) leaves salt cumin powder (jeera) red chilli powder',
#  'kaddu (parangikai/ pumpkin) turmeric powder (haldi) salt fresh coconut cumin seeds (jeera) green chilli oil mustard seeds curry leaves dry red chilli dry red chilli',
#  'bhindi (lady finger/okra) gram flour (besan) red chilli powder turmeric powder (haldi) coriander powder (dhania) amchur (dry mango powder) salt water oil cumin seeds (jeera) mustard seeds asafoetida (hing) green chilli onions coriander (dhania) leaves',
#  'green moong dal (whole) yellow moong dal (split) pearl onions (sambar onions) mustard seeds curry leaves dry red chilli turmeric powder (haldi) salt coconut oil fresh coconut green chilli cumin seeds (jeera)',
#  'raw banana green peas (matar) cumin seeds (jeera) green chilli turmeric powder (haldi) coriander powder (dhania) cumin powder (jeera) amchur (dry mango powder) lemon oil coriander (dhania) leaves salt',
#  'extra virgin olive oil chicken breasts spaghetti pasta basil leaves walnuts parmesan cheese garlic extra virgin olive oil salt whole black pepper corns lemon juice',
#  'tomato onions khoya (mawa) sesame seeds (til seeds) raw peanuts (moongphali) red chilli powder kashmiri red chilli powder turmeric powder (haldi) coriander powder (dhania) cumin powder (jeera) cloves (laung) cinnamon stick (dalchini) garlic oil salt whole eggs',
#  'brinjal (baingan / eggplant) green bell pepper (capsicum) carrot (gajjar) onion green chilli garlic basil leaves parsley leaves extra virgin olive oil black pepper powder salt dried oregano mozzarella cheese',
#  'black eyed beans (lobia) rice carrots (gajjar) green beans (french beans) turmeric powder (haldi) tomato bay leaves (tej patta) cinnamon stick (dalchini) cardamom (elaichi) pods/seeds cumin seeds (jeera) green chilli mint leaves (pudina) salt',
#  'small brinjal (baingan / eggplant) turmeric powder (haldi) red chilli powder jaggery tomato salt black sesame seeds raw peanuts (moongphali) cumin seeds (jeera) ginger garlic onions green chilli gingelly oil mustard seeds asafoetida (hing) curry leaves',
#  'raw banana coconut oil salt garlic ginger green chilli curry leaves black pepper corns tamarind',
#  'kabuli chana (white chickpeas) gram flour (besan) garlic onion cumin powder (jeera) coriander (dhania) powder black pepper powder red chilli powder salt parsley leaves oil',
#  'ragi flour (finger millet/ nagli) whole wheat flour green chilli ginger drumstick leaves (moringa/murungai keerai) black pepper powder salt',
#  'chana dal (bengal gram dal) dry red chilli fennel seeds (saunf) salt oil onion tomato green chilli garlic coriander powder (dhania) red chilli powder cinnamon stick (dalchini) bay leaf (tej patta) cardamom (elaichi) pods/seeds fennel seeds (saunf) curry leaves coriander (dhania) leaves oil salt fresh coconut poppy seeds fennel seeds (saunf) cashew nuts roasted gram dal (pottukadalai)',
#  'onions tomato green chilli mustard seeds cumin seeds (jeera) curry leaves dry red chilli asafoetida (hing) salt oil mint leaves (pudina)',
#  'brinjal (baingan / eggplant) potato onion fresh coconut turmeric powder (haldi) tamarind garlic ginger jaggery gram flour (besan) coriander (dhania) leaves salt cloves (laung) cinnamon stick (dalchini) cardamom (elaichi) pods/seeds whole black peppercorns byadagi dried chilli oil onion fresh coconut oil mustard seeds asafoetida (hing) curry leaves',
#  'all purpose flour (maida) caster sugar cinnamon powder (dalchini) baking powder butter (unsalted) sultana raisins whole egg',
#  'makki ka atta (yellow corn meal flour) milk water whole black peppercorns extra virgin olive oil salt red yellow and green bell peppers (capsicum) button mushrooms mixed herbs (dried) onions cheese',
#  'all purpose flour (maida) buttermilk salt butter (unsalted) lukewarm water caster sugar butter (unsalted) cinnamon powder (dalchini) caster sugar milk icing sugar vanilla extract',
#  'sabudana (tapioca pearls) shallots mixed vegetables coriander (dhania) leaves coriander (dhania) leaves black pepper powder garlic oil water garlic oil',
#  'fresh coconut whole black peppercorns dry red chilli coriander (dhania) seeds turmeric powder (haldi) tamarind mustard seeds curry leaves asafoetida (hing) jaggery oil',
#  'chipotle peppers onion garlic tomato raw peanuts (moongphali) star anise cinnamon stick (dalchini) cloves (laung) dark chocolate dried oregano black pepper powder sultana raisins makki ka atta (yellow corn meal flour) butter (salted) chicken stock salt',
#  'whole eggs green capsicum onion britannia cheese block whole eggs salt black pepper powder milk avocado onion tomato green chilli salt coriander (dhania) leaves lemon juice sugar',
#  'tofu sesame (gingelly) oil brown sugar (demerara sugar) dried basil leaves garlic powder cayenne pepper coconut milk ginger garlic peanut butter turmeric powder (haldi) lemon juice brown sugar (demerara sugar) iceberg lettuce roasted peanuts (moongphali)',
#  'mutton salt lemon juice turmeric powder (haldi) onions garlic ginger cloves (laung) bay leaf (tej patta) cardamom (elaichi) pods/seeds cinnamon stick (dalchini) fennel seeds (saunf) green chilli salt tomato red chilli powder cumin powder (jeera) coriander (dhania) powder meat masala kasuri methi (dried fenugreek leaves) coriander (dhania) leaves',
#  'avarekalu / lilva beans tomato fresh coconut jaggery turmeric powder (haldi) salt coriander (dhania) seeds dry red chilli byadagi dried chilli cumin seeds (jeera) whole black peppercorns mustard seeds methi seeds (fenugreek seeds) mustard seeds curry leaves',
#  'french loaf butter (salted) extra virgin olive oil red yellow and green bell peppers (capsicum) sweet corn pickled jalapenos basil leaves salt mozzarella cheese mixed herbs (dried) red chilli flakes garlic bread spice mix',
#  'cashew nuts tomato green bell pepper (capsicum) turmeric powder (haldi) oil coriander (dhania) leaves salt fresh coconut onion garlic coriander (dhania) seeds byadagi dried chilli whole black peppercorns cumin seeds (jeera) cloves (laung) tamarind',
#  'methi seeds (fenugreek seeds) coriander (dhania) seeds fennel seeds (saunf) dry red chilli fresh coconut pearl onions (sambar onions) garlic tomato potato brinjal (baingan / eggplant) jaggery gingelly oil mustard seeds curry leaves',
#  'rice yellow moong dal (split) turmeric powder (haldi) cardamom (elaichi) pods/seeds cinnamon stick (dalchini) cardamom (elaichi) pods/seeds cinnamon stick (dalchini)',
#  'vellai poosanikai (ash gourd/white pumpkin) turmeric powder (haldi) salt oil dry red chilli fresh coconut methi seeds (fenugreek seeds) cumin seeds (jeera) coriander (dhania) seeds sesame seeds (til seeds) jaggery oil mustard seeds curry leaves dry red chilli',
#  'bajra flour ( pearl millet) whole wheat flour methi leaves (fenugreek leaves) garlic red chilli powder sesame seeds (til seeds) fennel seeds (saunf) coriander powder (dhania) cumin powder (jeera) amchur (dry mango powder) oil turmeric powder (haldi) salt oil',
#  'bhindi (lady finger/okra) oil ajwain (carom seeds) curry leaves roasted peanuts (moongphali) coriander powder (dhania) turmeric powder (haldi) red chilli powder amchur (dry mango powder) salt',
#  'whole egg mutton ginger garlic coriander powder (dhania) turmeric powder (haldi) kashmiri red chilli powder corn flour mustard oil salt onion turmeric powder (haldi) green chilli paste red chilli powder garlic ginger coriander powder (dhania) cumin powder (jeera) kasuri methi (dried fenugreek leaves) bay leaf (tej patta) dry red chilli salt oil',
#  'tofu orange zest (rind) corn flour whole black peppercorns rice vinegar brown sugar (demerara sugar) fresh orange juice ginger sesame (gingelly) oil sesame seeds (til seeds) salt',
#  'cumin seeds (jeera) cardamom (elaichi) pods/seeds cloves (laung) cinnamon stick (dalchini) coriander (dhania) seeds whole black peppercorns fennel seeds (saunf) bay leaves (tej patta) mace (javitri) nutmeg powder',
#  'green moong dal (whole) carrot (gajjar) fresh coconut cucumber tomato green chilli lemon coriander (dhania) leaves salt mustard seeds white urad dal (split) curry leaves coconut oil',
#  'bhindi (lady finger/okra) pearl onions (sambar onions) tomato tamarind curry leaves mustard seeds cumin seeds (jeera) methi seeds (fenugreek seeds) turmeric powder (haldi) red chilli powder jaggery gingelly oil salt',
#  'ridge gourd skin (turai/ peerkangai) white urad dal (split) methi seeds (fenugreek seeds) dry red chilli curry leaves tamarind salt gingelly oil mustard seeds white urad dal (split) dry red chilli curry leaves',
#  'button mushrooms onion garlic ginger turmeric powder (haldi) oil salt dry red chilli coriander (dhania) seeds cumin seeds (jeera) whole black peppercorns cardamom (elaichi) pods/seeds cloves (laung)',
#  'arhar dal (split toor dal) chana dal (bengal gram dal) masoor dal (whole) white urad dal (split) kashmiri rajma kala chana (brown chickpeas) cumin (jeera) seeds onion ginger green chilli cinnamon stick cardamom (elaichi) pods/seeds bay leaves (tej patta) tomato turmeric powder (haldi) red chilli powder salt lemon coriander (dhania) leaves',
#  'oil button mushrooms turmeric powder (haldi) salt onions ginger garlic coriander (dhania) leaves dry red chilli poppy seeds cloves (laung) cinnamon stick (dalchini) whole black pepper corns cumin seeds (jeera) coriander (dhania) seeds methi seeds (fenugreek seeds) tamarind',
#  'black raisins prunes apricots dates dried figs cranberries rum fresh orange juice fresh orange juice whole wheat flour baking powder baking soda oil brown sugar (demerara sugar) cinnamon powder (dalchini) dry ginger powder vanilla extract slivered almonds (badam) walnuts',
#  'mini pita breads cauliflower (gobi) cumin seeds (jeera) coriander (dhania) seeds fennel seeds (saunf) badam (almond) sunflower oil salt avocado basil leaves garlic lemon juice milk salt green chilli',
#  'cabbage (patta gobi/ muttaikose) carrots (gajjar) green bell pepper (capsicum) red onion green chilli vinegar classic mayonnaise (with egg) black pepper powder',
#  'colocasia root (arbi) red chilli powder turmeric powder (haldi) amchur (dry mango powder) coriander (dhania) powder asafoetida (hing) salt gingelly oil mustard seeds white urad dal (split) dry red chilli curry leaves',
#  'mangalorean cucumber chana dal (bengal gram dal) cumin seeds (jeera) bay leaf (tej patta) ginger tomato coriander powder (dhania) turmeric powder (haldi) red chilli powder sugar coriander (dhania) leaves oil cumin seeds (jeera) dry red chilli salt',
#  'pointed gourd (parval) potato turmeric powder (haldi) red chilli powder coriander powder (dhania) amchur (dry mango powder) mustard seeds cumin seeds (jeera) salt mustard oil',
#  'mustard oil mustard seeds bay leaves (tej patta) green chilli potato kaddu (parangikai/ pumpkin) small brinjal (baingan / eggplant) carrot (gajjar) turmeric powder (haldi) salt sugar fresh coconut yellow moong dal (split) chana dal (bengal gram dal) ginger dry red chilli turmeric powder (haldi) mustard oil',
#  'potato garlic fresh thyme leaves salt',
#  'kabuli chana (white chickpeas) extra virgin olive oil cinnamon stick (dalchini) garlic onions salt whole black pepper corns turmeric powder (haldi) paprika powder cumin powder (jeera) tomato apricots lemon juice mint leaves (pudina) coriander (dhania) leaves whole almonds (badam)',
#  'whole wheat flour black urad dal (whole) water oil salt',
#  'potato green chilli ginger curry leaves mustard seeds white urad dal (split) turmeric powder (haldi) oil coriander (dhania) leaves',
#  'mustard oil mustard seeds bay leaves (tej patta) green chilli potato brinjal (baingan / eggplant) carrot (gajjar) turmeric powder (haldi) salt sugar yellow moong dal (split) chana dal (bengal gram dal) dry red chilli turmeric powder (haldi) mustard oil',
#  'chicken onion tomato green chilli bay leaves (tej patta) cardamom (elaichi) pods/seeds cloves (laung) cinnamon stick (dalchini) whole black peppercorns extra virgin olive oil salt basmati rice water cardamom (elaichi) pods/seeds cloves (laung) whole black peppercorns nutmeg powder dry ginger powder bay leaves (tej patta)',
#  'vivatta maida salt water oil green moong dal (whole) cumin seeds (jeera) fennel seeds (saunf) sesame seeds (til seeds) sugar asafoetida (hing) amchur (dry mango powder) turmeric powder (haldi) red chilli powder green chilli ginger salt',
#  'pink masoor dal (split) garlic ginger green chilli onion tomato turmeric powder (haldi) red chilli powder salt to taste coriander (dhania) leaves',
#  'all purpose flour (maida) milk vanilla extract whole eggs caster sugar salt butter (unsalted)',
#  'mooli/ mullangi (radish) arhar dal (split toor dal) onion fresh coconut green chilli dry red chilli coriander (dhania) seeds tamarind jaggery salt',
#  'pav buns butter (salted) onion sev fresh pomegranate fruit kernels coriander (dhania) leaves potato fennel seeds (saunf) coriander (dhania) seeds cumin seeds (jeera) sesame seeds (til seeds) dry red chilli whole black pepper corns cinnamon stick (dalchini) brown cardamom (badi elaichi) star anise dessicated coconut kashmiri red chilli powder sugar amchur (dry mango powder) salt',
#  'sunflower oil cumin seeds (jeera) bay leaves (tej patta) onion ginger garlic green chilli tomato cashew nuts kashmiri red chilli powder turmeric powder (haldi) coriander powder (dhania) salt carrots (gajjar) sweet corn green peas (matar) green beans (french beans) green bell pepper (capsicum) cauliflower (gobi) button mushrooms water fresh cream kasuri methi (dried fenugreek leaves) coriander (dhania) leaves mint leaves (pudina) lemon',
#  'button mushrooms spinach onion garlic extra virgin olive oil whole wheat bread crumbs dried oregano red bell pepper (capsicum) parmesan cheese mozzarella cheese salt',
#  'elephant yam (suran/senai/ratalu) turmeric powder (haldi) salt raw peanuts (moongphali) sesame (gingelly) oil mustard seeds white urad dal (split) curry leaves green chilli salt turmeric powder (haldi) red chilli powder',
#  'pani puris potato salt cumin powder (jeera) chaat masala powder red chilli powder mango (raw) mint leaves (pudina) cumin powder (jeera) black salt (kala namak) black pepper powder sugar',
#  'bhindi (lady finger/okra) oil gram flour (besan) turmeric powder (haldi) coriander powder (dhania) red chilli powder salt cumin seeds (jeera) dry red chilli cinnamon stick (dalchini)',
#  'potato onion green chilli ginger garlic cashew nuts gram flour (besan) turmeric powder (haldi) salt coriander (dhania) leaves sesame (gingelly) oil mustard seeds chana dal (bengal gram dal) curry leaves',
#  'bimbla (bilimbi) fresh coconut red chilli powder turmeric powder (haldi) jaggery oil methi seeds (fenugreek seeds) white urad dal (split) mustard seeds curry leaves asafoetida (hing) salt',
#  'papaya onion parsley leaves lemon feta cheese roasted peanuts (moongphali) salt and pepper',
#  'tindora (dondakaya/ kovakkai) cashew nuts fresh coconut sugar salt coconut oil white urad dal (split) mustard seeds dry red chilli turmeric powder (haldi) curry leaves',
#  'tortillas mozzarella cheese chicken breasts green bell pepper (capsicum) spring onion (bulb & greens) garlic ginger green chilli corn flour tomato ketchup sunflower oil salt',
#  'mango (raw) kaddu (parangikai/ pumpkin) green chilli ginger dry red chilli cumin seeds (jeera) fennel seeds (saunf) methi seeds (fenugreek seeds) whole black peppercorns coriander (dhania) seeds fresh coconut oil',
#  'gram flour (besan) whole wheat flour rice flour cucumber turmeric powder (haldi) cumin powder (jeera) coriander powder (dhania) red chilli powder green chilli coriander (dhania) leaves garlic salt',
#  'butter (unsalted) cocoa powder sugar all purpose flour (maida) salt milk chocolate chips vanilla extract',
#  'carrot (gajjar) bottle gourd (lauki) potato green peas (matar) green capsicum gram flour (besan) green chilli cumin powder (jeera) salt amchur (dry mango powder) cashew nuts cumin (jeera) seeds sunflower oil ginger garlic onions cinnamon stick (dalchini) cardamom (elaichi) pods/seeds jaggery cloves (laung) tomato turmeric powder (haldi) red chilli powder kasuri methi (dried fenugreek leaves) salt',
#  'whole eggs coconut oil cumin seeds (jeera) curry leaves green chilli pearl onions (sambar onions) salt turmeric powder (haldi) black pepper powder coriander (dhania) leaves',
#  'red chilli flakes brown sugar (demerara sugar) ginger sesame seeds (til seeds) star anise garlic cooking oil',
#  'bathua leaves green chilli ginger black salt (kala namak) cumin powder (jeera) black pepper powder cooking oil',
#  'carrot (gajjar) green bell pepper (capsicum) onion hakka noodles spring onion (bulb & greens) black pepper powder salt all purpose flour (maida) water',
#  'extra virgin olive oil red yellow and green bell peppers (capsicum) black olives sweet corn salt to taste pickled jalapenos mixed herbs (dried) red chilli flakes mozzarella cheese',
#  'chicken breasts whole egg corn flour salt tomato ketchup vinegar sesame (gingelly) oil ginger garlic green chilli onion spring onion greens',
#  'garlic ginger spring onion (bulb & greens) lemon grass green chilli coriander (dhania) seeds water cauliflower (gobi) red bell pepper (capsicum) green beans (french beans) pineapple coconut milk brown sugar (demerara sugar) salt basil leaves oil',
#  'apples beetroots salad leaves black olives walnuts extra virgin olive oil apple cider vinegar honey salt',
#  'fennel seeds (saunf) coriander (dhania) seeds whole black pepper corns byadagi dried chilli cloves (laung) cinnamon stick cardamom (elaichi) pods/seeds fresh coconut whole eggs coconut oil pearl onions (sambar onions) curry leaves ginger garlic green chilli tomato tomato',
#  'spinach britannia cheese cubes chicken keema salt garlic powder mixed herbs (dried) red chilli flakes extra virgin olive oil black pepper powder oil whole eggs whole wheat bread crumbs mixed herbs (dried)',
#  'sweet corn onion tomato green bell pepper (capsicum) yellow bell pepper (capsicum) red bell pepper (capsicum) carrot (gajjar) lemon juice extra virgin olive oil green chilli coriander (dhania) leaves salt',
#  'broccoli button mushrooms red bell pepper (capsicum) extra virgin olive oil garlic black pepper corns salt to taste basil leaves',
#  'bottle gourd (lauki) yellow moong dal (split) mustard seeds cumin (jeera) seeds curry leaves dry red chilli pearl onions (sambar onions) tomato turmeric powder (haldi) salt to taste coriander (dhania) leaves',
#  'milk whole almonds (badam) sugar saffron strands cardamom powder (elaichi) pistachios',
#  'all purpose flour (maida) whole wheat flour baking powder salt extra virgin olive oil carrots (gajjar) garlic salt tzatziki',
#  'methi leaves (fenugreek leaves) soya chunks mustard oil cumin (jeera) seeds onions ginger garlic bay leaf (tej patta) cinnamon stick (dalchini) turmeric powder (haldi) coriander (dhania) powder red chilli powder amchur (dry mango powder) jaggery salt to taste',
#  'kashmiri dry red chilli mutton cumin seeds (jeera) cumin powder (jeera) coriander powder (dhania) turmeric powder (haldi) brown cardamom (badi elaichi) cardamom (elaichi) pods/seeds cinnamon stick (dalchini) cloves (laung) bay leaf (tej patta) onions salt coriander (dhania) leaves charcoal',
#  'mooli/ mullangi (radish) yellow moong dal (split) turmeric powder (haldi) green chilli ginger fresh coconut mustard seeds dry red chilli asafoetida (hing) coriander (dhania) leaves lemon wedges',
#  'basmati rice extra virgin olive oil onion green chilli garlic green bell pepper (capsicum) tomato celery sweet corn green peas (matar) red chilli powder cheddar cheese coal salt',
#  'sweet corn coriander (dhania) leaves baking powder whole egg salt sunflower oil',
#  'basmati rice jackfruit raw (kathal) onions ginger garlic bay leaves (tej patta) cardamom (elaichi) pods/seeds black cardamom (badi elaichi) cloves (laung) whole black peppercorns cinnamon stick (dalchini) star anise mace (javitri) nutmeg powder green chilli red chilli powder coriander powder (dhania) salt mint leaves (pudina) coriander (dhania) leaves lemon juice saffron strands caramelized onions cashew nuts raisins',
#  'spinach leaves (palak) cumin seeds (jeera) whole black peppercorns green chilli fresh coconut salt mustard seeds cumin seeds (jeera) curry leaves dry red chilli',
#  'button mushrooms turmeric powder (haldi) oil salt fresh coconut shallots green chilli curry leaves cumin seeds (jeera) mustard seeds cumin seeds (jeera) curry leaves dry red chilli',
#  'whole egg broccoli onion tomato garlic turmeric powder (haldi) red chilli powder coriander (dhania) leaves salt oil',
#  'multigrain digestive oat biscuits butter (salted) britannia cream cheese hung curd (greek yogurt) honey mango (ripe) mint leaves (pudina)',
#  'green beans (french beans) carrot (gajjar) green peas (matar) potato mangalorean cucumber pointed gourd (parval) green chilli coconut milk mustard seeds cumin seeds (jeera) dry red chilli coconut oil curry leaves',
#  'strawberries sugar lemon juice amul whipping cream condensed milk',
#  'kaddu (parangikai/ pumpkin) carrot (gajjar) garlic milk cinnamon powder (dalchini) brown sugar (demerara sugar) salt and pepper extra virgin olive oil',
#  'bhindi (lady finger/okra) salt oil green chilli cumin seeds (jeera) fresh coconut salt coconut oil white urad dal (split) mustard seeds curry leaves',
#  'arhar dal (split toor dal) potato brinjal (baingan / eggplant) raw banana bottle gourd (lauki) tamarind jaggery curry leaves mustard seeds cumin seeds (jeera) dry red chilli sunflower oil salt sunflower oil white urad dal (split) fresh coconut coriander (dhania) seeds whole black peppercorns cumin seeds (jeera) dry red chilli',
#  'baby brinjals turmeric powder (haldi) salt coconut oil coconut oil mustard seeds fennel seeds (saunf) curry leaves green chilli pearl onions (sambar onions) turmeric powder (haldi) red chilli powder tomato coconut milk salt coriander (dhania) leaves',
#  'bajra (seeds) white urad dal (whole) methi seeds (fenugreek seeds) salt onion green bell pepper (capsicum) green chilli salt mint leaves (pudina) cumin powder (jeera)',
#  'elephant yam (suran/senai/ratalu) turmeric powder (haldi) salt fresh coconut green chilli cumin seeds (jeera) whole black peppercorns coconut oil mustard seeds curry leaves',
#  'chicken breasts garlic ginger black pepper powder red wine brown sugar (demerara sugar) vinegar sunflower oil garlic corn flour water',
#  'kala chana (brown chickpeas) mangalorean cucumber drumstick turmeric powder (haldi) pearl onions (sambar onions) salt mustard seeds curry leaves sesame (gingelly) oil fresh coconut coriander (dhania) seeds methi seeds (fenugreek seeds) white urad dal (split) dry red chilli',
#  'cauliflower (gobi) onion garlic black pepper powder red chilli powder coriander (dhania) leaves salt mustard seeds curry leaves black urad dal (split) dry red chilli sunflower oil sunflower oil',
#  'mustard oil garlic green chilli tomato gram flour (besan) tamarind kaddu (parangikai/ pumpkin) mooli/ mullangi (radish) colocasia root (arbi) brinjal (baingan / eggplant) carrot (gajjar) bhindi (lady finger/okra) drumstick turmeric powder (haldi) red chilli powder salt oil',
#  'lotus stem gram flour (besan) dry ginger powder fennel seeds (saunf) ajwain (carom seeds) cinnamon stick (dalchini) black cardamom (badi elaichi) cardamom (elaichi) pods/seeds cloves (laung) bay leaf (tej patta) asafoetida (hing) salt',
#  'orange tamarind jaggery rasam powder red chilli powder rice flour salt oil mustard seeds cumin seeds (jeera) methi seeds (fenugreek seeds) white urad dal (split) dry red chilli green chilli asafoetida (hing) turmeric powder (haldi)',
#  'all purpose flour (maida) baking powder whole eggs butter (salted) oil brown sugar (demerara sugar) sugar vanilla extract ripe bananas chocolate chips walnuts walnuts',
#  'pineapple fresh coconut white urad dal (split) dry red chilli jaggery salt mustard seeds curry leaves sunflower oil',
#  'chana dal (bengal gram dal) dry coconut (kopra) turmeric powder (haldi) salt mustard oil cumin seeds (jeera) green chilli ginger dry red chilli cloves (laung) cinnamon stick (dalchini) bay leaf (tej patta)',
#  'whole wheat flour salt oil arhar dal (split toor dal) jaggery saffron strands cardamom powder (elaichi) nutmeg powder gram flour (besan)',
#  'chicken whole egg corn flour salt sunflower oil corn flour chilli vinegar water garlic ginger onion green bell pepper (capsicum) green chilli spring onion greens',
#  'baguette garlic button mushrooms extra virgin olive oil salt black pepper powder basil leaves',
#  'green moong dal (whole) fresh coconut dry red chilli coconut oil mustard seeds curry leaves salt',
#  'britannia cheese block green chilli onions mint leaves (pudina) cumin powder (jeera) whole wheat flour kalonji (onion nigella seeds) salt',
#  'sweet potatoes onions garlic red chilli flakes honey salt and pepper sunflower oil',
#  'flat green beans small brinjal (baingan / eggplant) ajwain (carom seeds) mustard seeds ginger garlic tomato asafoetida (hing) turmeric powder (haldi) coriander powder (dhania) cumin powder (jeera) red chilli powder jaggery sunflower oil salt methi leaves (fenugreek leaves) gram flour (besan) whole wheat flour turmeric powder (haldi) jaggery asafoetida (hing) enos fruit salt lemon juice sunflower oil salt',
#  'potato mustard oil turmeric powder (haldi) rice flour lemon juice salt mustard oil green chilli coriander (dhania) leaves',
#  'sunflower oil cumin seeds (jeera) garlic onions red chilli powder turmeric powder (haldi) coconut milk dijon mustard carrots (gajjar) green beans (french beans) green peas (matar) potato salt',
#  'spinach leaves (palak) garlic salt fresh coconut dry red chilli tamarind',
#  'rice tomato green chilli basil leaves garlic extra virgin olive oil whole black peppercorns salt water coriander (dhania) leaves',
#  'conchiglie pasta broccoli extra virgin olive oil black pepper powder white vinegar dried oregano salt rosemary fresh thyme leaves',
#  'pearl onions (sambar onions) roasted peanuts (moongphali) garlic coriander powder (dhania) red chilli powder cumin powder (jeera) turmeric powder (haldi) coriander (dhania) leaves sunflower oil salt',
#  'quinoa brown rice garlic button mushrooms green bell pepper (capsicum) broccoli cheddar cheese fresh cream salt black pepper powder',
#  'bhindi (lady finger/okra) garlic cashew nuts fresh coconut curry leaves red chilli powder mustard seeds cumin seeds (jeera) chana dal (bengal gram dal) dry red chilli sunflower oil',
#  'whole wheat flour extra virgin olive oil sugar salt lukewarm water green zucchini onion mozzarella cheese',
#  'potato sunflower oil turmeric powder (haldi) red chilli powder coriander powder (dhania) amchur (dry mango powder) salt',
#  'colocasia root (arbi) tamarind salt fresh coconut red chilli powder onions coconut oil onions mustard seeds cumin seeds (jeera) dry red chilli curry leaves',
#  'long green brinjal mustard seeds curry leaves onion tomato turmeric powder (haldi) jaggery salt gingelly oil sesame seeds (til seeds) roasted peanuts (moongphali)',
#  'tindora (dondakaya/ kovakkai) onion dry red chilli methi seeds (fenugreek seeds) coriander (dhania) seeds cumin seeds (jeera) whole black peppercorns tamarind fresh coconut garlic turmeric powder (haldi) salt sunflower oil',
#  'mixed vegetables onion salt turmeric powder (haldi) green chilli coconut oil fresh coconut kashmiri dry red chilli whole black peppercorns onion garlic coriander (dhania) seeds cumin seeds (jeera) tamarind',
#  'methi leaves (fenugreek leaves) brinjal (baingan / eggplant) ginger onion tomato green chilli turmeric powder (haldi) coriander powder (dhania) red chilli powder salt sunflower oil anardana powder (pomegranate seed powder)',
#  'basmati rice onions tomato ginger garlic green chilli red chilli powder turmeric powder (haldi) coriander powder (dhania) cloves (laung) cinnamon stick (dalchini) cardamom (elaichi) pods/seeds bay leaves (tej patta) whole black peppercorns mint leaves (pudina) salt sunflower oil',
#  'fresh pomegranate fruit kernels brussel sprouts cranberries honey green chilli lemon salt and pepper',
#  'mango (raw) jaggery red chilli powder turmeric powder (haldi) salt mustard seeds cumin seeds (jeera) curry leaves dry red chilli gingelly oil',
#  'all purpose flour (maida) lukewarm water salt sugar whole eggs extra virgin olive oil sesame seeds (til seeds)',
#  'coconut oil mustard seeds cumin seeds (jeera) curry leaves nendra pazham banana (ripe) turmeric powder (haldi) salt fresh coconut green chilli curry leaves cumin seeds (jeera) lukewarm water sunflower oil',
#  'wild rice green bell pepper (capsicum) yellow bell pepper (capsicum) red bell pepper (capsicum) onion ginger garlic salt and pepper sunflower oil paprika powder dried oregano black pepper powder cinnamon powder (dalchini) ginger sugar garlic onion salt tofu',
#  'karela (bitter gourd/ pavakkai) onions turmeric powder (haldi) red chilli powder kashmiri red chilli powder jaggery salt sunflower oil onion fresh coconut sunflower oil sunflower oil mustard seeds asafoetida (hing)',
#  'mackerel fish goan recheado masala sooji (semolina/ rava) extra virgin olive oil salt',
#  'corn cob mooli/ mullangi (radish) spring onion greens extra virgin olive oil lemon salt whole black peppercorns dijon mustard coriander (dhania) leaves',
#  'egg white button mushrooms spinach onion dried oregano basil leaves red chilli flakes salt and pepper',
#  'cashew nuts fresh coconut sugar salt coconut oil white urad dal (split) mustard seeds dry red chilli garlic turmeric powder (haldi) curry leaves',
#  'blanched tomato extra virgin olive oil garlic onion basil leaves salt whole black peppercorns sugar',
#  'mangalorean cucumber arhar dal (split toor dal) turmeric powder (haldi) salt sunflower oil coriander (dhania) seeds cumin seeds (jeera) methi seeds (fenugreek seeds) white urad dal (split) whole black peppercorns fresh coconut dry red chilli garlic sunflower oil mustard seeds white urad dal (split) dry red chilli garlic curry leaves',
#  'white urad dal (whole) ginger green chilli salt onions coriander (dhania) leaves sunflower oil arhar dal (split toor dal) pearl onions (sambar onions) mooli/ mullangi (radish) carrot (gajjar) salt coriander (dhania) leaves gingelly oil mustard seeds dry red chilli curry leaves asafoetida (hing)',
#  'chicken breasts garlic lemon juice dried oregano dried thyme leaves rosemary red chilli flakes salt cumin powder (jeera) whole egg milk all purpose flour (maida)',
#  'small brinjal (baingan / eggplant) arhar dal (split toor dal) turmeric powder (haldi) mustard seeds curry leaves salt sesame (gingelly) oil chana dal (bengal gram dal) white urad dal (split) coriander (dhania) seeds whole black peppercorns dry red chilli fresh coconut asafoetida (hing)',
#  'whole eggs onion green chilli coriander (dhania) leaves salt onion green chilli coriander (dhania) seeds whole black peppercorns ginger garlic coriander (dhania) leaves mint leaves (pudina) tomato fresh coconut poppy seeds hung curd (greek yogurt) turmeric powder (haldi) salt sunflower oil cinnamon stick (dalchini) cardamom (elaichi) pods/seeds curry leaves onion coriander (dhania) leaves',
#  'small brinjal (baingan / eggplant) onion green chilli garlic ginger mustard seeds bay leaf (tej patta) cinnamon stick (dalchini) cloves (laung) red chilli powder cumin powder (jeera) coriander powder (dhania) turmeric powder (haldi) oil salt fresh coconut sesame seeds (til seeds) roasted peanuts (moongphali) coriander (dhania) leaves',
#  'mutton cumin powder (jeera) red chilli powder coriander powder (dhania) turmeric powder (haldi) salt lemon juice onion garlic ginger curry leaves black pepper powder fresh coconut salt water coconut oil',
#  'chana dal (bengal gram dal) green chilli mustard seeds white urad dal (split) cumin seeds (jeera) curry leaves asafoetida (hing) onion red chilli powder turmeric powder (haldi) salt sunflower oil',
#  'red bell pepper (capsicum) kaddu (parangikai/ pumpkin) garlic extra virgin olive oil milk red chilli flakes salt',
#  'small brinjal (baingan / eggplant) methi leaves (fenugreek leaves) turmeric powder (haldi) red chilli powder coriander powder (dhania) cumin powder (jeera) jaggery amchur (dry mango powder) mustard seeds cumin seeds (jeera) sunflower oil salt',
#  'karela (bitter gourd/ pavakkai) red chilli powder turmeric powder (haldi) sooji (semolina/ rava) salt extra virgin olive oil',
#  'cucumber kala chana (brown chickpeas) fresh coconut dry red chilli tamarind coriander (dhania) seeds turmeric powder (haldi) whole black peppercorns sugar salt',
#  'cabbage (patta gobi/ muttaikose) carrot (gajjar) ginger salt all purpose flour (maida) corn flour sunflower oil sunflower oil red bell pepper (capsicum) green bell pepper (capsicum) yellow bell pepper (capsicum) green beans (french beans) carrot (gajjar) green chilli ginger salt tomato ketchup sugar chilled water corn flour coriander (dhania) leaves',
#  'mixed vegetables cabbage (patta gobi/ muttaikose) salt black pepper powder sunflower oil cooked rice garlic black pepper powder chilli vinegar salt sunflower oil potato button mushrooms salt red chilli powder whole wheat bread crumbs sunflower oil sunflower oil black pepper powder garlic chilli vinegar tomato ketchup water',
#  'bok choy cabbage (patta gobi/ muttaikose) button mushrooms lotus stem garlic honey salt sunflower oil spring onion (bulb & greens)',
#  'black urad dal (whole) rajma (large kidney beans) cumin seeds (jeera) cinnamon stick (dalchini) cloves (laung) black cardamom (badi elaichi) tomato green chilli red chilli powder dry ginger powder milk salt ginger fresh cream',
#  'tomato green chilli turmeric powder (haldi) red chilli powder salt coconut oil mustard seeds curry leaves fresh coconut cumin seeds (jeera) pearl onions (sambar onions)',
#  'spinach garlic onion potato all purpose flour (maida) red chilli powder dried oregano salt sunflower oil',
#  'prawns turmeric powder (haldi) red chilli powder salt sooji (semolina/ rava) rice flour turmeric powder (haldi) red chilli powder salt sunflower oil',
#  'potato drumstick ginger tomato cinnamon stick (dalchini) bay leaves (tej patta) asafoetida (hing) red chilli powder coriander powder (dhania) turmeric powder (haldi) salt coriander (dhania) leaves',
#  'corn flour sweet corn carrots (gajjar) green beans (french beans) spring onion greens salt black pepper powder sugar green chilli rice vinegar',
#  'vivatta maida sugar salt butter (unsalted) whole eggs fresh herbs lukewarm water milk whole egg sesame seeds (til seeds)',
#  'brinjal (baingan / eggplant) turmeric powder (haldi) red chilli powder mustard seeds poppy seeds mustard oil green chilli salt',
#  'dried green peas (vatana) potato turmeric powder (haldi) fresh coconut coriander (dhania) seeds white urad dal (split) cumin seeds (jeera) dry red chilli jaggery mustard seeds curry leaves salt',
#  'black rice salt jaggery coconut milk mango (ripe) goji berries mixed nuts',
#  'seeraga (jeeraga) samba rice bay leaf (tej patta) star anise cinnamon stick (dalchini) cardamom (elaichi) pods/seeds cloves (laung) chicken oil ginger garlic onions tomato red chilli powder salt coriander powder (dhania) mint leaves (pudina)',
#  'spaghetti pasta garlic extra virgin olive oil red chilli flakes mixed herbs (dried) kaddu (parangikai/ pumpkin) spinach leaves (palak) walnuts salt',
#  'whole cashews tomato green chilli kashmiri red chilli powder bay leaf (tej patta) kasuri methi (dried fenugreek leaves) fresh cream salt',
#  'green amaranth leaves fresh coconut cumin seeds (jeera) green chilli jaggery mustard seeds white urad dal (split) dry red chilli asafoetida (hing) curry leaves sunflower oil salt',
#  'sweet corn polenta mozzarella cheese cheddar cheese green chilli onion milk sugar extra virgin olive oil salt',
#  'colocasia root (arbi) mustard seeds turmeric powder (haldi) dry red chilli curry leaves salt sunflower oil black pepper powder cumin seeds (jeera) methi seeds (fenugreek seeds) fresh coconut',
#  'arhar dal (split toor dal) tamarind shallot bhindi (lady finger/okra) tomato salt sesame (gingelly) oil mustard seeds dry red chilli asafoetida (hing) curry leaves coriander (dhania) leaves',
#  'cauliflower (gobi) green bell pepper (capsicum) gram flour (besan) coriander powder (dhania) coconut milk cumin seeds (jeera) curry leaves cloves (laung) cinnamon stick (dalchini) ginger red chilli powder salt sunflower oil',
#  'tagliatelle pasta basil leaves extra virgin olive oil salt parmesan cheese tomato garlic onion sugar whole black pepper corns red chilli flakes basil leaves salt red chilli powder amchur (dry mango powder) onion sugar methi seeds (fenugreek seeds) dry red chilli garlic ginger',
#  'all purpose flour (maida) whole wheat flour ragi flour (finger millet/ nagli) black pepper powder salt baking powder green bell pepper (capsicum) carrot (gajjar) green peas (matar) sweet corn coriander (dhania) leaves sunflower oil',
#  'ridge gourd (turai/ peerkangai) methi leaves (fenugreek leaves) onion cumin seeds (jeera) dry red chilli garlic green chilli coriander powder (dhania) turmeric powder (haldi) lemon sunflower oil',
#  'onion green bell pepper (capsicum) ginger red chilli powder green chilli sunflower oil dried oregano salt spring onion greens coriander (dhania) leaves',
#  'prawns rice tomato onion garlic ginger green chilli curry leaves kashmiri red chilli powder salt turmeric powder (haldi) cloves (laung) cinnamon stick (dalchini) cardamom (elaichi) pods/seeds bay leaves (tej patta) sugar asafoetida (hing) cumin seeds (jeera) sunflower oil',
#  'macaroni pasta whole eggs green bell pepper (capsicum) onion tomato button mushrooms parsley leaves salt and pepper cheese extra virgin olive oil',
#  'arhar dal (split toor dal) mango (raw) turmeric powder (haldi) onion tomato garlic dry red chilli mustard seeds curry leaves',
#  'soy chunks (nuggets) tomato onion green chilli garlic cumin seeds (jeera) curry leaves turmeric powder (haldi) red chilli powder coriander powder (dhania) curry powder coconut milk sunflower oil salt',
#  'whole wheat flour salt sunflower oil',
#  'arhar dal (split toor dal) white urad dal (split) tomato ginger garlic turmeric powder (haldi) asafoetida (hing) ginger garlic cumin seeds (jeera) green chilli mustard oil',
#  'baguette garlic powder extra virgin olive oil watermelon cucumber red onion spinach balsamic vinegar black olives salt and pepper',
#  'cabbage (patta gobi/ muttaikose) cooked rice button mushrooms carrot (gajjar) onion garlic black pepper powder mixed herbs (dried) sunflower oil salt tomato onion garlic black pepper powder red chilli powder sunflower oil sugar salt',
#  'bhindi (lady finger/okra) onion tomato ginger red chilli powder turmeric powder (haldi) coriander powder (dhania) gram flour (besan) fennel seeds (saunf) cumin seeds (jeera) kalonji (onion nigella seeds) mustard seeds ajwain (carom seeds)',
#  'button mushrooms carrots (gajjar) extra virgin olive oil all purpose flour (maida) milk fresh cream mozzarella cheese italian seasoning dried oregano salt and pepper',
#  'elephant yam (suran/senai/ratalu) mustard seeds dry red chilli methi seeds (fenugreek seeds) asafoetida (hing) turmeric powder (haldi) jaggery salt sunflower oil',
#  'green bell pepper (capsicum) raw peanuts (moongphali) cashew nuts coconut oil mustard seeds methi seeds (fenugreek seeds) asafoetida (hing) turmeric powder (haldi) red chilli powder jaggery cloves (laung) cinnamon stick (dalchini) coriander (dhania) seeds cumin seeds (jeera) whole black pepper corns methi seeds (fenugreek seeds) fresh coconut roasted peanuts (moongphali) tamarind',
#  'cooked rice carrot (gajjar) green bell peppers red bell pepper (capsicum) onion ginger garlic chilli vinegar whole black peppercorns salt spring onion greens sunflower oil garlic sunflower oil',
#  'drumstick mangalorean cucumber red chilli powder turmeric powder (haldi) jaggery garlic salt dry red chilli coriander (dhania) seeds fresh coconut',
#  'gram flour (besan) ajwain (carom seeds) red chilli powder oil salt gram flour (besan) asafoetida (hing) turmeric powder (haldi) red chilli powder bay leaf (tej patta) cinnamon stick (dalchini) salt coriander (dhania) leaves mustard seeds cumin seeds (jeera) curry leaves',
#  'phulka button mushrooms green zucchini green bell peppers onion sunflower oil mexican seasoning salt',
#  'mango (raw) fresh coconut white urad dal (split) methi seeds (fenugreek seeds) basmati rice dry red chilli turmeric powder (haldi) curry leaves mustard seeds asafoetida (hing) jaggery salt coconut oil',
#  'arhar dal (split toor dal) chow chow (chayote squash) tamarind onion tomato turmeric powder (haldi) coriander (dhania) leaves sunflower oil salt sesame (gingelly) oil mustard seeds asafoetida (hing) dry red chilli curry leaves',
#  'ragi flour (finger millet/ nagli) instant oats (oatmeal) water milk honey multigrain digestive ragi biscuits badam (almond) pistachios',
#  'raw banana tomato onion green bell pepper (capsicum) green chilli green peas (matar) red chilli powder turmeric powder (haldi) coriander powder (dhania) pav bhaji masala salt cumin seeds (jeera) sunflower oil water lemon juice onion mozzarella cheese coriander (dhania) leaves pizza base',
#  'kaddu (parangikai/ pumpkin) tomato poppy seeds garlic turmeric powder (haldi) coriander powder (dhania) coriander (dhania) leaves salt red chilli powder',
#  'whole wheat flour turmeric powder (haldi) sunflower oil arhar dal (split toor dal) jaggery fresh coconut cardamom powder (elaichi)',
#  'carrots (gajjar) spinach salt mustard seeds green chilli pearl onions (sambar onions) coriander (dhania) leaves sunflower oil',
#  'bhindi (lady finger/okra) ajwain (carom seeds) asafoetida (hing) red chilli powder sugar cashew nuts salt',
#  'arhar dal (split toor dal) tomato turmeric powder (haldi) jaggery salt coriander (dhania) leaves whole black peppercorns cumin seeds (jeera) coriander (dhania) seeds arhar dal (split toor dal) methi seeds (fenugreek seeds) mustard seeds cumin seeds (jeera) asafoetida (hing) curry leaves',
#  'chicken onion green chilli whole eggs coriander (dhania) leaves mint leaves (pudina) red chilli powder turmeric powder (haldi) coriander powder (dhania) salt lemon juice sunflower oil whole wheat bread crumbs',
#  'cauliflower (gobi) badam (almond) cumin powder (jeera) coriander powder (dhania) cinnamon powder (dalchini) salt extra virgin olive oil black pepper powder',
#  'jackfruit raw (kathal) yellow moong dal (split) sunflower oil black urad dal (split) cumin seeds (jeera) mustard seeds dry red chilli asafoetida (hing) curry leaves turmeric powder (haldi) salt',
#  'tindora (dondakaya/ kovakkai) mustard seeds cumin seeds (jeera) dry red chilli asafoetida (hing) curry leaves sunflower oil turmeric powder (haldi) salt white urad dal (split) chana dal (bengal gram dal) coriander (dhania) seeds cumin seeds (jeera) sesame seeds (til seeds) dry red chilli fresh coconut',
#  'broccoli onion coriander powder (dhania) salt red chilli powder cumin powder (jeera) sunflower oil whole wheat flour salt water sunflower oil',
#  'asafoetida (hing) onion ginger garlic green chilli tomato turmeric powder (haldi) red chilli powder salt masoor dal (whole) water coriander (dhania) leaves cumin seeds (jeera) asafoetida (hing) red chilli powder',
#  'cabbage (patta gobi/ muttaikose) gram flour (besan) green chilli coriander (dhania) leaves cumin powder (jeera) red chilli powder turmeric powder (haldi) salt sunflower oil tomato ginger gram flour (besan) fresh cream coriander powder (dhania) red chilli powder turmeric powder (haldi) cumin powder (jeera) bay leaf (tej patta) cardamom (elaichi) pods/seeds salt sunflower oil coriander (dhania) leaves',
#  'cooked rice sunflower oil indian borage (doddapatre) cumin seeds (jeera) chana dal (bengal gram dal) white urad dal (split) dessicated coconut byadagi dried chilli guntur dried chilli coriander (dhania) leaves mustard seeds chana dal (bengal gram dal) white urad dal (split) asafoetida (hing) raw peanuts (moongphali) curry leaves salt',
#  'pasta  fusilli extra virgin olive oil garlic cherry tomato salt whole black peppercorns basil leaves mozzarella cheese',
#  'masoor dal (whole) onion tomato garlic ginger bay leaf (tej patta) cloves (laung) cumin seeds (jeera) cinnamon stick (dalchini) red chilli powder coriander powder (dhania) fresh cream salt',
#  'green amaranth leaves shallots green chilli dry red chilli mustard seeds white urad dal (split) mandi coconut milk sesame (gingelly) oil salt',
#  'conchiglie pasta green bell peppers red bell pepper (capsicum) yellow bell pepper (capsicum) onion green chilli salt vinegar sugar extra virgin olive oil',
#  'kabuli chana (white chickpeas) masoor dal (whole) carrot (gajjar) onion coriander (dhania) leaves garlic salt black pepper powder cumin powder (jeera) coriander powder (dhania) turmeric powder (haldi) cinnamon powder (dalchini) paprika powder mint leaves (pudina) extra virgin olive oil coriander (dhania) leaves parsley leaves',
#  'all purpose flour (maida) whole eggs water cheddar cheese button mushrooms onion garlic salt balsamic vinegar spring onion (bulb & greens) red chilli flakes coriander (dhania) leaves quail eggs',
# ...
#  'fresh cream milk caster sugar gelatin vanilla extract water green grapes caster sugar gelatin green grapes water black grapes caster sugar gelatin black grapes water green grapes',
#  'whole wheat flour brown sugar (demerara sugar) baking powder baking soda salt water oil vanilla extract',
#  'prawns all purpose flour (maida) corn flour whole eggs whole wheat bread crumbs salt black pepper powder garlic powder red chilli powder sweet potatoes extra virgin olive oil paprika powder salt black pepper powder',
#  'britannia cream cheese hung curd (greek yogurt) sugar gelatin water raspberry compote marie biscuit butter (salted)',
#  'fresh figs lemon juice lemon zest red chilli flakes honey brown sugar (demerara sugar)',
#  'apple dates multigrain digestive oat biscuits whole almonds (badam) milk',
#  'black rice fresh coconut jaggery',
#  'vellai poosanikai (ash gourd/white pumpkin) drumstick carrots (gajjar) green beans (french beans) raw banana potato elephant yam (suran/senai/ratalu) turmeric powder (haldi) salt fresh coconut green chilli curry leaves cumin seeds (jeera) coconut oil salt',
#  'tomato green chilli red chilli powder ginger salt mustard seeds curry leaves oil',
#  'sooji (semolina/ rava) sugar milk baking powder cardamom powder (elaichi) nutmeg pistachios sultana raisins saffron strands',
#  'cabbage (patta gobi/ muttaikose) carrot (gajjar) all purpose flour (maida) rice flour turmeric powder (haldi) red chilli powder salt sugar black pepper powder water oil',
#  'ragi flour (finger millet/ nagli) jaggery muesli instant coffee powder extra virgin olive oil vanilla extract apricots egg whites',
#  'rice black urad dal (split) fresh coconut asafoetida (hing) salt oil',
#  'arugula leaves watermelon feta cheese extra virgin olive oil red wine vinaigrette honey salt black pepper powder',
#  'chana dal (bengal gram dal) white urad dal (split) cinnamon stick (dalchini) cloves (laung) cardamom (elaichi) pods/seeds dry red chilli methi seeds (fenugreek seeds) poppy seeds coriander (dhania) seeds fresh coconut turmeric powder (haldi) asafoetida (hing) pearl onions (sambar onions) green bell pepper (capsicum) carrots (gajjar) green peas (matar) green beans (french beans) potato drumstick tomato jaggery salt rice arhar dal (split toor dal) turmeric powder (haldi) salt mustard seeds cumin seeds (jeera) dry red chilli curry leaves coriander (dhania) leaves boondi',
#  'all purpose flour (maida) ajwain (carom seeds) sooji (semolina/ rava) salt water oil potato onion oil cumin seeds (jeera) turmeric powder (haldi) red chilli powder coriander powder (dhania) anardana powder (pomegranate seed powder) fennel seeds (saunf) sugar salt kasuri methi (dried fenugreek leaves) coriander (dhania) leaves fresh pomegranate fruit kernels lemon wedges onion',
#  'cauliflower (gobi) turmeric powder (haldi) mustard oil cumin seeds (jeera) bay leaf (tej patta) water onion water kashmiri red chilli powder fresh cream green chilli cashew nuts salt',
#  'whole turmeric ginger brown sugar (demerara sugar) honey cinnamon stick (dalchini) cardamom (elaichi) pods/seeds saffron strands milk sultana raisins',
#  'puffed rice sev papdi puris onion tomato green chilli cucumber potato anardana powder (pomegranate seed powder) mango (raw) roasted peanuts (moongphali) chaat masala powder salt coriander (dhania) leaves',
#  'potato ajwain (carom seeds) onion ginger garlic tomato turmeric powder (haldi) coriander powder (dhania) kashmiri red chilli powder coriander (dhania) leaves salt oil',
#  'yellow moong dal (split) cucumber carrot (gajjar) fresh coconut lemon juice salt oil mustard seeds green chilli asafoetida (hing) curry leaves coriander (dhania) leaves',
#  'shrimps tofu iceberg lettuce cabbage (patta gobi/ muttaikose) carrots (gajjar) beetroot red baby radish yellow bell pepper (capsicum) green chilli salt whole black peppercorns lemon juice balsamic vinegar red chilli flakes sugar extra virgin olive oil coriander (dhania) leaves mint leaves (pudina) roasted peanuts (moongphali)',
#  'lettuce leaves tomato english cucumber feta cheese extra virgin olive oil lemon juice honey salt and pepper',
#  'kunafa dough (strands) butter (salted) pistachios milk corn flour rose water ricotta cheese sugar water lemon juice rose water',
#  'extra virgin olive oil garlic onion salt rosemary rice extra virgin olive oil red chilli flakes red bell pepper (capsicum) yellow bell pepper (capsicum) salt green bell pepper (capsicum) mixed herbs (dried) parsley leaves extra virgin olive oil carrots (gajjar) yellow zucchini green zucchini baby corn dry mix herbs salt extra virgin olive oil garlic basil leaves salt sugar paprika powder fresh cream milk mozzarella cheese',
#  'green apple red radish mooli/ mullangi (radish) tomato tomato red cabbage onion broccoli red bell pepper (capsicum) green bell pepper (capsicum) yellow bell pepper (capsicum) lemon juice lemon zest fresh thyme leaves green chilli ginger coriander (dhania) leaves sesame (gingelly) oil garlic salt black pepper powder',
#  'quinoa flour all purpose flour (maida) whole egg vanilla extract honey avocado brown sugar (demerara sugar) baking soda salt cinnamon powder (dalchini) chia seeds',
#  'whole eggs canola oil milk brown sugar (demerara sugar) dessicated coconut all purpose flour (maida) whole wheat flour vanilla extract nutmeg powder cardamom powder (elaichi) baking powder slivered almonds (badam) salt chocolate ganache raspberry compote',
#  'gram flour (besan) hung curd (greek yogurt) ajwain (carom seeds) red chilli powder salt green bell pepper (capsicum) carrot (gajjar) yellow zucchini onion oil dried oregano salt coriander (dhania) leaves mint leaves (pudina) garlic lemon juice green chilli salt',
#  'sultana raisins prunes apricots dates dried figs rum fresh orange juice orange zest (rind) all purpose flour (maida) baking powder butter (unsalted) brown sugar (demerara sugar) cinnamon powder (dalchini) cloves (laung) dry ginger powder whole almonds (badam) flax seed powder (flax meal) chilled water',
#  'butter (unsalted) caster sugar vanilla extract whole eggs fresh cream milk ripe bananas walnuts baileys irish cream',
#  'chana dal (bengal gram dal) white urad dal (split) fennel seeds (saunf) green chilli ginger garlic curry leaves mint leaves (pudina) coriander (dhania) leaves onion oil salt asafoetida (hing)',
#  'beetroot garlic spring onion (bulb & greens) extra virgin olive oil whole black peppercorns walnuts cumin powder (jeera) salt lemon juice coriander (dhania) leaves',
#  'soy milk cocoa powder salt cane sugar vanilla extract chocolate bar',
#  'mango (ripe) milk heavy whipping cream vanilla extract water pistachios saffron strands honey',
#  'dessicated coconut condensed milk milk chocolate',
#  'poblano chilli extra virgin olive oil onion garlic cheddar cheese dried thyme leaves black pepper powder tarragon dried oregano gram flour (besan) whole egg tomato garlic tomato ketchup sugar red chilli flakes dried oregano',
#  'all purpose flour (maida) salt sugar extra virgin olive oil milk lukewarm water pineapple red bell pepper (capsicum) oil hung curd (greek yogurt) gram flour (besan) garlic ginger kasuri methi (dried fenugreek leaves) fennel seeds (saunf) ajwain (carom seeds) cumin powder (jeera) coriander powder (dhania) turmeric powder (haldi) red chilli powder chaat masala powder salt mozzarella cheese cheese',
#  'rice ajwain powder salt',
#  'penne pasta butter (salted) garlic lemon juice lemon rosemary black pepper powder mozzarella cheese',
#  'poha (flattened rice) milk fresh cream green chilli green peas (matar) cumin seeds (jeera) ginger black pepper powder coriander (dhania) leaves lemon juice salt',
#  'dark chocolate egg yolks egg whites caster sugar fresh cream',
#  'red bell pepper (capsicum) garlic coriander (dhania) seeds cumin seeds (jeera) dry red chilli extra virgin olive oil sugar salt',
#  'basa fish all purpose flour (maida) salt black pepper powder whole egg milk whole wheat bread crumbs red chilli powder red chilli flakes garlic powder dry ginger powder cinnamon powder (dalchini) dried oregano',
#  'nendra pazham banana (ripe) oil',
#  'whole wheat flour cinnamon powder (dalchini) cardamom powder (elaichi) baking powder salt whole almonds (badam) butter (salted) brown sugar (demerara sugar) whole eggs vanilla extract whole almonds (badam)',
#  'whole almonds (badam) pistachios sugar butter (salted) cardamom powder (elaichi) milk saffron strands honey rose water gelatin water sugar water saffron strands cardamom powder (elaichi) corn flour water',
#  'arhar dal (split toor dal) tamarind tomato garlic green chilli rasam powder mustard seeds asafoetida (hing) curry leaves coriander (dhania) leaves salt',
#  'green zucchini ajwain (carom seeds) red chilli powder amchur (dry mango powder) cumin powder (jeera) turmeric powder (haldi) whole wheat flour water salt',
#  'green zucchini spring onion greens garlic dill leaves red bell pepper (capsicum) potato salt black pepper powder parmesan cheese whole wheat bread crumbs extra virgin olive oil baking powder',
#  'brinjal (baingan / eggplant) cranberries parsley leaves sesame seeds (til seeds) lemon juice salt oil',
#  'britannia cream cheese agar agar heavy whipping cream white chocolate vanilla extract sugar lemon zest orange zest (rind) graham cracker crumbs butter (unsalted) vanilla extract',
#  'mango (ripe) green chilli salt fresh coconut cumin seeds (jeera) turmeric powder (haldi) red chilli powder coconut oil mustard seeds methi seeds (fenugreek seeds) dry red chilli curry leaves',
#  'mango (raw) jaggery red chilli powder methi seeds (fenugreek seeds) cumin seeds (jeera) asafoetida (hing) water coconut oil salt',
#  'graham cracker crumbs butter (unsalted) britannia cream cheese whole eggs vanilla extract sugar butter (unsalted) vivatta maida brown sugar (demerara sugar) cinnamon powder (dalchini)',
#  'hung curd (greek yogurt) fresh cream rose water sugar butter (salted) all purpose flour (maida) confectioners sugar pistachios sugar dessicated coconut',
#  'carrot (gajjar) green beans (french beans) salt butter (salted) mustard seeds asafoetida (hing)',
#  'plum all purpose flour (maida) whole eggs caster sugar milk rosemary vanilla extract sugar',
#  'chicken ham dill leaves swiss cheese black olives extra virgin olive oil salt black pepper powder',
#  'mint leaves (pudina) coriander (dhania) leaves green chilli red chilli powder cumin powder (jeera) rock salt chaat masala powder kala chana (brown chickpeas) potato red chilli powder rock salt salt',
#  'parsnip honey sesame (gingelly) oil garlic dried thyme leaves dried oregano black pepper powder',
#  'whole eggs hung curd (greek yogurt) dijon mustard fresh herbs salt crackers',
#  'fresh cream garlic chives parsley leaves salt black pepper powder balsamic vinegar buttermilk yellow bell pepper (capsicum) red bell pepper (capsicum) english cucumber carrots (gajjar)',
#  'horse gram dal (kollu/ kulith) bay leaf (tej patta) cardamom (elaichi) pods/seeds black cardamom (badi elaichi) cinnamon stick (dalchini) cumin seeds (jeera) asafoetida (hing) ginger black pepper powder coriander powder (dhania) red chilli powder turmeric powder (haldi) fresh cream salt',
#  'tomato mozzarella cheese basil leaves red wine vinaigrette extra virgin olive oil salt black pepper powder',
#  'all purpose flour (maida) whole wheat flour baking soda salt cinnamon powder (dalchini) nutmeg instant oats (oatmeal) sweet potato whole egg brown sugar (demerara sugar) milk maple syrup extra virgin olive oil vanilla extract chia seeds pecans',
#  'extra virgin olive oil onion garlic button mushrooms fresh thyme leaves salt and pepper extra virgin olive oil onion garlic celery carrot (gajjar) green peas (matar) sweet corn button mushrooms soy chunks (nuggets) dried oregano dried thyme leaves butter (unsalted) potato milk salt and pepper',
#  'whole eggs sunflower oil cumin seeds (jeera) onions green chilli tomato red chilli powder turmeric powder (haldi) coriander powder (dhania) coconut milk salt coriander (dhania) leaves',
#  'oreo biscuits butter (unsalted) nutella spread britannia cream cheese nutella spread caster sugar vanilla extract heavy whipping cream cocoa powder gelatin oreo biscuits fresh cherries',
#  'vivatta maida sugar baking soda baking powder oil instant coffee powder walnuts',
#  'red snapper fish shallots tomato kokum (malabar tamarind) gingelly oil mustard seeds dagad phool (/pathar phool/black stone flower) fennel seeds (saunf) cumin seeds (jeera) turmeric powder (haldi) red chilli powder coriander powder (dhania) salt',
#  'whole wheat flour lukewarm water sugar salt',
#  'whole wheat flour water whole almonds (badam) cashew nuts sultana raisins jaggery ajwain (carom seeds) cardamom powder (elaichi) cinnamon powder (dalchini)',
#  'walnuts walnuts milk jaggery cardamom powder (elaichi)',
#  'whole almonds (badam) jaggery milk cardamom (elaichi) pods/seeds whole almonds (badam) cashew nuts pistachios saffron strands',
#  'basmati rice broccoli green bell pepper (capsicum) red bell pepper (capsicum) onion green chilli garlic coriander (dhania) leaves salt',
#  'ripe bananas cardamom (elaichi) pods/seeds sooji (semolina/ rava) milk hot water jaggery cashew nuts sultana raisins saffron strands',
#  'phool makhana (lotus seeds) milk jaggery cardamom powder (elaichi) cinnamon stick (dalchini) saffron strands whole almonds (badam) sultana raisins chironji',
#  'dates dried figs pistachios cashew nuts whole almonds (badam) walnuts milk',
#  'soy chunks (nuggets) onion green chilli green peas (matar) ginger garlic coriander powder (dhania) red chilli powder turmeric powder (haldi) coriander (dhania) leaves potato corn flour wheat bran salt oil',
#  'sooji (semolina/ rava) coriander (dhania) leaves salt oil garlic whole almonds (badam) green chilli coriander (dhania) leaves',
#  'fresh cream condensed milk vanilla extract pineapple pears peaches plum strawberries mango (ripe) butter (salted) cinnamon powder (dalchini)',
#  'asparagus red bell pepper (capsicum) garlic ginger butter (salted) bay leaf (tej patta) cinnamon powder (dalchini) balsamic vinegar brown sugar (demerara sugar) black pepper powder mint leaves (pudina) water extra virgin olive oil',
#  'whole eggs onion tomato coriander powder (dhania) red chilli powder cinnamon stick (dalchini) cloves (laung) oil salt coriander (dhania) seeds garlic ginger fresh coconut fennel seeds (saunf) whole black peppercorns poppy seeds cumin seeds (jeera) dry red chilli',
#  'sweet potatoes onion dry coconut (kopra) karela (bitter gourd/ pavakkai) tamarind dry red chilli sesame (gingelly) oil raw peanuts (moongphali) turmeric powder (haldi) coriander powder (dhania) salt mustard seeds methi seeds (fenugreek seeds) chana dal (bengal gram dal) asafoetida (hing) curry leaves water',
#  'sooji (semolina/ rava) green chilli onion green bell peppers coriander (dhania) leaves salt and pepper',
#  'raw papaya carrot (gajjar) apple raw peanuts (moongphali) green chilli mint leaves (pudina) lemon juice black pepper powder salt',
#  'instant oats (oatmeal) strawberries whole almonds (badam) cinnamon powder (dalchini) nutmeg powder',
#  'whole wheat flour extra virgin olive oil sugar salt lukewarm water onion garlic dried thyme leaves red chilli flakes sugar salt chicken breasts',
#  'ridge gourd (turai/ peerkangai) whole eggs onion cumin seeds (jeera) mustard seeds white urad dal (split) black pepper powder sunflower oil salt curry leaves',
#  'all purpose flour (maida) baking powder salt butter (salted) caster sugar whole eggs lemon juice lemon zest rosemary hung curd (greek yogurt) white chocolate lemon juice',
#  'cabbage (patta gobi/ muttaikose) mustard seeds cumin seeds (jeera) green chilli tomato turmeric powder (haldi) coriander powder (dhania) red chilli powder salt oil coriander (dhania) leaves',
#  ...]

# %%
dataML = re.sub(r'\b\w{1,2}\b', '', dataML)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-39961f261205> in <module>
# ----> 1 dataML = re.sub(r'\b\w{1,2}\b', '', dataML)
#
# ~/opt/miniconda3/lib/python3.8/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
def clean(test):
    test = re.sub(r'\b\w{1,2}\b', '', test)
    return test

# %%
dataML = dataML.replace(to_replace='\)', value="", regex=True)

# %%
dataML = lambda x: clean(x)

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in dataML['ingredients']])

print(tfidf_matrix.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-48763c9d87a8> in <module>
# ----> 1 tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in dataML['ingredients']])
#       2
#       3 print(tfidf_matrix.shape)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1848         """
#    1849         self._check_params()
# -> 1850         X = super().fit_transform(raw_documents)
#    1851         self._tfidf.fit(X)
#    1852         # X is already a transformed view of raw_documents so
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1201         max_features = self.max_features
#    1202
# -> 1203         vocabulary, X = self._count_vocab(raw_documents,
#    1204                                           self.fixed_vocabulary_)
#    1205
#
# ~/opt/miniconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1132             vocabulary = dict(vocabulary)
#    1133             if not vocabulary:
# -> 1134                 raise ValueError("empty vocabulary; perhaps the documents only"
#    1135                                  " contain stop words")
#    1136
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
tfidf_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-29d9e51ad7c1> in <module>
# ----> 1 tfidf_matrix
#
# NameError: name 'tfidf_matrix' is not defined

# %%
dataML.loc[dataML['ingredients'].str.contains(r'[:ascii:]+') == False]
# Out:
# Empty DataFrame
# Columns: [cuisine, ingredients_list, seperated_ingredients, ingredients]
# Index: []

# %%
dataML = dataML[~dataML['ingredients'].str.contains(r'[^\x00-\x7F]')]

# %%
dataML.shape
# Out:
# (7922, 4)

# %%
dataML.to_pickle("bareMLdataNoHindi.pkl")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.feature_extraction import DictVectorizer
from sklearn.decomposition import KernelPCA
from sklearn.manifold import TSNE
from IPython.display import display, HTML
import itertools

# %%
data = pd.read_csv("recipes_CLEANED.csv")

# %%
data = data.drop(['tags','category'], 1)

# %%
data['ingredients_strings'] = data['ingredients_strings'].astype(str)

# %%
data
# Out:
#                                            recipe_title               cuisine  \
# 0     Roasted Peppers And Mushroom Tortilla Pizza Re...               Mexican
# 1     Thakkali Gotsu Recipe ,  Thakkali Curry ,  Spi...  South Indian Recipes
# 2                  Spicy Grilled Pineapple Salsa Recipe               Mexican
# 3        Karwar Style Dali Thoy Recipe - Toor dal Curry             Karnataka
# 4       Rajma Kofta In Milk And Poppy Seed Gravy Recipe  North Indian Recipes
# ...                                                 ...                   ...
# 7967                   Zucchini and Carrot Pasta Recipe       Italian Recipes
# 7968  Hyderabadi Khatti Dal Recipe (Hyderabadi Tangy...            Hyderabadi
# 7969  Karwar Style Muga Ambat Recipe (Moong Sprouts ...             Karnataka
# 7970  Beetroot, Amla And Pudina Juice Recipe ,  Mint...                Indian
# 7971  Chettinad Cauliflower Pepper Fry Recipe - Chet...            Tamil Nadu
#
#                          diet  \
# 0                  Vegetarian
# 1                  Vegetarian
# 2                  Vegetarian
# 3     High Protein Vegetarian
# 4     High Protein Vegetarian
# ...                       ...
# 7967               Vegetarian
# 7968  High Protein Vegetarian
# 7969  High Protein Vegetarian
# 7970               Vegetarian
# 7971               Vegetarian
#
#                                        ingredients_list  \
# 0     ['tortillas', 'extra virgin olive oil', 'garli...
# 1     ['sesame (gingelly) oil', 'mustard seeds', 'cu...
# 2     ['extra virgin olive oil', 'pineapple', 'white...
# 3     ['arhar dal (split toor dal)', 'turmeric powde...
# 4     ['rajma (large kidney beans)', 'cashew nuts', ...
# ...                                                 ...
# 7967  ['spirali pasta', 'onions', 'tomato', 'green z...
# 7968  ['arhar dal (split toor dal)', 'tomato', 'turm...
# 7969  ['turmeric powder (haldi)', 'sugar', 'salt', '...
# 7970  ['beetroot', 'amla (nellikai/ gooseberry)', 'm...
# 7971  ['cauliflower (gobi)', 'pearl onions (sambar o...
#
#                                     ingredients_strings
# 0     ['tortillas', 'extra virgin olive oil', 'garli...
# 1     ['sesame (gingelly) oil', 'mustard seeds', 'cu...
# 2     ['extra virgin olive oil', 'pineapple', 'white...
# 3     ['arhar dal (split toor dal)', 'turmeric powde...
# 4     ['rajma (large kidney beans)', 'cashew nuts', ...
# ...                                                 ...
# 7967  ['spirali pasta', 'onions', 'tomato', 'green z...
# 7968  ['arhar dal (split toor dal)', 'tomato', 'turm...
# 7969  ['turmeric powder (haldi)', 'sugar', 'salt', '...
# 7970  ['beetroot', 'amla (nellikai/ gooseberry)', 'm...
# 7971  ['cauliflower (gobi)', 'pearl onions (sambar o...
#
# [7972 rows x 5 columns]

# %%
dataML['recipe_title'] = data['recipe_title']
dataML
# Out:
#                    cuisine                                   ingredients_list  \
# 0                  Mexican  [tortillas, extra virgin olive oil, garlic, mo...
# 1     South Indian Recipes  [sesame (gingelly) oil, mustard seeds, curry l...
# 2                  Mexican  [extra virgin olive oil, pineapple, white onio...
# 3                Karnataka  [arhar dal (split toor dal), turmeric powder (...
# 4     North Indian Recipes  [rajma (large kidney beans), cashew nuts, sult...
# ...                    ...                                                ...
# 7967       Italian Recipes  [spirali pasta, onions, tomato, green zucchini...
# 7968            Hyderabadi  [arhar dal (split toor dal), tomato, turmeric ...
# 7969             Karnataka  [turmeric powder (haldi), sugar, salt, fresh c...
# 7970                Indian  [beetroot, amla (nellikai/ gooseberry), mint l...
# 7971            Tamil Nadu  [cauliflower (gobi), pearl onions (sambar onio...
#
#                                   seperated_ingredients  \
# 0     tortillas,extra virgin olive oil,garlic,mozzar...
# 1     sesame gingelly oil,mustard seeds,curry leaves...
# 2     extra virgin olive oil,pineapple,white onion,r...
# 3     arhar dal split toor dal,turmeric powder haldi...
# 4     rajma large kidney beans,cashew nuts,sultana r...
# ...                                                 ...
# 7967  spirali pasta,onions,tomato,green zucchini,car...
# 7968  arhar dal split toor dal,tomato,turmeric powde...
# 7969  turmeric powder haldi,sugar,salt,fresh coconut...
# 7970  beetroot,amla nellikai/ gooseberry,mint leaves...
# 7971  cauliflower gobi,pearl onions sambar onions,ga...
#
#                                             ingredients  \
# 0     tortillas extra virgin olive oil garlic mozzar...
# 1     sesame gingelly oil mustard seeds curry leaves...
# 2     extra virgin olive oil pineapple white onion r...
# 3     arhar dal split toor dal turmeric powder haldi...
# 4     rajma large kidney beans cashew nuts sultana r...
# ...                                                 ...
# 7967  spirali pasta onions tomato green zucchini car...
# 7968  arhar dal split toor dal tomato turmeric powde...
# 7969  turmeric powder haldi sugar salt fresh coconut...
# 7970  beetroot amla nellikai/ gooseberry mint leaves...
# 7971  cauliflower gobi pearl onions sambar onions ga...
#
#                                            recipe_title
# 0     Roasted Peppers And Mushroom Tortilla Pizza Re...
# 1     Thakkali Gotsu Recipe ,  Thakkali Curry ,  Spi...
# 2                  Spicy Grilled Pineapple Salsa Recipe
# 3        Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4       Rajma Kofta In Milk And Poppy Seed Gravy Recipe
# ...                                                 ...
# 7967                   Zucchini and Carrot Pasta Recipe
# 7968  Hyderabadi Khatti Dal Recipe (Hyderabadi Tangy...
# 7969  Karwar Style Muga Ambat Recipe (Moong Sprouts ...
# 7970  Beetroot, Amla And Pudina Juice Recipe ,  Mint...
# 7971  Chettinad Cauliflower Pepper Fry Recipe - Chet...
#
# [7922 rows x 5 columns]

# %%
dataML
# Out:
#                    cuisine                              seperated_ingredients  \
# 0                  Mexican  tortillas,extra virgin olive oil,garlic,mozzar...
# 1     South Indian Recipes  sesame gingelly oil,mustard seeds,curry leaves...
# 2                  Mexican  extra virgin olive oil,pineapple,white onion,r...
# 3                Karnataka  arhar dal split toor dal,turmeric powder haldi...
# 4     North Indian Recipes  rajma large kidney beans,cashew nuts,sultana r...
# ...                    ...                                                ...
# 7967       Italian Recipes  spirali pasta,onions,tomato,green zucchini,car...
# 7968            Hyderabadi  arhar dal split toor dal,tomato,turmeric powde...
# 7969             Karnataka  turmeric powder haldi,sugar,salt,fresh coconut...
# 7970                Indian  beetroot,amla nellikai/ gooseberry,mint leaves...
# 7971            Tamil Nadu  cauliflower gobi,pearl onions sambar onions,ga...
#
#                                             ingredients  \
# 0     tortillas extra virgin olive oil garlic mozzar...
# 1     sesame gingelly oil mustard seeds curry leaves...
# 2     extra virgin olive oil pineapple white onion r...
# 3     arhar dal split toor dal turmeric powder haldi...
# 4     rajma large kidney beans cashew nuts sultana r...
# ...                                                 ...
# 7967  spirali pasta onions tomato green zucchini car...
# 7968  arhar dal split toor dal tomato turmeric powde...
# 7969  turmeric powder haldi sugar salt fresh coconut...
# 7970  beetroot amla nellikai/ gooseberry mint leaves...
# 7971  cauliflower gobi pearl onions sambar onions ga...
#
#                                            recipe_title
# 0     Roasted Peppers And Mushroom Tortilla Pizza Re...
# 1     Thakkali Gotsu Recipe ,  Thakkali Curry ,  Spi...
# 2                  Spicy Grilled Pineapple Salsa Recipe
# 3        Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4       Rajma Kofta In Milk And Poppy Seed Gravy Recipe
# ...                                                 ...
# 7967                   Zucchini and Carrot Pasta Recipe
# 7968  Hyderabadi Khatti Dal Recipe (Hyderabadi Tangy...
# 7969  Karwar Style Muga Ambat Recipe (Moong Sprouts ...
# 7970  Beetroot, Amla And Pudina Juice Recipe ,  Mint...
# 7971  Chettinad Cauliflower Pepper Fry Recipe - Chet...
#
# [7922 rows x 4 columns]

# %%
def convert_to_dict(lst):
    d = {} #empty dict
    for ingre in lst:
        d[ingre] = 1
    return d

# %%
dataML["bagofwords"] = dataML.seperated_ingredients.str.split(",").apply(convert_to_dict)
print(dataML.bagofwords)
# Out:
# 0       {'tortillas': 1, 'extra virgin olive oil': 1, ...
# 1       {'sesame gingelly oil': 1, 'mustard seeds': 1,...
# 2       {'extra virgin olive oil': 1, 'pineapple': 1, ...
# 3       {'arhar dal split toor dal': 1, 'turmeric powd...
# 4       {'rajma large kidney beans': 1, 'cashew nuts':...
#                               ...
# 7967    {'spirali pasta': 1, 'onions': 1, 'tomato': 1,...
# 7968    {'arhar dal split toor dal': 1, 'tomato': 1, '...
# 7969    {'turmeric powder haldi': 1, 'sugar': 1, 'salt...
# 7970    {'beetroot': 1, 'amla nellikai/ gooseberry': 1...
# 7971    {'cauliflower gobi': 1, 'pearl onions sambar o...
# Name: bagofwords, Length: 7922, dtype: object

# %%
#one hot encoding
vector_dict = DictVectorizer(sparse = False)
X = vector_dict.fit_transform(dataML["bagofwords"].tolist())
y = dataML.cuisine.astype("category").cat.codes

# %%
ing_arr = np.zeros((X.shape[1], X.shape[1]))
ing_arr.shape
# Out:
# (1783, 1783)

# %%
#trying 10 cuisines for clustering

dish_name_list = dataML.cuisine.astype("category").cat.categories

dish_subset = ['Indian','Continental','North Indian Recipes','South Indian Recipes','Italian Recipes','Karnataka','Bengali Recipes','Kerala Recipes','Mexican','Tamil Nadu']

subset = dataML.cuisine.apply(lambda x :x in dish_subset)
x_subset, y_subset = X[subset], y[subset]

# %%
#PCA

kpca = KernelPCA(n_components=2, kernel='cosine', n_jobs=2)

x_pca = kpca.fit_transform(x_subset)
x_pca.shape
# Out:
# (5612, 2)

# %%
# Plotting the clusters
plot_pca = pd.DataFrame(data = x_pca[:,:2], columns = ["PC1","PC2"])
plot_pca["Dish"] = dish_name_list[y_subset].tolist()
sns.lmplot("PC1", "PC2", data = plot_pca, palette = "Paired",height=15, aspect=1,legend=True, hue = "Dish", fit_reg = False)
# Out:
# /Users/samkatterfield/opt/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
