# %%
import pandas as pd

df = pd.read_csv('food_recipes_no_commas.csv')

# %%
df['ingredients'][3]
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7972 entries, 0 to 8008
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   recipe_title  7972 non-null   object
#  1   url           7972 non-null   object
#  2   vote_count    7972 non-null   int64
#  3   rating        7972 non-null   float64
#  4   cuisine       7922 non-null   object
#  5   course        7836 non-null   object
#  6   diet          7840 non-null   object
#  7   prep_time     7972 non-null   float64
#  8   cook_time     7972 non-null   float64
#  9   ingredients   7972 non-null   object
#  10  author        7972 non-null   object
#  11  tags          7894 non-null   object
#  12  category      7972 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 871.9+ KB

# %%
print(df.columns)
# Out:
# Index(['recipe_title', 'url', 'vote_count', 'rating', 'cuisine', 'course',
#        'diet', 'prep_time', 'cook_time', 'ingredients', 'author', 'tags',
#        'category'],
#       dtype='object')

# %%
df.head(2)
# Out:
#                                                             recipe_title  \
# 0                     Roasted Peppers And Mushroom Tortilla Pizza Recipe
# 1  Thakkali Gotsu Recipe ,  Thakkali Curry ,  Spicy & Tangy Tomato Gravy
#
#                                                                                   url  \
# 0  https://www.archanaskitchen.com/roasted-peppers-and-mushroom-tortilla-pizza-recipe
# 1        https://www.archanaskitchen.com/tomato-gotsu-recipe-spicy-tangy-tomato-gravy
#
#    vote_count    rating               cuisine  course        diet  prep_time  \
# 0         434  4.958525               Mexican  Dinner  Vegetarian       15.0
# 1        3423  4.932223  South Indian Recipes   Lunch  Vegetarian       10.0
#
#    cook_time  \
# 0       15.0
# 1       20.0
#
#                                                                                                                                              ingredients  \
# 0  [tortillas, extra virgin olive oil, garlic, mozzarella cheese, red yellow or green bell pepper (capsicum), onions, kalmatta olives, button mushrooms]
# 1   [sesame (gingelly) oil, mustard seeds, curry leaves, garlic, pearl onions (sambar onions), tomato, tamarind, turmeric powder (haldi), salt, jaggery]
#
#              author  \
# 0  Divya Shivaraman
# 1     Archana Doshi
#
#                                                                                                              tags  \
# 0  Party Food Recipes, Tea Party Recipes, Mushroom Recipes, Fusion Recipes, Tortilla Recipe, Bell Peppers Recipes
# 1                                Vegetarian Recipes, Tomato Recipes, South Indian Recipes, Breakfast Recipe Ideas
#
#                category
# 0         Pizza Recipes
# 1  Indian Curry Recipes

# %%
# backup to a pickle

df.to_pickle('backup.pkl')

# %%
df['prep_time'][441]
# Out:
# nan

# %%
df.drop(df.columns[16], axis=1, inplace=True)

# %%
# potatoes, chilllies, mustard seeds, tomatoes, peppers - cleaning!

# %%
# drop description and instructions as they're huge and we have the URL anyway
df = df.drop('description', axis=1)

# %%
df = df.drop('ingredients_list', axis=1)

# %%
df = df.drop('instructions', axis=1)

# %%
df = df.drop('record_health', axis=1)

# %%
#drop ingredients as we now have it as a list
df = df.drop('ingredients', axis=1)

# %%
#remove non-numerical characters from prep time & cook time

df['prep_time'].replace(r'[a-zA-Z%]', '', regex=True, inplace=True)

# %%
df['cook_time'].replace(r'[a-zA-Z%]', '', regex=True, inplace=True)

# %%
df['prep_time'] = pd.to_numeric(df['prep_time'])

# %%
df['cook_time'] = pd.to_numeric(df['cook_time'])

# %%
df['ingredients'][0].split(",")
# Out:
# ['Tortillas',
#  ' Extra Virgin Olive Oil',
#  ' Garlic',
#  ' Mozzarella cheese',
#  ' Red Yellow or Green Bell Pepper (Capsicum)',
#  ' Onions',
#  ' Kalmatta olives',
#  ' Button mushrooms']

# %%
df['ingredients'] = ingredients_list

# %%
ingredients_list = []

for ing in df['ingredients']:
    ingredients_list.append([a.strip() for a in ing.split(",")])

# %%
ingredients_list
# Out:
# [['Tortillas',
#   'Extra Virgin Olive Oil',
#   'Garlic',
#   'Mozzarella cheese',
#   'Red Yellow or Green Bell Pepper (Capsicum)',
#   'Onions',
#   'Kalmatta olives',
#   'Button mushrooms'],
#  ['Sesame (Gingelly) Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Garlic',
#   'Pearl onions (Sambar Onions)',
#   'Tomatoes',
#   'Tamarind',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Jaggery'],
#  ['Extra Virgin Olive Oil',
#   'Pineapple',
#   'White onion',
#   'Red Yellow and Green Bell Peppers (Capsicum)',
#   'Pickled Jalapenos',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)',
#   'Salt',
#   'Lemon juice',
#   'Paprika powder'],
#  ['Arhar dal (Split Toor Dal)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Dry Red Chillies',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)',
#   'Curry leaves',
#   'Coriander (Dhania) Leaves'],
#  ['Rajma (Large Kidney Beans)',
#   'Cashew nuts',
#   'Sultana Raisins',
#   'Asafoetida (hing)',
#   'Cumin seeds (Jeera)',
#   'Gram flour (besan)',
#   'Red Chilli powder',
#   'Coriander (Dhania) Leaves',
#   'Poppy seeds',
#   'Fresh cream',
#   'Milk',
#   'Water',
#   'Salt',
#   'Saffron strands'],
#  ['Barnyard Millet',
#   'Oil',
#   'Bay leaf (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Star anise',
#   'Curry leaves',
#   'Green Chillies',
#   'Garlic',
#   'Ginger',
#   'Onions',
#   'Button mushrooms',
#   'Salt',
#   'Coriander (Dhania) Powder',
#   'Black pepper powder',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)'],
#  ['Coriander (Dhania) Leaves',
#   'Tahini',
#   'Lemon juice',
#   'Extra Virgin Olive Oil',
#   'Honey',
#   'Ginger',
#   'Salt'],
#  ['Avarekalu / Lilva Beans',
#   'Rice',
#   'Turmeric powder (Haldi)',
#   'Asafoetida (hing)',
#   'Green Chillies',
#   'Curry leaves',
#   'Mustard seeds (Rai/ Kadugu)',
#   'White Urad Dal (Split)',
#   'Lemon juice',
#   'Coriander (Dhania) Leaves',
#   'Onion',
#   'Salt'],
#  ['Whole Wheat Flour',
#   'Sooji (Semolina/ Rava)',
#   'Ajwain (Carom seeds)',
#   'Salt',
#   'Extra Virgin Olive Oil',
#   'Carrot (Gajjar)',
#   'Green Bell Pepper (Capsicum)',
#   'Cabbage (Patta Gobi/ Muttaikose)',
#   'Ginger',
#   'Garlic',
#   'Green Chilli',
#   'Spring Onion Greens',
#   'Salt',
#   'Black pepper powder'],
#  ['Butter (Unsalted)',
#   'Caster Sugar',
#   'Whole Eggs',
#   'All Purpose Flour (Maida)',
#   'Salt',
#   'Baking powder',
#   'Canned Pineapple (Preserved & Tinned)',
#   'Canned Cherries'],
#  ['Cashew nuts',
#   'Onions',
#   'Ginger',
#   'Garlic',
#   'Green Chilli',
#   'Green peas (Matar)',
#   'Butter (Salted)',
#   'Bay leaf (tej patta)',
#   'Turmeric powder (Haldi)',
#   'Kashmiri Red Chilli Powder',
#   'Coriander Powder (Dhania)',
#   'Salt',
#   'Tomatoes',
#   'Sugar',
#   'Fresh cream',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Coriander (Dhania) Leaves'],
#  ['Butter (Salted)',
#   'Garlic',
#   'Green Chillies',
#   'Onion',
#   'Green capsicum',
#   'Cooked rice',
#   'Sweet corn',
#   'All Purpose Flour (Maida)',
#   'Mint Leaves (Pudina)',
#   'Mozzarella cheese',
#   'Black pepper powder',
#   'Oil',
#   'Salt',
#   'All Purpose Flour (Maida)',
#   'Water',
#   'Whole Wheat Bread crumbs',
#   'Mixed Herbs (Dried)',
#   'Red Chilli flakes'],
#  ['Shrimps',
#   'Butter (Salted)',
#   'Orange color',
#   'Lemon juice',
#   'Honey',
#   'Black pepper powder',
#   'Garlic',
#   'Ginger',
#   'Fresh Thyme leaves'],
#  ['Oil',
#   'Kokum (Malabar Tamarind)',
#   'Green Chillies',
#   'Jaggery',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Fresh coconut',
#   'Onion',
#   'Garlic',
#   'Cumin seeds (Jeera)',
#   'Coriander (Dhania) Seeds',
#   'Dry Red Chillies',
#   'Turmeric powder (Haldi)'],
#  ['Ripe Bananas',
#   'Sesame seeds (Til seeds)',
#   'Sesame seeds (Til seeds)',
#   'Oil',
#   'Chilled water',
#   'All Purpose Flour (Maida)',
#   'Corn flour',
#   'Oil',
#   'Baking powder',
#   'Sugar',
#   'Water'],
#  ['Mango (Ripe)',
#   'Tomato',
#   'Onion',
#   'Rajma (Large Kidney Beans)',
#   'Pickled Jalapenos',
#   'Mint Leaves (Pudina)',
#   'Lemon juice',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Cumin powder (Jeera)',
#   'Red Chilli powder'],
#  ['Kaddu (Parangikai/ Pumpkin)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Fresh coconut',
#   'Cumin seeds (Jeera)',
#   'Green Chillies',
#   'Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Dry Red Chillies',
#   'Dry Red Chillies'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Gram flour (besan)',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Amchur (Dry Mango Powder)',
#   'Salt',
#   'Water',
#   'Oil',
#   'Cumin seeds (Jeera)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)',
#   'Green Chilli',
#   'Onions',
#   'Coriander (Dhania) Leaves'],
#  ['Green Moong Dal (Whole)',
#   'Yellow Moong Dal (Split)',
#   'Pearl onions (Sambar Onions)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Dry Red Chilli',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Coconut Oil',
#   'Fresh coconut',
#   'Green Chilli',
#   'Cumin seeds (Jeera)'],
#  ['Raw Banana',
#   'Green peas (Matar)',
#   'Cumin seeds (Jeera)',
#   'Green Chilli',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Amchur (Dry Mango Powder)',
#   'Lemon',
#   'Oil',
#   'Coriander (Dhania) Leaves',
#   'Salt'],
#  ['Extra Virgin Olive Oil',
#   'Chicken breasts',
#   'Spaghetti Pasta',
#   'Basil leaves',
#   'Walnuts',
#   'Parmesan cheese',
#   'Garlic',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Whole Black Pepper Corns',
#   'Lemon juice'],
#  ['Tomatoes',
#   'Onions',
#   'Khoya (Mawa)',
#   'Sesame seeds (Til seeds)',
#   'Raw Peanuts (Moongphali)',
#   'Red Chilli powder',
#   'Kashmiri Red Chilli Powder',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Garlic',
#   'Oil',
#   'Salt',
#   'Whole Eggs'],
#  ['Brinjal (Baingan / Eggplant)',
#   'Green Bell Pepper (Capsicum)',
#   'Carrot (Gajjar)',
#   'Onion',
#   'Green Chillies',
#   'Garlic',
#   'Basil leaves',
#   'Parsley leaves',
#   'Extra Virgin Olive Oil',
#   'Black pepper powder',
#   'Salt',
#   'Dried oregano',
#   'Mozzarella cheese'],
#  ['Black Eyed Beans (Lobia)',
#   'Rice',
#   'Carrots (Gajjar)',
#   'Green beans (French Beans)',
#   'Turmeric powder (Haldi)',
#   'Tomatoes',
#   'Bay leaves (tej patta)',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cumin seeds (Jeera)',
#   'Green Chillies',
#   'Mint Leaves (Pudina)',
#   'Salt'],
#  ['Small Brinjal (Baingan / Eggplant)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Jaggery',
#   'Tomatoes',
#   'Salt',
#   'Black sesame seeds',
#   'Raw Peanuts (Moongphali)',
#   'Cumin seeds (Jeera)',
#   'Ginger',
#   'Garlic',
#   'Onions',
#   'Green Chillies',
#   'Gingelly oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)',
#   'Curry leaves'],
#  ['Raw Banana',
#   'Coconut Oil',
#   'Salt',
#   'Garlic',
#   'Ginger',
#   'Green Chillies',
#   'Curry leaves',
#   'Black pepper corns',
#   'Tamarind'],
#  ['Kabuli Chana (White Chickpeas)',
#   'Gram flour (besan)',
#   'Garlic',
#   'Onion',
#   'Cumin powder (Jeera)',
#   'Coriander (Dhania) Powder',
#   'Black pepper powder',
#   'Red Chilli powder',
#   'Salt',
#   'Parsley leaves',
#   'Oil'],
#  ['Ragi Flour (Finger Millet/ Nagli)',
#   'Whole Wheat Flour',
#   'Green Chillies',
#   'Ginger',
#   'Drumstick Leaves (Moringa/Murungai Keerai)',
#   'Black pepper powder',
#   'Salt'],
#  ['Chana dal (Bengal Gram Dal)',
#   'Dry Red Chillies',
#   'Fennel seeds (Saunf)',
#   'Salt',
#   'Oil',
#   'Onion',
#   'Tomato',
#   'Green Chillies',
#   'Garlic',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Cinnamon Stick (Dalchini)',
#   'Bay leaf (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Fennel seeds (Saunf)',
#   'Curry leaves',
#   'Coriander (Dhania) Leaves',
#   'Oil',
#   'Salt',
#   'Fresh coconut',
#   'Poppy seeds',
#   'Fennel seeds (Saunf)',
#   'Cashew nuts',
#   'Roasted Gram Dal (Pottukadalai)'],
#  ['Onions',
#   'Tomato',
#   'Green Chillies',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Dry Red Chillies',
#   'Asafoetida (hing)',
#   'Salt',
#   'Oil',
#   'Mint Leaves (Pudina)'],
#  ['Brinjal (Baingan / Eggplant)',
#   'Potato (Aloo)',
#   'Onion',
#   'Fresh coconut',
#   'Turmeric powder (Haldi)',
#   'Tamarind',
#   'Garlic',
#   'Ginger',
#   'Jaggery',
#   'Gram flour (besan)',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Whole Black Peppercorns',
#   'Byadagi Dried Chillies',
#   'Oil',
#   'Onion',
#   'Fresh coconut',
#   'Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)',
#   'Curry leaves'],
#  ['All Purpose Flour (Maida)',
#   'Caster Sugar',
#   'Cinnamon Powder (Dalchini)',
#   'Baking powder',
#   'Butter (Unsalted)',
#   'Sultana Raisins',
#   'Whole Egg'],
#  ['Makki Ka Atta (Yellow Corn Meal Flour)',
#   'Milk',
#   'Water',
#   'Whole Black Peppercorns',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Red Yellow and Green Bell Peppers (Capsicum)',
#   'Button mushrooms',
#   'Mixed Herbs (Dried)',
#   'Onions',
#   'Cheese'],
#  ['All Purpose Flour (Maida)',
#   'Buttermilk',
#   'Salt',
#   'Butter (Unsalted)',
#   'Lukewarm Water',
#   'Caster Sugar',
#   'Butter (Unsalted)',
#   'Cinnamon Powder (Dalchini)',
#   'Caster Sugar',
#   'Milk',
#   'Icing Sugar',
#   'Vanilla Extract'],
#  ['Sabudana (Tapioca Pearls)',
#   'Shallots',
#   'Mixed vegetables',
#   'Coriander (Dhania) Leaves',
#   'Coriander (Dhania) Leaves',
#   'Black pepper powder',
#   'Garlic',
#   'Oil',
#   'Water',
#   'Garlic',
#   'Oil'],
#  ['Fresh coconut',
#   'Whole Black Peppercorns',
#   'Dry Red Chillies',
#   'Coriander (Dhania) Seeds',
#   'Turmeric powder (Haldi)',
#   'Tamarind',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Asafoetida (hing)',
#   'Jaggery',
#   'Oil'],
#  ['Chipotle peppers',
#   'Onion',
#   'Garlic',
#   'Tomatoes',
#   'Raw Peanuts (Moongphali)',
#   'Star anise',
#   'Cinnamon Stick (Dalchini)',
#   'Cloves (Laung)',
#   'Dark chocolate',
#   'Dried oregano',
#   'Black pepper powder',
#   'Sultana Raisins',
#   'Makki Ka Atta (Yellow Corn Meal Flour)',
#   'Butter (Salted)',
#   'Chicken stock',
#   'Salt'],
#  ['Whole Eggs',
#   'Green capsicum',
#   'Onion',
#   'Britannia Cheese Block',
#   'Whole Eggs',
#   'Salt',
#   'Black pepper powder',
#   'Milk',
#   'Avocado',
#   'Onion',
#   'Tomato',
#   'Green Chillies',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Lemon juice',
#   'Sugar'],
#  ['Tofu',
#   'Sesame (Gingelly) Oil',
#   'Brown Sugar (Demerara Sugar)',
#   'Dried basil leaves',
#   'Garlic powder',
#   'Cayenne Pepper',
#   'Coconut milk',
#   'Ginger',
#   'Garlic',
#   'Peanut Butter',
#   'Turmeric powder (Haldi)',
#   'Lemon juice',
#   'Brown Sugar (Demerara Sugar)',
#   'Iceberg lettuce',
#   'Roasted Peanuts (Moongphali)'],
#  ['Mutton',
#   'Salt',
#   'Lemon juice',
#   'Turmeric powder (Haldi)',
#   'Onions',
#   'Garlic',
#   'Ginger',
#   'Cloves (Laung)',
#   'Bay leaf (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cinnamon Stick (Dalchini)',
#   'Fennel seeds (Saunf)',
#   'Green Chillies',
#   'Salt',
#   'Tomatoes',
#   'Red Chilli powder',
#   'Cumin powder (Jeera)',
#   'Coriander (Dhania) Powder',
#   'Meat masala',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Coriander (Dhania) Leaves'],
#  ['Avarekalu / Lilva Beans',
#   'Tomatoes',
#   'Fresh coconut',
#   'Jaggery',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Coriander (Dhania) Seeds',
#   'Dry Red Chillies',
#   'Byadagi Dried Chillies',
#   'Cumin seeds (Jeera)',
#   'Whole Black Peppercorns',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves'],
#  ['French Loaf',
#   'Butter (Salted)',
#   'Extra Virgin Olive Oil',
#   'Red Yellow and Green Bell Peppers (Capsicum)',
#   'Sweet corn',
#   'Pickled Jalapenos',
#   'Basil leaves',
#   'Salt',
#   'Mozzarella cheese',
#   'Mixed Herbs (Dried)',
#   'Red Chilli flakes',
#   'Garlic bread spice mix'],
#  ['Cashew nuts',
#   'Tomato',
#   'Green Bell Pepper (Capsicum)',
#   'Turmeric powder (Haldi)',
#   'Oil',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Fresh coconut',
#   'Onion',
#   'Garlic',
#   'Coriander (Dhania) Seeds',
#   'Byadagi Dried Chillies',
#   'Whole Black Peppercorns',
#   'Cumin seeds (Jeera)',
#   'Cloves (Laung)',
#   'Tamarind'],
#  ['Methi Seeds (Fenugreek Seeds)',
#   'Coriander (Dhania) Seeds',
#   'Fennel seeds (Saunf)',
#   'Dry Red Chillies',
#   'Fresh coconut',
#   'Pearl onions (Sambar Onions)',
#   'Garlic',
#   'Tomatoes',
#   'Potatoes (Aloo)',
#   'Brinjal (Baingan / Eggplant)',
#   'Jaggery',
#   'Gingelly oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves'],
#  ['Rice',
#   'Yellow Moong Dal (Split)',
#   'Turmeric powder (Haldi)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cinnamon Stick (Dalchini)'],
#  ['Vellai Poosanikai (Ash gourd/White Pumpkin)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Oil',
#   'Dry Red Chillies',
#   'Fresh coconut',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Cumin seeds (Jeera)',
#   'Coriander (Dhania) Seeds',
#   'Sesame seeds (Til seeds)',
#   'Jaggery',
#   'Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Dry Red Chillies'],
#  ['Bajra Flour ( Pearl Millet)',
#   'Whole Wheat Flour',
#   'Methi Leaves (Fenugreek Leaves)',
#   'Garlic',
#   'Red Chilli powder',
#   'Sesame seeds (Til seeds)',
#   'Fennel seeds (Saunf)',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Amchur (Dry Mango Powder)',
#   'Oil',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Oil'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Oil',
#   'Ajwain (Carom seeds)',
#   'Curry leaves',
#   'Roasted Peanuts (Moongphali)',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Amchur (Dry Mango Powder)',
#   'Salt'],
#  ['Whole Egg',
#   'Mutton',
#   'Ginger',
#   'Garlic',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Kashmiri Red Chilli Powder',
#   'Corn flour',
#   'Mustard oil',
#   'Salt',
#   'Onion',
#   'Turmeric powder (Haldi)',
#   'Green Chilli Paste',
#   'Red Chilli powder',
#   'Garlic',
#   'Ginger',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Bay leaf (tej patta)',
#   'Dry Red Chilli',
#   'Salt',
#   'Oil'],
#  ['Tofu',
#   'Orange Zest (Rind)',
#   'Corn flour',
#   'Whole Black Peppercorns',
#   'Rice Vinegar',
#   'Brown Sugar (Demerara Sugar)',
#   'Fresh orange juice',
#   'Ginger',
#   'Sesame (Gingelly) Oil',
#   'Sesame seeds (Til seeds)',
#   'Salt'],
#  ['Cumin seeds (Jeera)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Coriander (Dhania) Seeds',
#   'Whole Black Peppercorns',
#   'Fennel seeds (Saunf)',
#   'Bay leaves (tej patta)',
#   'Mace (Javitri)',
#   'Nutmeg powder'],
#  ['Green Moong Dal (Whole)',
#   'Carrot (Gajjar)',
#   'Fresh coconut',
#   'Cucumber',
#   'Tomato',
#   'Green Chillies',
#   'Lemon',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Mustard seeds (Rai/ Kadugu)',
#   'White Urad Dal (Split)',
#   'Curry leaves',
#   'Coconut Oil'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Pearl onions (Sambar Onions)',
#   'Tomatoes',
#   'Tamarind',
#   'Curry leaves',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Jaggery',
#   'Gingelly oil',
#   'Salt'],
#  ['Ridge Gourd Skin (Turai/ Peerkangai)',
#   'White Urad Dal (Split)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Dry Red Chillies',
#   'Curry leaves',
#   'Tamarind',
#   'Salt',
#   'Gingelly oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'White Urad Dal (Split)',
#   'Dry Red Chillies',
#   'Curry leaves'],
#  ['Button mushrooms',
#   'Onion',
#   'Garlic',
#   'Ginger',
#   'Turmeric powder (Haldi)',
#   'Oil',
#   'Salt',
#   'Dry Red Chillies',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Whole Black Peppercorns',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)'],
#  ['Arhar dal (Split Toor Dal)',
#   'Chana dal (Bengal Gram Dal)',
#   'Masoor Dal (Whole)',
#   'White Urad Dal (Split)',
#   'Kashmiri Rajma',
#   'Kala Chana (Brown Chickpeas)',
#   'Cumin (Jeera) seeds',
#   'Onion',
#   'Ginger',
#   'Green Chillies',
#   'Cinnamon stick',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Bay leaves (tej patta)',
#   'Tomatoes',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Salt',
#   'Lemon',
#   'Coriander (Dhania) Leaves'],
#  ['Oil',
#   'Button mushrooms',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Onions',
#   'Ginger',
#   'Garlic',
#   'Coriander (Dhania) Leaves',
#   'Dry Red Chillies',
#   'Poppy seeds',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Whole Black Pepper Corns',
#   'Cumin seeds (Jeera)',
#   'Coriander (Dhania) Seeds',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Tamarind'],
#  ['Black Raisins',
#   'Prunes',
#   'Apricots',
#   'Dates',
#   'Dried Figs',
#   'Cranberries',
#   'Rum',
#   'Fresh orange juice',
#   'Fresh orange juice',
#   'Whole Wheat Flour',
#   'Baking powder',
#   'Baking soda',
#   'Oil',
#   'Brown Sugar (Demerara Sugar)',
#   'Cinnamon Powder (Dalchini)',
#   'Dry ginger powder',
#   'Vanilla Extract',
#   'Slivered Almonds (Badam)',
#   'Walnuts'],
#  ['Mini Pita Breads',
#   'Cauliflower (gobi)',
#   'Cumin seeds (Jeera)',
#   'Coriander (Dhania) Seeds',
#   'Fennel seeds (Saunf)',
#   'Badam (Almond)',
#   'Sunflower Oil',
#   'Salt',
#   'Avocado',
#   'Basil leaves',
#   'Garlic',
#   'Lemon juice',
#   'Milk',
#   'Salt',
#   'Green Chillies'],
#  ['Cabbage (Patta Gobi/ Muttaikose)',
#   'Carrots (Gajjar)',
#   'Green Bell Pepper (Capsicum)',
#   'Red onion',
#   'Green Chilli',
#   'Vinegar',
#   'Classic Mayonnaise (With Egg)',
#   'Black pepper powder'],
#  ['Colocasia root (Arbi)',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Amchur (Dry Mango Powder)',
#   'Coriander (Dhania) Powder',
#   'Asafoetida (hing)',
#   'Salt',
#   'Gingelly oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'White Urad Dal (Split)',
#   'Dry Red Chilli',
#   'Curry leaves'],
#  ['Mangalorean cucumber',
#   'Chana dal (Bengal Gram Dal)',
#   'Cumin seeds (Jeera)',
#   'Bay leaf (tej patta)',
#   'Ginger',
#   'Tomato',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Sugar',
#   'Coriander (Dhania) Leaves',
#   'Oil',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chillies',
#   'Salt'],
#  ['Pointed gourd (Parval)',
#   'Potatoes (Aloo)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Amchur (Dry Mango Powder)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Salt',
#   'Mustard oil'],
#  ['Mustard oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Bay leaves (tej patta)',
#   'Green Chillies',
#   'Potato (Aloo)',
#   'Kaddu (Parangikai/ Pumpkin)',
#   'Small Brinjal (Baingan / Eggplant)',
#   'Carrot (Gajjar)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sugar',
#   'Fresh coconut',
#   'Yellow Moong Dal (Split)',
#   'Chana dal (Bengal Gram Dal)',
#   'Ginger',
#   'Dry Red Chillies',
#   'Turmeric powder (Haldi)',
#   'Mustard oil'],
#  ['Potatoes (Aloo)', 'Garlic', 'Fresh Thyme leaves', 'Salt'],
#  ['Kabuli Chana (White Chickpeas)',
#   'Extra Virgin Olive Oil',
#   'Cinnamon Stick (Dalchini)',
#   'Garlic',
#   'Onions',
#   'Salt',
#   'Whole Black Pepper Corns',
#   'Turmeric powder (Haldi)',
#   'Paprika powder',
#   'Cumin powder (Jeera)',
#   'Tomato',
#   'Apricots',
#   'Lemon juice',
#   'Mint Leaves (Pudina)',
#   'Coriander (Dhania) Leaves',
#   'Whole Almonds (Badam)'],
#  ['Whole Wheat Flour', 'Black Urad Dal (Whole)', 'Water', 'Oil', 'Salt'],
#  ['Potatoes (Aloo)',
#   'Green Chillies',
#   'Ginger',
#   'Curry leaves',
#   'Mustard seeds (Rai/ Kadugu)',
#   'White Urad Dal (Split)',
#   'Turmeric powder (Haldi)',
#   'Oil',
#   'Coriander (Dhania) Leaves'],
#  ['Mustard oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Bay leaves (tej patta)',
#   'Green Chillies',
#   'Potato (Aloo)',
#   'Brinjal (Baingan / Eggplant)',
#   'Carrot (Gajjar)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sugar',
#   'Yellow Moong Dal (Split)',
#   'Chana dal (Bengal Gram Dal)',
#   'Dry Red Chillies',
#   'Turmeric powder (Haldi)',
#   'Mustard oil'],
#  ['Chicken',
#   'Onion',
#   'Tomato',
#   'Green Chillies',
#   'Bay leaves (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Whole Black Peppercorns',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Basmati rice',
#   'Water',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)',
#   'Whole Black Peppercorns',
#   'Nutmeg powder',
#   'Dry ginger powder',
#   'Bay leaves (tej patta)'],
#  ['Vivatta Maida',
#   'Salt',
#   'Water',
#   'Oil',
#   'Green Moong Dal (Whole)',
#   'Cumin seeds (Jeera)',
#   'Fennel seeds (Saunf)',
#   'Sesame seeds (Til seeds)',
#   'Sugar',
#   'Asafoetida (hing)',
#   'Amchur (Dry Mango Powder)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Green Chillies',
#   'Ginger',
#   'Salt'],
#  ['Pink Masoor Dal (Split)',
#   'Garlic',
#   'Ginger',
#   'Green Chillies',
#   'Onion',
#   'Tomato',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Salt to taste',
#   'Coriander (Dhania) Leaves'],
#  ['All Purpose Flour (Maida)',
#   'Milk',
#   'Vanilla Extract',
#   'Whole Eggs',
#   'Caster Sugar',
#   'Salt',
#   'Butter (unsalted)'],
#  ['Mooli/ Mullangi (Radish)',
#   'Arhar dal (Split Toor Dal)',
#   'Onion',
#   'Fresh coconut',
#   'Green Chilli',
#   'Dry Red Chillies',
#   'Coriander (Dhania) Seeds',
#   'Tamarind',
#   'Jaggery',
#   'Salt'],
#  ['Pav buns',
#   'Butter (Salted)',
#   'Onion',
#   'Sev',
#   'Fresh Pomegranate Fruit Kernels',
#   'Coriander (Dhania) Leaves',
#   'Potatoes (Aloo)',
#   'Fennel seeds (Saunf)',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Sesame seeds (Til seeds)',
#   'Dry Red Chillies',
#   'Whole Black Pepper Corns',
#   'Cinnamon Stick (Dalchini)',
#   'Brown cardamom (Badi Elaichi)',
#   'Star anise',
#   'Dessicated Coconut',
#   'Kashmiri Red Chilli Powder',
#   'Sugar',
#   'Amchur (Dry Mango Powder)',
#   'Salt'],
#  ['Sunflower Oil',
#   'Cumin seeds (Jeera)',
#   'Bay leaves (tej patta)',
#   'Onion',
#   'Ginger',
#   'Garlic',
#   'Green Chilli',
#   'Tomatoes',
#   'Cashew nuts',
#   'Kashmiri Red Chilli Powder',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Salt',
#   'Carrots (Gajjar)',
#   'Sweet corn',
#   'Green peas (Matar)',
#   'Green beans (French Beans)',
#   'Green Bell Pepper (Capsicum)',
#   'Cauliflower (gobi)',
#   'Button mushrooms',
#   'Water',
#   'Fresh cream',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)',
#   'Lemon'],
#  ['Button mushrooms',
#   'Spinach',
#   'Onion',
#   'Garlic',
#   'Extra Virgin Olive Oil',
#   'Whole Wheat Bread crumbs',
#   'Dried oregano',
#   'Red Bell pepper (Capsicum)',
#   'Parmesan cheese',
#   'Mozzarella cheese',
#   'Salt'],
#  ['Elephant yam (Suran/Senai/Ratalu)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Raw Peanuts (Moongphali)',
#   'Sesame (Gingelly) Oil',
#   'Mustard seeds',
#   'White Urad Dal (Split)',
#   'Curry leaves',
#   'Green Chillies',
#   'Salt',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder'],
#  ['Pani Puris',
#   'Potato (Aloo)',
#   'Salt',
#   'Cumin powder (Jeera)',
#   'Chaat Masala Powder',
#   'Red Chilli powder',
#   'Mango (Raw)',
#   'Mint Leaves (Pudina)',
#   'Cumin powder (Jeera)',
#   'Black Salt (Kala Namak)',
#   'Black pepper powder',
#   'Sugar'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Oil',
#   'Gram flour (besan)',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Salt',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chillies',
#   'Cinnamon Stick (Dalchini)'],
#  ['Potatoes (Aloo)',
#   'Onion',
#   'Green Chillies',
#   'Ginger',
#   'Garlic',
#   'Cashew nuts',
#   'Gram flour (besan)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Sesame (Gingelly) Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Chana dal (Bengal Gram Dal)',
#   'Curry leaves'],
#  ['Bimbla (Bilimbi)',
#   'Fresh coconut',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Jaggery',
#   'Oil',
#   'Methi Seeds (Fenugreek Seeds)',
#   'White Urad Dal (Split)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves',
#   'Asafoetida (hing)',
#   'Salt'],
#  ['Papaya',
#   'Onion',
#   'Parsley leaves',
#   'Lemon',
#   'Feta Cheese',
#   'Roasted Peanuts (Moongphali)',
#   'Salt and Pepper'],
#  ['Tindora (Dondakaya/ Kovakkai)',
#   'Cashew nuts',
#   'Fresh coconut',
#   'Sugar',
#   'Salt',
#   'Coconut Oil',
#   'White Urad Dal (Split)',
#   'Mustard seeds',
#   'Dry Red Chillies',
#   'Turmeric powder (Haldi)',
#   'Curry leaves'],
#  ['Tortillas',
#   'Mozzarella cheese',
#   'Chicken breasts',
#   'Green Bell Pepper (Capsicum)',
#   'Spring Onion (Bulb & Greens)',
#   'Garlic',
#   'Ginger',
#   'Green Chillies',
#   'Corn flour',
#   'Tomato Ketchup',
#   'Sunflower Oil',
#   'Salt'],
#  ['Mango (Raw)',
#   'Kaddu (Parangikai/ Pumpkin)',
#   'Green Chillies',
#   'Ginger',
#   'Dry Red Chillies',
#   'Cumin seeds (Jeera)',
#   'Fennel seeds (Saunf)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Whole Black Peppercorns',
#   'Coriander (Dhania) Seeds',
#   'Fresh coconut',
#   'Oil'],
#  ['Gram flour (besan)',
#   'Whole Wheat Flour',
#   'Rice flour',
#   'Cucumber',
#   'Turmeric powder (Haldi)',
#   'Cumin powder (Jeera)',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Green Chillies',
#   'Coriander (Dhania) Leaves',
#   'Garlic',
#   'Salt'],
#  ['Butter (Unsalted)',
#   'Cocoa Powder',
#   'Sugar',
#   'All Purpose Flour (Maida)',
#   'Salt',
#   'Milk',
#   'Chocolate chips',
#   'Vanilla Extract'],
#  ['Carrot (Gajjar)',
#   'Bottle gourd (lauki)',
#   'Potatoes (Aloo)',
#   'Green peas (Matar)',
#   'Green capsicum',
#   'Gram flour (besan)',
#   'Green Chilli',
#   'Cumin powder (Jeera)',
#   'Salt',
#   'Amchur (Dry Mango Powder)',
#   'Cashew nuts',
#   'Cumin (Jeera) seeds',
#   'Sunflower Oil',
#   'Ginger',
#   'Garlic',
#   'Onions',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Jaggery',
#   'Cloves (Laung)',
#   'Tomatoes',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Salt'],
#  ['Whole Eggs',
#   'Coconut Oil',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Green Chilli',
#   'Pearl onions (Sambar Onions)',
#   'Salt',
#   'Turmeric powder (Haldi)',
#   'Black pepper powder',
#   'Coriander (Dhania) Leaves'],
#  ['Red Chilli flakes',
#   'Brown Sugar (Demerara Sugar)',
#   'Ginger',
#   'Sesame seeds (Til seeds)',
#   'Star anise',
#   'Garlic',
#   'Cooking oil'],
#  ['Bathua leaves',
#   'Green Chillies',
#   'Ginger',
#   'Black Salt (Kala Namak)',
#   'Cumin powder (Jeera)',
#   'Black pepper powder',
#   'Cooking oil'],
#  ['Carrot (Gajjar)',
#   'Green Bell Pepper (Capsicum)',
#   'Onion',
#   'Hakka Noodles',
#   'Spring Onion (Bulb & Greens)',
#   'Black pepper powder',
#   'Salt',
#   'All Purpose Flour (Maida)',
#   'Water'],
#  ['Extra Virgin Olive Oil',
#   'Red Yellow and Green Bell Peppers (Capsicum)',
#   'Black olives',
#   'Sweet corn',
#   'Salt to taste',
#   'Pickled Jalapenos',
#   'Mixed Herbs (Dried)',
#   'Red Chilli flakes',
#   'Mozzarella cheese'],
#  ['Chicken breasts',
#   'Whole Egg',
#   'Corn flour',
#   'Salt',
#   'Tomato Ketchup',
#   'Vinegar',
#   'Sesame (Gingelly) Oil',
#   'Ginger',
#   'Garlic',
#   'Green Chillies',
#   'Onion',
#   'Spring Onion Greens'],
#  ['Garlic',
#   'Ginger',
#   'Spring Onion (Bulb & Greens)',
#   'Lemon Grass',
#   'Green Chillies',
#   'Coriander (Dhania) Seeds',
#   'Water',
#   'Cauliflower (gobi)',
#   'Red Bell pepper (Capsicum)',
#   'Green beans (French Beans)',
#   'Pineapple',
#   'Coconut milk',
#   'Brown Sugar (Demerara Sugar)',
#   'Salt',
#   'Basil leaves',
#   'Oil'],
#  ['Apples',
#   'Beetroots',
#   'Salad leaves',
#   'Black olives',
#   'Walnuts',
#   'Extra Virgin Olive Oil',
#   'Apple cider vinegar',
#   'Honey',
#   'Salt'],
#  ['Fennel seeds (Saunf)',
#   'Coriander (Dhania) Seeds',
#   'Whole Black Pepper Corns',
#   'Byadagi Dried Chillies',
#   'Cloves (Laung)',
#   'Cinnamon stick',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Fresh coconut',
#   'Whole Eggs',
#   'Coconut Oil',
#   'Pearl onions (Sambar Onions)',
#   'Curry leaves',
#   'Ginger',
#   'Garlic',
#   'Green Chillies',
#   'Tomatoes',
#   'Tomatoes'],
#  ['Spinach',
#   'Britannia Cheese Cubes',
#   'Chicken keema',
#   'Salt',
#   'Garlic powder',
#   'Mixed Herbs (Dried)',
#   'Red Chilli flakes',
#   'Extra Virgin Olive Oil',
#   'Black pepper powder',
#   'Oil',
#   'Whole Eggs',
#   'Whole Wheat Bread crumbs',
#   'Mixed Herbs (Dried)'],
#  ['Sweet corn',
#   'Onion',
#   'Tomato',
#   'Green Bell Pepper (Capsicum)',
#   'Yellow Bell Pepper (Capsicum)',
#   'Red Bell pepper (Capsicum)',
#   'Carrot (Gajjar)',
#   'Lemon juice',
#   'Extra Virgin Olive Oil',
#   'Green Chilli',
#   'Coriander (Dhania) Leaves',
#   'Salt'],
#  ['Broccoli',
#   'Button mushrooms',
#   'Red Bell pepper (Capsicum)',
#   'Extra Virgin Olive Oil',
#   'Garlic',
#   'Black pepper corns',
#   'Salt to taste',
#   'Basil leaves'],
#  ['Bottle gourd (lauki)',
#   'Yellow Moong Dal (Split)',
#   'Mustard seeds',
#   'Cumin (Jeera) seeds',
#   'Curry leaves',
#   'Dry Red Chillies',
#   'Pearl onions (Sambar Onions)',
#   'Tomato',
#   'Turmeric powder (Haldi)',
#   'Salt to taste',
#   'Coriander (Dhania) Leaves'],
#  ['Milk',
#   'Whole Almonds (Badam)',
#   'Sugar',
#   'Saffron strands',
#   'Cardamom Powder (Elaichi)',
#   'Pistachios'],
#  ['All Purpose Flour (Maida)',
#   'Whole Wheat Flour',
#   'Baking powder',
#   'Salt',
#   'Extra Virgin Olive Oil',
#   'Carrots (Gajjar)',
#   'Garlic',
#   'Salt',
#   'Tzatziki'],
#  ['Methi Leaves (Fenugreek Leaves)',
#   'Soya Chunks',
#   'Mustard oil',
#   'Cumin (Jeera) seeds',
#   'Onions',
#   'Ginger',
#   'Garlic',
#   'Bay leaf (tej patta)',
#   'Cinnamon Stick (Dalchini)',
#   'Turmeric powder (Haldi)',
#   'Coriander (Dhania) Powder',
#   'Red Chilli powder',
#   'Amchur (Dry Mango Powder)',
#   'Jaggery',
#   'Salt to taste'],
#  ['Kashmiri dry red chillies',
#   'Mutton',
#   'Cumin seeds (Jeera)',
#   'Cumin powder (Jeera)',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Brown cardamom (Badi Elaichi)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cinnamon Stick (Dalchini)',
#   'Cloves (Laung)',
#   'Bay leaf (tej patta)',
#   'Onions',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Charcoal'],
#  ['Mooli/ Mullangi (Radish)',
#   'Yellow Moong Dal (Split)',
#   'Turmeric powder (Haldi)',
#   'Green Chillies',
#   'Ginger',
#   'Fresh coconut',
#   'Mustard seeds',
#   'Dry Red Chillies',
#   'Asafoetida (hing)',
#   'Coriander (Dhania) Leaves',
#   'Lemon wedges'],
#  ['Basmati rice',
#   'Extra Virgin Olive Oil',
#   'Onion',
#   'Green Chillies',
#   'Garlic',
#   'Green Bell Pepper (Capsicum)',
#   'Tomatoes',
#   'Celery',
#   'Sweet corn',
#   'Green peas (Matar)',
#   'Red Chilli powder',
#   'Cheddar cheese',
#   'Coal',
#   'Salt'],
#  ['Sweet corn',
#   'Coriander (Dhania) Leaves',
#   'Baking powder',
#   'Whole Egg',
#   'Salt',
#   'Sunflower Oil'],
#  ['Basmati rice',
#   'Jackfruit Raw (Kathal)',
#   'Onions',
#   'Ginger',
#   'Garlic',
#   'Bay leaves (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Black cardamom (Badi Elaichi)',
#   'Cloves (Laung)',
#   'Whole Black Peppercorns',
#   'Cinnamon Stick (Dalchini)',
#   'Star anise',
#   'Mace (Javitri)',
#   'Nutmeg powder',
#   'Green Chillies',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Salt',
#   'Mint Leaves (Pudina)',
#   'Coriander (Dhania) Leaves',
#   'Lemon juice',
#   'Saffron strands',
#   'Caramelized onions',
#   'Cashew nuts',
#   'Raisins'],
#  ['Spinach Leaves (Palak)',
#   'Cumin seeds (Jeera)',
#   'Whole Black Peppercorns',
#   'Green Chilli',
#   'Fresh coconut',
#   'Salt',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Dry Red Chilli'],
#  ['Button mushrooms',
#   'Turmeric powder (Haldi)',
#   'Oil',
#   'Salt',
#   'Fresh coconut',
#   'Shallots',
#   'Green Chillies',
#   'Curry leaves',
#   'Cumin seeds (Jeera)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Dry Red Chillies'],
#  ['Whole Egg',
#   'Broccoli',
#   'Onion',
#   'Tomatoes',
#   'Garlic',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Oil'],
#  ['Multigrain Digestive Oat Biscuits',
#   'Butter (Salted)',
#   'Britannia Cream Cheese',
#   'Hung Curd (Greek Yogurt)',
#   'Honey',
#   'Mango (Ripe)',
#   'Mint Leaves (Pudina)'],
#  ['Green beans (French Beans)',
#   'Carrot (Gajjar)',
#   'Green peas (Matar)',
#   'Potato (Aloo)',
#   'Mangalorean cucumber',
#   'Pointed gourd (Parval)',
#   'Green Chillies',
#   'Coconut milk',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chilli',
#   'Coconut Oil',
#   'Curry leaves'],
#  ['Strawberries',
#   'Sugar',
#   'Lemon juice',
#   'Amul whipping cream',
#   'Condensed Milk'],
#  ['Kaddu (Parangikai/ Pumpkin)',
#   'Carrot (Gajjar)',
#   'Garlic',
#   'Milk',
#   'Cinnamon Powder (Dalchini)',
#   'Brown Sugar (Demerara Sugar)',
#   'Salt and Pepper',
#   'Extra Virgin Olive Oil'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Salt',
#   'Oil',
#   'Green Chillies',
#   'Cumin seeds (Jeera)',
#   'Fresh coconut',
#   'Salt',
#   'Coconut Oil',
#   'White Urad Dal (Split)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Curry leaves'],
#  ['Arhar dal (Split Toor Dal)',
#   'Potato (Aloo)',
#   'Brinjal (Baingan / Eggplant)',
#   'Raw Banana',
#   'Bottle gourd (lauki)',
#   'Tamarind',
#   'Jaggery',
#   'Curry leaves',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chilli',
#   'Sunflower Oil',
#   'Salt',
#   'Sunflower Oil',
#   'White Urad Dal (Split)',
#   'Fresh coconut',
#   'Coriander (Dhania) Seeds',
#   'Whole Black Peppercorns',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chillies'],
#  ['Baby brinjals',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Coconut Oil',
#   'Coconut Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Fennel seeds (Saunf)',
#   'Curry leaves',
#   'Green Chillies',
#   'Pearl onions (Sambar Onions)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Tomatoes',
#   'Coconut milk',
#   'Salt',
#   'Coriander (Dhania) Leaves'],
#  ['Bajra (seeds)',
#   'White Urad Dal (Whole)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Salt',
#   'Onion',
#   'Green Bell Pepper (Capsicum)',
#   'Green Chilli',
#   'Salt',
#   'Mint Leaves (Pudina)',
#   'Cumin powder (Jeera)'],
#  ['Elephant yam (Suran/Senai/Ratalu)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Fresh coconut',
#   'Green Chillies',
#   'Cumin seeds (Jeera)',
#   'Whole Black Peppercorns',
#   'Coconut Oil',
#   'Mustard seeds',
#   'Curry leaves'],
#  ['Chicken breasts',
#   'Garlic',
#   'Ginger',
#   'Black pepper powder',
#   'Red wine',
#   'Brown Sugar (Demerara Sugar)',
#   'Vinegar',
#   'Sunflower Oil',
#   'Garlic',
#   'Corn flour',
#   'Water'],
#  ['Kala Chana (Brown Chickpeas)',
#   'Mangalorean cucumber',
#   'Drumstick',
#   'Turmeric powder (Haldi)',
#   'Pearl onions (Sambar Onions)',
#   'Salt',
#   'Mustard seeds',
#   'Curry leaves',
#   'Sesame (Gingelly) Oil',
#   'Fresh coconut',
#   'Coriander (Dhania) Seeds',
#   'Methi Seeds (Fenugreek Seeds)',
#   'White Urad Dal (Split)',
#   'Dry Red Chillies'],
#  ['Cauliflower (gobi)',
#   'Onion',
#   'Garlic',
#   'Black pepper powder',
#   'Red Chilli powder',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Mustard seeds',
#   'Curry leaves',
#   'Black Urad Dal (Split)',
#   'Dry Red Chilli',
#   'Sunflower Oil',
#   'Sunflower Oil'],
#  ['Mustard oil',
#   'Garlic',
#   'Green Chillies',
#   'Tomatoes',
#   'Gram flour (besan)',
#   'Tamarind',
#   'Kaddu (Parangikai/ Pumpkin)',
#   'Mooli/ Mullangi (Radish)',
#   'Colocasia root (Arbi)',
#   'Brinjal (Baingan / Eggplant)',
#   'Carrot (Gajjar)',
#   'Bhindi (Lady Finger/Okra)',
#   'Drumstick',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Salt',
#   'Oil'],
#  ['Lotus Stem',
#   'Gram flour (besan)',
#   'Dry ginger powder',
#   'Fennel seeds (Saunf)',
#   'Ajwain (Carom seeds)',
#   'Cinnamon Stick (Dalchini)',
#   'Black cardamom (Badi Elaichi)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Cloves (Laung)',
#   'Bay leaf (tej patta)',
#   'Asafoetida (hing)',
#   'Salt'],
#  ['Orange',
#   'Tamarind',
#   'Jaggery',
#   'Rasam Powder',
#   'Red Chilli powder',
#   'Rice flour',
#   'Salt',
#   'Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'White Urad Dal (Split)',
#   'Dry Red Chilli',
#   'Green Chilli',
#   'Asafoetida (hing)',
#   'Turmeric powder (Haldi)'],
#  ['All Purpose Flour (Maida)',
#   'Baking powder',
#   'Whole Eggs',
#   'Butter (Salted)',
#   'Oil',
#   'Brown Sugar (Demerara Sugar)',
#   'Sugar',
#   'Vanilla Extract',
#   'Ripe Bananas',
#   'Chocolate chips',
#   'Walnuts',
#   'Walnuts'],
#  ['Pineapple',
#   'Fresh coconut',
#   'White Urad Dal (Split)',
#   'Dry Red Chillies',
#   'Jaggery',
#   'Salt',
#   'Mustard seeds',
#   'Curry leaves',
#   'Sunflower Oil'],
#  ['Chana dal (Bengal Gram Dal)',
#   'Dry coconut (kopra)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Mustard oil',
#   'Cumin seeds (Jeera)',
#   'Green Chillies',
#   'Ginger',
#   'Dry Red Chillies',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Bay leaf (tej patta)'],
#  ['Whole Wheat Flour',
#   'Salt',
#   'Oil',
#   'Arhar dal (Split Toor Dal)',
#   'Jaggery',
#   'Saffron strands',
#   'Cardamom Powder (Elaichi)',
#   'Nutmeg powder',
#   'Gram flour (besan)'],
#  ['Chicken',
#   'Whole Egg',
#   'Corn flour',
#   'Salt',
#   'Sunflower Oil',
#   'Corn flour',
#   'Chilli vinegar',
#   'Water',
#   'Garlic',
#   'Ginger',
#   'Onion',
#   'Green Bell Pepper (Capsicum)',
#   'Green Chillies',
#   'Spring Onion Greens'],
#  ['Baguette',
#   'Garlic',
#   'Button mushrooms',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Black pepper powder',
#   'Basil leaves'],
#  ['Green Moong Dal (Whole)',
#   'Fresh coconut',
#   'Dry Red Chilli',
#   'Coconut Oil',
#   'Mustard seeds',
#   'Curry leaves',
#   'Salt'],
#  ['Britannia Cheese Block',
#   'Green Chillies',
#   'Onions',
#   'Mint Leaves (Pudina)',
#   'Cumin powder (Jeera)',
#   'Whole Wheat Flour',
#   'Kalonji (Onion Nigella Seeds)',
#   'Salt'],
#  ['Sweet Potatoes',
#   'Onions',
#   'Garlic',
#   'Red Chilli flakes',
#   'Honey',
#   'Salt and Pepper',
#   'Sunflower Oil'],
#  ['Flat Green Beans',
#   'Small Brinjal (Baingan / Eggplant)',
#   'Ajwain (Carom seeds)',
#   'Mustard seeds',
#   'Ginger',
#   'Garlic',
#   'Tomatoes',
#   'Asafoetida (hing)',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Red Chilli powder',
#   'Jaggery',
#   'Sunflower Oil',
#   'Salt',
#   'Methi Leaves (Fenugreek Leaves)',
#   'Gram flour (besan)',
#   'Whole Wheat Flour',
#   'Turmeric powder (Haldi)',
#   'Jaggery',
#   'Asafoetida (hing)',
#   'Enos fruit salt',
#   'Lemon juice',
#   'Sunflower Oil',
#   'Salt'],
#  ['Potatoes (Aloo)',
#   'Mustard oil',
#   'Turmeric powder (Haldi)',
#   'Rice flour',
#   'Lemon juice',
#   'Salt',
#   'Mustard oil',
#   'Green Chillies',
#   'Coriander (Dhania) Leaves'],
#  ['Sunflower Oil',
#   'Cumin seeds (Jeera)',
#   'Garlic',
#   'Onions',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Coconut milk',
#   'Dijon Mustard',
#   'Carrots (Gajjar)',
#   'Green beans (French Beans)',
#   'Green peas (Matar)',
#   'Potatoes (Aloo)',
#   'Salt'],
#  ['Spinach Leaves (Palak)',
#   'Garlic',
#   'Salt',
#   'Fresh coconut',
#   'Dry Red Chillies',
#   'Tamarind'],
#  ['Rice',
#   'Tomatoes',
#   'Green Chilli',
#   'Basil leaves',
#   'Garlic',
#   'Extra Virgin Olive Oil',
#   'Whole Black Peppercorns',
#   'Salt',
#   'Water',
#   'Coriander (Dhania) Leaves'],
#  ['Conchiglie Pasta',
#   'Broccoli',
#   'Extra Virgin Olive Oil',
#   'Black pepper powder',
#   'White vinegar',
#   'Dried oregano',
#   'Salt',
#   'Rosemary',
#   'Fresh Thyme leaves'],
#  ['Pearl onions (Sambar Onions)',
#   'Roasted Peanuts (Moongphali)',
#   'Garlic',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Cumin powder (Jeera)',
#   'Turmeric powder (Haldi)',
#   'Coriander (Dhania) Leaves',
#   'Sunflower Oil',
#   'Salt'],
#  ['Quinoa',
#   'Brown Rice',
#   'Garlic',
#   'Button mushrooms',
#   'Green Bell Pepper (Capsicum)',
#   'Broccoli',
#   'Cheddar cheese',
#   'Fresh cream',
#   'Salt',
#   'Black pepper powder'],
#  ['Bhindi (Lady Finger/Okra)',
#   'Garlic',
#   'Cashew nuts',
#   'Fresh coconut',
#   'Curry leaves',
#   'Red Chilli powder',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Chana dal (Bengal Gram Dal)',
#   'Dry Red Chilli',
#   'Sunflower Oil'],
#  ['Whole Wheat Flour',
#   'Extra Virgin Olive Oil',
#   'Sugar',
#   'Salt',
#   'Lukewarm Water',
#   'Green zucchini',
#   'Onion',
#   'Mozzarella cheese'],
#  ['Potatoes (Aloo)',
#   'Sunflower Oil',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Amchur (Dry Mango Powder)',
#   'Salt'],
#  ['Colocasia root (Arbi)',
#   'Tamarind',
#   'Salt',
#   'Fresh coconut',
#   'Red Chilli powder',
#   'Onions',
#   'Coconut Oil',
#   'Onions',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chilli',
#   'Curry leaves'],
#  ['Long Green Brinjal',
#   'Mustard seeds',
#   'Curry leaves',
#   'Onion',
#   'Tomato',
#   'Turmeric powder (Haldi)',
#   'Jaggery',
#   'Salt',
#   'Gingelly oil',
#   'Sesame seeds (Til seeds)',
#   'Roasted Peanuts (Moongphali)'],
#  ['Tindora (Dondakaya/ Kovakkai)',
#   'Onion',
#   'Dry Red Chilli',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Whole Black Peppercorns',
#   'Tamarind',
#   'Fresh coconut',
#   'Garlic',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sunflower Oil'],
#  ['Mixed vegetables',
#   'Onion',
#   'Salt',
#   'Turmeric powder (Haldi)',
#   'Green Chilli',
#   'Coconut Oil',
#   'Fresh coconut',
#   'Kashmiri dry red chillies',
#   'Whole Black Peppercorns',
#   'Onion',
#   'Garlic',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Tamarind'],
#  ['Methi Leaves (Fenugreek Leaves)',
#   'Brinjal (Baingan / Eggplant)',
#   'Ginger',
#   'Onion',
#   'Tomato',
#   'Green Chillies',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Salt',
#   'Sunflower Oil',
#   'Anardana Powder (Pomegranate Seed Powder)'],
#  ['Basmati rice',
#   'Onions',
#   'Tomatoes',
#   'Ginger',
#   'Garlic',
#   'Green Chillies',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Cloves (Laung)',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Bay leaves (tej patta)',
#   'Whole Black Peppercorns',
#   'Mint Leaves (Pudina)',
#   'Salt',
#   'Sunflower Oil'],
#  ['Fresh Pomegranate Fruit Kernels',
#   'Brussel sprouts',
#   'Cranberries',
#   'Honey',
#   'Green Chilli',
#   'Lemon',
#   'Salt and Pepper'],
#  ['Mango (Raw)',
#   'Jaggery',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Dry Red Chillies',
#   'Gingelly oil'],
#  ['All Purpose Flour (Maida)',
#   'Lukewarm Water',
#   'Salt',
#   'Sugar',
#   'Whole Eggs',
#   'Extra Virgin Olive Oil',
#   'Sesame seeds (Til seeds)'],
#  ['Coconut Oil',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Nendra Pazham Banana (Ripe)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Fresh coconut',
#   'Green Chillies',
#   'Curry leaves',
#   'Cumin seeds (Jeera)',
#   'Lukewarm Water',
#   'Sunflower Oil'],
#  ['Wild Rice',
#   'Green Bell Pepper (Capsicum)',
#   'Yellow Bell Pepper (Capsicum)',
#   'Red Bell pepper (Capsicum)',
#   'Onion',
#   'Ginger',
#   'Garlic',
#   'Salt and Pepper',
#   'Sunflower Oil',
#   'Paprika powder',
#   'Dried oregano',
#   'Black pepper powder',
#   'Cinnamon Powder (Dalchini)',
#   'Ginger',
#   'Sugar',
#   'Garlic',
#   'Onion',
#   'Salt',
#   'Tofu'],
#  ['Karela (Bitter Gourd/ Pavakkai)',
#   'Onions',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Kashmiri Red Chilli Powder',
#   'Jaggery',
#   'Salt',
#   'Sunflower Oil',
#   'Onion',
#   'Fresh coconut',
#   'Sunflower Oil',
#   'Sunflower Oil',
#   'Mustard seeds',
#   'Asafoetida (hing)'],
#  ['Mackerel fish',
#   'Goan recheado masala',
#   'Sooji (Semolina/ Rava)',
#   'Extra Virgin Olive Oil',
#   'Salt'],
#  ['Corn Cob',
#   'Mooli/ Mullangi (Radish)',
#   'Spring Onion Greens',
#   'Extra Virgin Olive Oil',
#   'Lemon',
#   'Salt',
#   'Whole Black Peppercorns',
#   'Dijon Mustard',
#   'Coriander (Dhania) Leaves'],
#  ['Egg white',
#   'Button mushrooms',
#   'Spinach',
#   'Onion',
#   'Dried oregano',
#   'Basil leaves',
#   'Red Chilli flakes',
#   'Salt and Pepper'],
#  ['Cashew nuts',
#   'Fresh coconut',
#   'Sugar',
#   'Salt',
#   'Coconut Oil',
#   'White Urad Dal (Split)',
#   'Mustard seeds',
#   'Dry Red Chillies',
#   'Garlic',
#   'Turmeric powder (Haldi)',
#   'Curry leaves'],
#  ['Blanched tomatoes',
#   'Extra Virgin Olive Oil',
#   'Garlic',
#   'Onion',
#   'Basil leaves',
#   'Salt',
#   'Whole Black Peppercorns',
#   'Sugar'],
#  ['Mangalorean cucumber',
#   'Arhar dal (Split Toor Dal)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sunflower Oil',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'White Urad Dal (Split)',
#   'Whole Black Peppercorns',
#   'Fresh coconut',
#   'Dry Red Chillies',
#   'Garlic',
#   'Sunflower Oil',
#   'Mustard seeds',
#   'White Urad Dal (Split)',
#   'Dry Red Chillies',
#   'Garlic',
#   'Curry leaves'],
#  ['White Urad Dal (Whole)',
#   'Ginger',
#   'Green Chillies',
#   'Salt',
#   'Onions',
#   'Coriander (Dhania) Leaves',
#   'Sunflower Oil',
#   'Arhar dal (Split Toor Dal)',
#   'Pearl onions (Sambar Onions)',
#   'Mooli/ Mullangi (Radish)',
#   'Carrot (Gajjar)',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Gingelly oil',
#   'Mustard seeds',
#   'Dry Red Chillies',
#   'Curry leaves',
#   'Asafoetida (hing)'],
#  ['Chicken breasts',
#   'Garlic',
#   'Lemon juice',
#   'Dried oregano',
#   'Dried Thyme Leaves',
#   'Rosemary',
#   'Red Chilli flakes',
#   'Salt',
#   'Cumin powder (Jeera)',
#   'Whole Egg',
#   'Milk',
#   'All Purpose Flour (Maida)'],
#  ['Small Brinjal (Baingan / Eggplant)',
#   'Arhar dal (Split Toor Dal)',
#   'Turmeric powder (Haldi)',
#   'Mustard seeds',
#   'Curry leaves',
#   'Salt',
#   'Sesame (Gingelly) Oil',
#   'Chana dal (Bengal Gram Dal)',
#   'White Urad Dal (Split)',
#   'Coriander (Dhania) Seeds',
#   'Whole Black Peppercorns',
#   'Dry Red Chillies',
#   'Fresh coconut',
#   'Asafoetida (hing)'],
#  ['Whole Eggs',
#   'Onion',
#   'Green Chilli',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Onion',
#   'Green Chillies',
#   'Coriander (Dhania) Seeds',
#   'Whole Black Peppercorns',
#   'Ginger',
#   'Garlic',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)',
#   'Tomato',
#   'Fresh coconut',
#   'Poppy seeds',
#   'Hung Curd (Greek Yogurt)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sunflower Oil',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Curry leaves',
#   'Onion',
#   'Coriander (Dhania) Leaves'],
#  ['Small Brinjal (Baingan / Eggplant)',
#   'Onion',
#   'Green Chillies',
#   'Garlic',
#   'Ginger',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Bay leaf (tej patta)',
#   'Cinnamon Stick (Dalchini)',
#   'Cloves (Laung)',
#   'Red Chilli powder',
#   'Cumin powder (Jeera)',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Oil',
#   'Salt',
#   'Fresh coconut',
#   'Sesame seeds (Til seeds)',
#   'Roasted Peanuts (Moongphali)',
#   'Coriander (Dhania) Leaves'],
#  ['Mutton',
#   'Cumin powder (Jeera)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Lemon juice',
#   'Onion',
#   'Garlic',
#   'Ginger',
#   'Curry leaves',
#   'Black pepper powder',
#   'Fresh coconut',
#   'Salt',
#   'Water',
#   'Coconut Oil'],
#  ['Chana dal (Bengal Gram Dal)',
#   'Green Chilli',
#   'Mustard seeds',
#   'White Urad Dal (Split)',
#   'Cumin seeds (Jeera)',
#   'Curry leaves',
#   'Asafoetida (hing)',
#   'Onion',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Sunflower Oil'],
#  ['Red Bell pepper (Capsicum)',
#   'Kaddu (Parangikai/ Pumpkin)',
#   'Garlic',
#   'Extra Virgin Olive Oil',
#   'Milk',
#   'Red Chilli flakes',
#   'Salt'],
#  ['Small Brinjal (Baingan / Eggplant)',
#   'Methi Leaves (Fenugreek Leaves)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Cumin powder (Jeera)',
#   'Jaggery',
#   'Amchur (Dry Mango Powder)',
#   'Mustard seeds',
#   'Cumin seeds (Jeera)',
#   'Sunflower Oil',
#   'Salt'],
#  ['Karela (Bitter Gourd/ Pavakkai)',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Sooji (Semolina/ Rava)',
#   'Salt',
#   'Extra Virgin Olive Oil'],
#  ['Cucumber',
#   'Kala Chana (Brown Chickpeas)',
#   'Fresh coconut',
#   'Dry Red Chillies',
#   'Tamarind',
#   'Coriander (Dhania) Seeds',
#   'Turmeric powder (Haldi)',
#   'Whole Black Peppercorns',
#   'Sugar',
#   'Salt'],
#  ['Cabbage (Patta Gobi/ Muttaikose)',
#   'Carrot (Gajjar)',
#   'Ginger',
#   'Salt',
#   'All Purpose Flour (Maida)',
#   'Corn flour',
#   'Sunflower Oil',
#   'Sunflower Oil',
#   'Red Bell pepper (Capsicum)',
#   'Green Bell Pepper (Capsicum)',
#   'Yellow Bell Pepper (Capsicum)',
#   'Green beans (French Beans)',
#   'Carrot (Gajjar)',
#   'Green Chillies',
#   'Ginger',
#   'Salt',
#   'Tomato Ketchup',
#   'Sugar',
#   'Chilled water',
#   'Corn flour',
#   'Coriander (Dhania) Leaves'],
#  ['Mixed vegetables',
#   'Cabbage (Patta Gobi/ Muttaikose)',
#   'Salt',
#   'Black pepper powder',
#   'Sunflower Oil',
#   'Cooked rice',
#   'Garlic',
#   'Black pepper powder',
#   'Chilli vinegar',
#   'Salt',
#   'Sunflower Oil',
#   'Potatoes (Aloo)',
#   'Button mushrooms',
#   'Salt',
#   'Red Chilli powder',
#   'Whole Wheat Bread crumbs',
#   'Sunflower Oil',
#   'Sunflower Oil',
#   'Black pepper powder',
#   'Garlic',
#   'Chilli vinegar',
#   'Tomato Ketchup',
#   'Water'],
#  ['Bok Choy',
#   'Cabbage (Patta Gobi/ Muttaikose)',
#   'Button mushrooms',
#   'Lotus Stem',
#   'Garlic',
#   'Honey',
#   'Salt',
#   'Sunflower Oil',
#   'Spring Onion (Bulb & Greens)'],
#  ['Black Urad Dal (Whole)',
#   'Rajma (Large Kidney Beans)',
#   'Cumin seeds (Jeera)',
#   'Cinnamon Stick (Dalchini)',
#   'Cloves (Laung)',
#   'Black cardamom (Badi Elaichi)',
#   'Tomatoes',
#   'Green Chilli',
#   'Red Chilli powder',
#   'Dry ginger powder',
#   'Milk',
#   'Salt',
#   'Ginger',
#   'Fresh cream'],
#  ['Tomatoes',
#   'Green Chillies',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Salt',
#   'Coconut Oil',
#   'Mustard seeds',
# ...
#   'Cardamom Powder (Elaichi)',
#   'Nutmeg',
#   'Pistachios',
#   'Sultana Raisins',
#   'Saffron strands'],
#  ['Cabbage (Patta Gobi/ Muttaikose)',
#   'Carrot (Gajjar)',
#   'All Purpose Flour (Maida)',
#   'Rice flour',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Salt',
#   'Sugar',
#   'Black pepper powder',
#   'Water',
#   'Oil'],
#  ['Ragi Flour (Finger Millet/ Nagli)',
#   'Jaggery',
#   'Muesli',
#   'Instant Coffee Powder',
#   'Extra Virgin Olive Oil',
#   'Vanilla Extract',
#   'Apricots',
#   'Egg whites'],
#  ['Rice',
#   'Black Urad Dal (Split)',
#   'Fresh coconut',
#   'Asafoetida (hing)',
#   'Salt',
#   'Oil'],
#  ['Arugula leaves',
#   'Watermelon',
#   'Feta Cheese',
#   'Extra Virgin Olive Oil',
#   'Red Wine Vinaigrette',
#   'Honey',
#   'Salt',
#   'Black pepper powder'],
#  ['Chana dal (Bengal Gram Dal)',
#   'White Urad Dal (Split)',
#   'Cinnamon Stick (Dalchini)',
#   'Cloves (Laung)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Dry Red Chillies',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Poppy seeds',
#   'Coriander (Dhania) Seeds',
#   'Fresh coconut',
#   'Turmeric powder (Haldi)',
#   'Asafoetida (hing)',
#   'Pearl onions (Sambar Onions)',
#   'Green Bell Pepper (Capsicum)',
#   'Carrots (Gajjar)',
#   'Green peas (Matar)',
#   'Green beans (French Beans)',
#   'Potato (Aloo)',
#   'Drumstick',
#   'Tomatoes',
#   'Jaggery',
#   'Salt',
#   'Rice',
#   'Arhar dal (Split Toor Dal)',
#   'Turmeric powder (Haldi)',
#   'Salt',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chilli',
#   'Curry leaves',
#   'Coriander (Dhania) Leaves',
#   'Boondi'],
#  ['All Purpose Flour (Maida)',
#   'Ajwain (Carom seeds)',
#   'Sooji (Semolina/ Rava)',
#   'Salt',
#   'Water',
#   'Oil',
#   'Potatoes (Aloo)',
#   'Onion',
#   'Oil',
#   'Cumin seeds (Jeera)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Anardana Powder (Pomegranate Seed Powder)',
#   'Fennel seeds (Saunf)',
#   'Sugar',
#   'Salt',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Coriander (Dhania) Leaves',
#   'Fresh Pomegranate Fruit Kernels',
#   'Lemon wedges',
#   'Onion'],
#  ['Cauliflower (gobi)',
#   'Turmeric powder (Haldi)',
#   'Mustard oil',
#   'Cumin seeds (Jeera)',
#   'Bay leaf (tej patta)',
#   'Water',
#   'Onion',
#   'Water',
#   'Kashmiri Red Chilli Powder',
#   'Fresh cream',
#   'Green Chilli',
#   'Cashew nuts',
#   'Salt'],
#  ['Whole turmeric',
#   'Ginger',
#   'Brown Sugar (Demerara Sugar)',
#   'Honey',
#   'Cinnamon Stick (Dalchini)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Saffron strands',
#   'Milk',
#   'Sultana Raisins'],
#  ['Puffed rice',
#   'Sev',
#   'Papdi puris',
#   'Onion',
#   'Tomato',
#   'Green Chillies',
#   'Cucumber',
#   'Potatoes (Aloo)',
#   'Anardana Powder (Pomegranate Seed Powder)',
#   'Mango (Raw)',
#   'Roasted Peanuts (Moongphali)',
#   'Chaat Masala Powder',
#   'Salt',
#   'Coriander (Dhania) Leaves'],
#  ['Potatoes (Aloo)',
#   'Ajwain (Carom seeds)',
#   'Onion',
#   'Ginger',
#   'Garlic',
#   'Tomatoes',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Kashmiri Red Chilli Powder',
#   'Coriander (Dhania) Leaves',
#   'Salt',
#   'Oil'],
#  ['Yellow Moong Dal (Split)',
#   'Cucumber',
#   'Carrot (Gajjar)',
#   'Fresh coconut',
#   'Lemon juice',
#   'Salt',
#   'Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Green Chillies',
#   'Asafoetida (hing)',
#   'Curry leaves',
#   'Coriander (Dhania) Leaves'],
#  ['Shrimps',
#   'Tofu',
#   'Iceberg lettuce',
#   'Cabbage (Patta Gobi/ Muttaikose)',
#   'Carrots (Gajjar)',
#   'Beetroot',
#   'Red baby radish',
#   'Yellow Bell Pepper (Capsicum)',
#   'Green Chilli',
#   'Salt',
#   'Whole Black Peppercorns',
#   'Lemon juice',
#   'Balsamic Vinegar',
#   'Red Chilli flakes',
#   'Sugar',
#   'Extra Virgin Olive Oil',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)',
#   'Roasted Peanuts (Moongphali)'],
#  ['Lettuce leaves',
#   'Tomatoes',
#   'English Cucumber',
#   'Feta Cheese',
#   'Extra Virgin Olive Oil',
#   'Lemon juice',
#   'Honey',
#   'Salt and Pepper'],
#  ['Kunafa Dough (strands)',
#   'Butter (Salted)',
#   'Pistachios',
#   'Milk',
#   'Corn flour',
#   'Rose water',
#   'Ricotta Cheese',
#   'Sugar',
#   'Water',
#   'Lemon juice',
#   'Rose water'],
#  ['Extra Virgin Olive Oil',
#   'Garlic',
#   'Onion',
#   'Salt',
#   'Rosemary',
#   'Rice',
#   'Extra Virgin Olive Oil',
#   'Red Chilli flakes',
#   'Red Bell pepper (Capsicum)',
#   'Yellow Bell Pepper (Capsicum)',
#   'Salt',
#   'Green Bell Pepper (Capsicum)',
#   'Mixed Herbs (Dried)',
#   'Parsley leaves',
#   'Extra Virgin Olive Oil',
#   'Carrots (Gajjar)',
#   'Yellow Zucchini',
#   'Green zucchini',
#   'Baby corn',
#   'Dry mix herbs',
#   'Salt',
#   'Extra Virgin Olive Oil',
#   'Garlic',
#   'Basil leaves',
#   'Salt',
#   'Sugar',
#   'Paprika powder',
#   'Fresh cream',
#   'Milk',
#   'Mozzarella cheese'],
#  ['Green apple',
#   'Red Radish',
#   'Mooli/ Mullangi (Radish)',
#   'Tomato',
#   'Tomatoes',
#   'Red cabbage',
#   'Onion',
#   'Broccoli',
#   'Red Bell pepper (Capsicum)',
#   'Green Bell Pepper (Capsicum)',
#   'Yellow Bell Pepper (Capsicum)',
#   'Lemon juice',
#   'Lemon zest',
#   'Fresh Thyme leaves',
#   'Green Chilli',
#   'Ginger',
#   'Coriander (Dhania) Leaves',
#   'Sesame (Gingelly) Oil',
#   'Garlic',
#   'Salt',
#   'Black pepper powder'],
#  ['Quinoa flour',
#   'All Purpose Flour (Maida)',
#   'Whole Egg',
#   'Vanilla Extract',
#   'Honey',
#   'Avocado',
#   'Brown Sugar (Demerara Sugar)',
#   'Baking soda',
#   'Salt',
#   'Cinnamon Powder (Dalchini)',
#   'Chia Seeds'],
#  ['Whole Eggs',
#   'Canola Oil',
#   'Milk',
#   'Brown Sugar (Demerara Sugar)',
#   'Dessicated Coconut',
#   'All Purpose Flour (Maida)',
#   'Whole Wheat Flour',
#   'Vanilla Extract',
#   'Nutmeg powder',
#   'Cardamom Powder (Elaichi)',
#   'Baking powder',
#   'Slivered Almonds (Badam)',
#   'Salt',
#   'Chocolate ganache',
#   'Raspberry Compote'],
#  ['Gram flour (besan)',
#   'Hung Curd (Greek Yogurt)',
#   'Ajwain (Carom seeds)',
#   'Red Chilli powder',
#   'Salt',
#   'Green Bell Pepper (Capsicum)',
#   'Carrot (Gajjar)',
#   'Yellow Zucchini',
#   'Onion',
#   'Oil',
#   'Dried oregano',
#   'Salt',
#   'Coriander (Dhania) Leaves',
#   'Mint Leaves (Pudina)',
#   'Garlic',
#   'Lemon juice',
#   'Green Chilli',
#   'Salt'],
#  ['Sultana Raisins',
#   'Prunes',
#   'Apricots',
#   'Dates',
#   'Dried Figs',
#   'Rum',
#   'Fresh orange juice',
#   'Orange Zest (Rind)',
#   'All Purpose Flour (Maida)',
#   'Baking powder',
#   'Butter (Unsalted)',
#   'Brown Sugar (Demerara Sugar)',
#   'Cinnamon Powder (Dalchini)',
#   'Cloves (Laung)',
#   'Dry ginger powder',
#   'Whole Almonds (Badam)',
#   'Flax seed powder (flax meal)',
#   'Chilled water'],
#  ['Butter (unsalted)',
#   'Caster Sugar',
#   'Vanilla Extract',
#   'Whole Eggs',
#   'Fresh cream',
#   'Milk',
#   'Ripe Bananas',
#   'Walnuts',
#   'Baileys Irish Cream'],
#  ['Chana dal (Bengal Gram Dal)',
#   'White Urad Dal (Split)',
#   'Fennel seeds (Saunf)',
#   'Green Chilli',
#   'Ginger',
#   'Garlic',
#   'Curry leaves',
#   'Mint Leaves (Pudina)',
#   'Coriander (Dhania) Leaves',
#   'Onion',
#   'Oil',
#   'Salt',
#   'Asafoetida (hing)'],
#  ['Beetroot',
#   'Garlic',
#   'Spring Onion (Bulb & Greens)',
#   'Extra Virgin Olive Oil',
#   'Whole Black Peppercorns',
#   'Walnuts',
#   'Cumin powder (Jeera)',
#   'Salt',
#   'Lemon juice',
#   'Coriander (Dhania) Leaves'],
#  ['Soy milk',
#   'Cocoa Powder',
#   'Salt',
#   'Cane sugar',
#   'Vanilla Extract',
#   'Chocolate Bar'],
#  ['Mango (Ripe)',
#   'Milk',
#   'Heavy whipping cream',
#   'Vanilla Extract',
#   'Water',
#   'Pistachios',
#   'Saffron strands',
#   'Honey'],
#  ['Dessicated Coconut', 'Condensed Milk', 'Milk chocolate'],
#  ['Poblano Chillies',
#   'Extra Virgin Olive Oil',
#   'Onion',
#   'Garlic',
#   'Cheddar cheese',
#   'Dried Thyme Leaves',
#   'Black pepper powder',
#   'Tarragon',
#   'Dried oregano',
#   'Gram flour (besan)',
#   'Whole Egg',
#   'Tomatoes',
#   'Garlic',
#   'Tomato Ketchup',
#   'Sugar',
#   'Red Chilli flakes',
#   'Dried oregano'],
#  ['All Purpose Flour (Maida)',
#   'Salt',
#   'Sugar',
#   'Extra Virgin Olive Oil',
#   'Milk',
#   'Lukewarm Water',
#   'Pineapple',
#   'Red Bell pepper (Capsicum)',
#   'Oil',
#   'Hung Curd (Greek Yogurt)',
#   'Gram flour (besan)',
#   'Garlic',
#   'Ginger',
#   'Kasuri Methi (Dried Fenugreek Leaves)',
#   'Fennel seeds (Saunf)',
#   'Ajwain (Carom seeds)',
#   'Cumin powder (Jeera)',
#   'Coriander Powder (Dhania)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Chaat Masala Powder',
#   'Salt',
#   'Mozzarella cheese',
#   'Cheese'],
#  ['Rice', 'Ajwain Powder', 'Salt'],
#  ['Penne pasta',
#   'Butter (Salted)',
#   'Garlic',
#   'Lemon juice',
#   'Lemon',
#   'Rosemary',
#   'Black pepper powder',
#   'Mozzarella cheese'],
#  ['Poha (Flattened rice)',
#   'Milk',
#   'Fresh cream',
#   'Green Chilli',
#   'Green peas (Matar)',
#   'Cumin seeds (Jeera)',
#   'Ginger',
#   'Black pepper powder',
#   'Coriander (Dhania) Leaves',
#   'Lemon juice',
#   'Salt'],
#  ['Dark chocolate', 'Egg yolks', 'Egg whites', 'Caster Sugar', 'Fresh cream'],
#  ['Red Bell pepper (Capsicum)',
#   'Garlic',
#   'Coriander (Dhania) Seeds',
#   'Cumin seeds (Jeera)',
#   'Dry Red Chillies',
#   'Extra Virgin Olive Oil',
#   'Sugar',
#   'Salt'],
#  ['Basa fish',
#   'All Purpose Flour (Maida)',
#   'Salt',
#   'Black pepper powder',
#   'Whole Egg',
#   'Milk',
#   'Whole Wheat Bread crumbs',
#   'Red Chilli powder',
#   'Red Chilli flakes',
#   'Garlic powder',
#   'Dry ginger powder',
#   'Cinnamon Powder (Dalchini)',
#   'Dried oregano'],
#  ['Nendra Pazham Banana (Ripe)', 'Oil'],
#  ['Whole Wheat Flour',
#   'Cinnamon Powder (Dalchini)',
#   'Cardamom Powder (Elaichi)',
#   'Baking powder',
#   'Salt',
#   'Whole Almonds (Badam)',
#   'Butter (Salted)',
#   'Brown Sugar (Demerara Sugar)',
#   'Whole Eggs',
#   'Vanilla Extract',
#   'Whole Almonds (Badam)'],
#  ['Whole Almonds (Badam)',
#   'Pistachios',
#   'Sugar',
#   'Butter (Salted)',
#   'Cardamom Powder (Elaichi)',
#   'Milk',
#   'Saffron strands',
#   'Honey',
#   'Rose water',
#   'Gelatin',
#   'Water',
#   'Sugar',
#   'Water',
#   'Saffron strands',
#   'Cardamom Powder (Elaichi)',
#   'Corn flour',
#   'Water'],
#  ['Arhar dal (Split Toor Dal)',
#   'Tamarind',
#   'Tomatoes',
#   'Garlic',
#   'Green Chilli',
#   'Rasam Powder',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)',
#   'Curry leaves',
#   'Coriander (Dhania) Leaves',
#   'Salt'],
#  ['Green zucchini',
#   'Ajwain (Carom seeds)',
#   'Red Chilli powder',
#   'Amchur (Dry Mango Powder)',
#   'Cumin powder (Jeera)',
#   'Turmeric powder (Haldi)',
#   'Whole Wheat Flour',
#   'Water',
#   'Salt'],
#  ['Green zucchini',
#   'Spring Onion Greens',
#   'Garlic',
#   'Dill leaves',
#   'Red Bell pepper (Capsicum)',
#   'Potato (Aloo)',
#   'Salt',
#   'Black pepper powder',
#   'Parmesan cheese',
#   'Whole Wheat Bread crumbs',
#   'Extra Virgin Olive Oil',
#   'Baking powder'],
#  ['Brinjal (Baingan / Eggplant)',
#   'Cranberries',
#   'Parsley leaves',
#   'Sesame seeds (Til seeds)',
#   'Lemon juice',
#   'Salt',
#   'Oil'],
#  ['Britannia Cream Cheese',
#   'Agar agar',
#   'Heavy whipping cream',
#   'White Chocolate',
#   'Vanilla Extract',
#   'Sugar',
#   'Lemon zest',
#   'Orange Zest (Rind)',
#   'Graham cracker crumbs',
#   'Butter (Unsalted)',
#   'Vanilla Extract'],
#  ['Mango (Ripe)',
#   'Green Chillies',
#   'Salt',
#   'Fresh coconut',
#   'Cumin seeds (Jeera)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coconut Oil',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Dry Red Chilli',
#   'Curry leaves'],
#  ['Mango (Raw)',
#   'Jaggery',
#   'Red Chilli powder',
#   'Methi Seeds (Fenugreek Seeds)',
#   'Cumin seeds (Jeera)',
#   'Asafoetida (hing)',
#   'Water',
#   'Coconut Oil',
#   'Salt'],
#  ['Graham cracker crumbs',
#   'Butter (unsalted)',
#   'Britannia Cream Cheese',
#   'Whole Eggs',
#   'Vanilla Extract',
#   'Sugar',
#   'Butter (unsalted)',
#   'Vivatta Maida',
#   'Brown Sugar (Demerara Sugar)',
#   'Cinnamon Powder (Dalchini)'],
#  ['Hung Curd (Greek Yogurt)',
#   'Fresh cream',
#   'Rose water',
#   'Sugar',
#   'Butter (Salted)',
#   'All Purpose Flour (Maida)',
#   'Confectioners sugar',
#   'Pistachios',
#   'Sugar',
#   'Dessicated Coconut'],
#  ['Carrot (Gajjar)',
#   'Green beans (French Beans)',
#   'Salt',
#   'Butter (Salted)',
#   'Mustard seeds (Rai/ Kadugu)',
#   'Asafoetida (hing)'],
#  ['Plum',
#   'All Purpose Flour (Maida)',
#   'Whole Eggs',
#   'Caster Sugar',
#   'Milk',
#   'Rosemary',
#   'Vanilla Extract',
#   'Sugar'],
#  ['Chicken ham',
#   'Dill leaves',
#   'Swiss cheese',
#   'Black olives',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Black pepper powder'],
#  ['Mint Leaves (Pudina)',
#   'Coriander (Dhania) Leaves',
#   'Green Chilli',
#   'Red Chilli powder',
#   'Cumin powder (Jeera)',
#   'Rock Salt',
#   'Chaat Masala Powder',
#   'Kala Chana (Brown Chickpeas)',
#   'Potatoes (Aloo)',
#   'Red Chilli powder',
#   'Rock Salt',
#   'Salt'],
#  ['Parsnip',
#   'Honey',
#   'Sesame (Gingelly) Oil',
#   'Garlic',
#   'Dried Thyme Leaves',
#   'Dried oregano',
#   'Black pepper powder'],
#  ['Whole Eggs',
#   'Hung Curd (Greek Yogurt)',
#   'Dijon Mustard',
#   'Fresh Herbs',
#   'Salt',
#   'Crackers'],
#  ['Fresh cream',
#   'Garlic',
#   'Chives',
#   'Parsley leaves',
#   'Salt',
#   'Black pepper powder',
#   'Balsamic Vinegar',
#   'Buttermilk',
#   'Yellow Bell Pepper (Capsicum)',
#   'Red Bell pepper (Capsicum)',
#   'English Cucumber',
#   'Carrots (Gajjar)'],
#  ['Horse Gram Dal (Kollu/ Kulith)',
#   'Bay leaf (tej patta)',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Black cardamom (Badi Elaichi)',
#   'Cinnamon Stick (Dalchini)',
#   'Cumin seeds (Jeera)',
#   'Asafoetida (hing)',
#   'Ginger',
#   'Black pepper powder',
#   'Coriander Powder (Dhania)',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Fresh cream',
#   'Salt'],
#  ['Tomatoes',
#   'Mozzarella cheese',
#   'Basil leaves',
#   'Red Wine Vinaigrette',
#   'Extra Virgin Olive Oil',
#   'Salt',
#   'Black pepper powder'],
#  ['All Purpose Flour (Maida)',
#   'Whole Wheat Flour',
#   'Baking soda',
#   'Salt',
#   'Cinnamon Powder (Dalchini)',
#   'Nutmeg',
#   'Instant Oats (Oatmeal)',
#   'Sweet Potato',
#   'Whole Egg',
#   'Brown Sugar (Demerara Sugar)',
#   'Milk',
#   'Maple syrup',
#   'Extra Virgin Olive Oil',
#   'Vanilla Extract',
#   'Chia Seeds',
#   'Pecans'],
#  ['Extra Virgin Olive Oil',
#   'Onion',
#   'Garlic',
#   'Button mushrooms',
#   'Fresh Thyme leaves',
#   'Salt and Pepper',
#   'Extra Virgin Olive Oil',
#   'Onion',
#   'Garlic',
#   'Celery',
#   'Carrot (Gajjar)',
#   'Green peas (Matar)',
#   'Sweet corn',
#   'Button mushrooms',
#   'Soy Chunks (Nuggets)',
#   'Dried oregano',
#   'Dried Thyme Leaves',
#   'Butter (Unsalted)',
#   'Potatoes (Aloo)',
#   'Milk',
#   'Salt and Pepper'],
#  ['Whole Eggs',
#   'Sunflower Oil',
#   'Cumin seeds (Jeera)',
#   'Onions',
#   'Green Chilli',
#   'Tomatoes',
#   'Red Chilli powder',
#   'Turmeric powder (Haldi)',
#   'Coriander Powder (Dhania)',
#   'Coconut milk',
#   'Salt',
#   'Coriander (Dhania) Leaves'],
#  ['Oreo biscuits',
#   'Butter (Unsalted)',
#   'Nutella Spread',
#   'Britannia Cream Cheese',
#   'Nutella Spread',
#   'Caster Sugar',
#   'Vanilla Extract',
#   'Heavy whipping cream',
#   'Cocoa Powder',
#   'Gelatin',
#   'Oreo biscuits',
#   'Fresh Cherries'],
#  ['Vivatta Maida',
#   'Sugar',
#   'Baking soda',
#   'Baking powder',
#   'Oil',
#   'Instant Coffee Powder',
#   'Walnuts'],
#  ['Red snapper fish',
#   'Shallots',
#   'Tomato',
#   'Kokum (Malabar Tamarind)',
#   'Gingelly oil',
#   'Mustard seeds',
#   'Dagad phool (/pathar phool/black stone flower)',
#   'Fennel seeds (Saunf)',
#   'Cumin seeds (Jeera)',
#   'Turmeric powder (Haldi)',
#   'Red Chilli powder',
#   'Coriander Powder (Dhania)',
#   'Salt'],
#  ['Whole Wheat Flour', 'Lukewarm Water', 'Sugar', 'Salt'],
#  ['Whole Wheat Flour',
#   'Water',
#   'Whole Almonds (Badam)',
#   'Cashew nuts',
#   'Sultana Raisins',
#   'Jaggery',
#   'Ajwain (Carom seeds)',
#   'Cardamom Powder (Elaichi)',
#   'Cinnamon Powder (Dalchini)'],
#  ['Walnuts', 'Walnuts', 'Milk', 'Jaggery', 'Cardamom Powder (Elaichi)'],
#  ['Whole Almonds (Badam)',
#   'Jaggery',
#   'Milk',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Whole Almonds (Badam)',
#   'Cashew nuts',
#   'Pistachios',
#   'Saffron strands'],
#  ['Basmati rice',
#   'Broccoli',
#   'Green Bell Pepper (Capsicum)',
#   'Red Bell pepper (Capsicum)',
#   'Onion',
#   'Green Chillies',
#   'Garlic',
#   'Coriander (Dhania) Leaves',
#   'Salt'],
#  ['Ripe Bananas',
#   'Cardamom (Elaichi) Pods/Seeds',
#   'Sooji (Semolina/ Rava)',
#   'Milk',
#   'Hot water',
#   'Jaggery',
#   'Cashew nuts',
#   'Sultana Raisins',
#   'Saffron strands'],
#  ['Phool Makhana (Lotus Seeds)',
#   'Milk',
#   'Jaggery',
#   'Cardamom Powder (Elaichi)',
#   'Cinnamon Stick (Dalchini)',
#   'Saffron strands',
#   'Whole Almonds (Badam)',
#   'Sultana Raisins',
#   'Chironji'],
#  ['Dates',
#   'Dried Figs',
#   'Pistachios',
#   'Cashew nuts',
#   'Whole Almonds (Badam)',
#   'Walnuts',
#   'Milk'],
#  ...]

# %%
#making a list of tags, but there are nulls. so not worth it

tags_list = []


for ing in df['tags']:
    try:
        tags_list.append([a.strip() for a in ing.split(",")])
    except:
        continue

# %%
type(ingredients_list)
# Out:
# list

# %%
type(df['ingredients'][0])
# Out:
# str

# %%
df3_backup = df2

# %%
#df.rename(columns = {'ingredients_list':'ingredients'}, inplace = True)

# %%
df = df2

# %%
df
# Out:
#                                                                recipe_title  \
# 0                        Roasted Peppers And Mushroom Tortilla Pizza Recipe
# 1     Thakkali Gotsu Recipe ,  Thakkali Curry ,  Spicy & Tangy Tomato Gravy
# 2                                      Spicy Grilled Pineapple Salsa Recipe
# 3                            Karwar Style Dali Thoy Recipe - Toor dal Curry
# 3               Side Dish Recipes, South Indian Recipes, Indian Lunch Recipes, Indian Vegetarian Recipes, Toor Dal Recipes (Pigeon Pea)
# 4                     Side Dish Recipes, Indian Lunch Recipes, Office Lunch Box Recipes, Rajma Kidney Bean Recipes, Poppy Seeds Recipes
# ...                                                                                                                                 ...
# 8004                                             Vegetarian Recipes, Carrot Recipes, Zucchini Recipes, Mother's Day Recipe Contest 2016
# 8005                                                                                       Gluten Free Recipes, Indian Diabetic Recipes
# 8006  High Protein Vegetarian Diet Recipes, South Indian Recipes, Healthy Recipes, Sprout Recipes, Coconut Milk Recipes, karwar Recipes
# 8007                                                 Healthy Recipes, Beetroot Recipes, Pudina Mint Recipes, Amla Recipes  (Gooseberry)
# 8008                                                                                                   Cauliflower Recipes (Phool Gobi)
#
#                                   category  ingredients
# 0                            Pizza Recipes          NaN
# 1                     Indian Curry Recipes          NaN
# 2                          Mexican Recipes          NaN
# 3                     Indian Curry Recipes          NaN
# 4                            Kofta Recipes          NaN
# ...                                    ...          ...
# 8004                         Pasta Recipes          NaN
# 8005                  Indian Curry Recipes          NaN
# 8006                  Indian Curry Recipes          NaN
# 8007                  Indian Drink Recipes          NaN
# 8008  Poriyal Recipes (South Indian Sabzi)          NaN
#
# [7972 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7972 entries, 0 to 8008
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   recipe_title      7972 non-null   object
#  1   url               7972 non-null   object
#  2   vote_count        7972 non-null   int64
#  3   rating            7972 non-null   float64
#  4   cuisine           7922 non-null   object
#  5   course            7836 non-null   object
#  6   diet              7840 non-null   object
#  7   prep_time         7972 non-null   float64
#  8   cook_time         7972 non-null   float64
#  9   author            7972 non-null   object
#  10  tags              7894 non-null   object
#  11  category          7972 non-null   object
#  12  ingredients_list  7972 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 871.9+ KB

# %%
#converting all ingredients to lower case (my apologies to proper nouns) to make things easier

df['ingredients'] = df['ingredients'].str.lower()

# %%
df['ingredients'].value_counts()
# Out:
# गेहूं का आटा|नमक|तेल|घी                                                                                                                                                                                             3
# strawberries|sugar|lemon juice                                                                                                                                                                                      3
# lemons|sugar|salt|red chilli powder                                                                                                                                                                                 3
# dates|dried figs|pistachios|cashew nuts|whole almonds (badam)|walnuts|milk                                                                                                                                          2
# ragi seeds|white urad dal (whole)|methi seeds (fenugreek seeds)|salt|water                                                                                                                                          2
#                                                                                                                                                                                                                    ..
# button mushrooms|pearl onions (sambar onions)|garlic|black pepper powder|salt|sunflower oil|coriander (dhania) leaves                                                                                               1
# broccoli|baby corn|carrots (gajjar)|red bell pepper (capsicum)|lemon grass|lemon juice|basil leaves|sugar|salt and pepper                                                                                           1
# masoor dal (whole)|tomatoes|onion|garlic|ginger|green chillies|kasuri methi (dried fenugreek leaves)|sunflower oil|red chilli powder|salt|turmeric powder (haldi)|coriander powder (dhania)|cumin powder (jeera)    1
# all purpose flour (maida)|baking soda|salt|caster sugar|buttermilk|vanilla extract|whole egg|sunflower oil|fresh fruits                                                                                             1
# all purpose flour (maida)|sugar|baking powder|baking soda|oil|orange zest (rind)|fresh orange juice|whole egg|vanilla extract|caster sugar|butter (salted)                                                          1
# Name: ingredients, Length: 7953, dtype: int64

# %%
#a lot of null values that need dealing with. Especially ingredients

null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# cuisine     50
# course     136
# diet       132
# tags        78
# dtype: int64

# %%
# 12 rows lacking ingredients. In a lot of cases, they also lack prep/cook time, course, diet, cuisine. May as well drop them

print(df[df["cook_time"].isnull()])
# Out:
# Empty DataFrame
# Columns: [recipe_title, url, vote_count, rating, cuisine, course, diet, prep_time, cook_time, ingredients, author, tags, category]
# Index: []

# %%
print(df[df["cook_time"].isnull()][null_columns])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-420-b06941729c74> in <module>
# ----> 1 print(df[df["cook_time"].isnull()][null_columns])
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['description'] not in index"

# %%
df = df.dropna(subset=['ingredients'])

# %%
# dropping null prep & cook times

df = df.dropna(subset=['prep_time'])

# %%
ingredients_brackets = df[df['ingredients'].str.contains("\(")]

# %%
# 223 recipes with ingredients in Hindi, hmmmm... approx 3% of total recipes. drop them?
# changed the ingredients column to LISTS instead of STRINGS... uh oh. not easy to check this now

ingredients['ingredients']
# Out:
# 841     अरहर दाल|हरी मिर्च|नारियल|जीरा|हल्दी पाउडर|नमक...
# 851     दही|बेसन|हींग|हल्दी पाउडर|गुड|नमक|जीरा|राइ|दाल...
# 1210    अरहर दाल|हल्दी पाउडर|इमली का पानी|टमाटर|लहसुन|...
# 1231    काबुली चना या छोला|प्याज|शिमला मिर्च (हरी)|लहस...
# 1234    चावल|घी|जीरा|तेज पत्ता|स्टार अनीस|इलाइची|लॉन्ग...
#                               ...
# 7534    दही|बेसन|हल्दी पाउडर|लाल मिर्च पाउडर|पानी|प्या...
# 7535    चावल|अदरक लहसुन का पेस्ट|हरे मटर|बटन मशरुम|प्य...
# 7550    अरहर दाल|टमाटर|संतरे का रस|निम्बू का रस|हल्दी ...
# 7619    पापड़|आलू|टमाटर|अदरक|तेज पत्ता|सुखी लाल मिर्च|ज...
# 7937    रागी का आटा|प्याज|अदरक|गाजर|बादाम|हरा बीन्स|नम...
# Name: ingredients, Length: 223, dtype: object

# %%
#6378 rows with brackets in the ingredients. that's a lot

pd.set_option('display.max_colwidth', None)
ingredients_brackets['ingredients']
# Out:
# 0                                                                                                                         tortillas|extra virgin olive oil|garlic|mozzarella cheese|red yellow or green bell pepper (capsicum)|onions|kalmatta olives|button mushrooms
# 1                                                                                                            sesame (gingelly) oil|mustard seeds (rai/ kadugu)|curry leaves|garlic|pearl onions (sambar onions)|tomatoes|tamarind|turmeric powder (haldi)|salt|jaggery
# 7962                                                                                                                                             couscous|onion|carrot|green peas (matar)|red chilli powder|coriander powder (dhania)|mint leaves (pudina)|bay leaf (tej patta)|cloves (laung)|cinnamon stick (dalchini)|oil|salt|coriander (dhania) leaves
# 7966                                                                                                                                                                                                                                                              red cabbage|carrot|apple|red onion|mint leaves (pudina)|lemon juice|honey|salt and pepper
# 7968                                                                                                                                                             hakka noodles|water|garlic|ginger|fresh red chilli|carrot|red bell pepper (capsicum)|green bell peppers|salt|black pepper powder|spring onion greens|chicken breasts|dry red chilli|garlic
# 8004                                                                                                                                                                                                  spirali pasta|onions|tomato|green zucchini|carrot|green chilli|dried oregano|dried basil leaves|black pepper powder|salt|extra virgin olive oil|sugar
# Name: ingredients, Length: 685, dtype: object

# %%
#ensuring consistent spelling of tomato and potato

potato = df[df['ingredients'].str.contains('gajar')]
print (potato['ingredients'])
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
#saving all as 'chilli' singular

df['ingredients'] = df['ingredients'].replace(r'carrot \(gajjar\)', 'carrot', regex=True)

# %%
# potatoes, chilllies, mustard seeds, tomatoes, peppers - cleaning!

# %%
df['ingredients'] = df['ingredients'].replace(r'potato \(aloo\)', 'potato', regex=True)

# %%
#make all chillies singular

df['ingredients'] = df['ingredients'].replace(r'chillies', 'chilli', regex=True)

# %%
#make tomatoes singular

df['ingredients'] = df['ingredients'].replace(r'tomatoes', 'tomato', regex=True)

# %%
chilli = df[df['ingredients'].str.contains('tomatoes')]
print (chilli['ingredients'])
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
type(df['ingredients'][0])
# Out:
# list

# %%
potato = df[df['ingredients'].str.contains('potato')]
print (potato['ingredients'])
# Out:
# 30      brinjal (baingan / eggplant), potato, onion, fresh coconut, turmeric powder (haldi), tamarind, garlic, ginger, jaggery, gram flour (besan), coriander (dhania) leaves, salt, cloves (laung), cinnamon stick (dalchini), cardamom (elaichi) pods/seeds, whole black peppercorns, byadagi dried chillies, oil, onion, fresh coconut, oil, mustard seeds (rai/ kadugu), asafoetida (hing), curry leaves
# 43                                                                                                                                    methi seeds (fenugreek seeds), coriander (dhania) seeds, fennel seeds (saunf), dry red chillies, fresh coconut, pearl onions (sambar onions), garlic, tomatoes, potato, brinjal (baingan / eggplant), jaggery, gingelly oil, mustard seeds (rai/ kadugu), curry leaves
# 62                                                                                                                                                                                                     pointed gourd (parval), potato, turmeric powder (haldi), red chilli powder, coriander powder (dhania), amchur (dry mango powder), mustard seeds (rai/ kadugu), cumin seeds (jeera), salt, mustard oil
# 63                                                    mustard oil, mustard seeds (rai/ kadugu), bay leaves (tej patta), green chillies, potato, kaddu (parangikai/ pumpkin), small brinjal (baingan / eggplant), carrot (gajjar), turmeric powder (haldi), salt, sugar, fresh coconut, yellow moong dal (split), chana dal (bengal gram dal), ginger, dry red chillies, turmeric powder (haldi), mustard oil
# 64                                                                                                                                                                                                                                                                                                                                                                  potato, garlic, fresh thyme leaves, salt
#                                                                                                                                                                                                         ...
# 7951                                                                                                                                                                   quinoa, potato, green peas (matar), carrots (gajjar), onion, green chilli, black pepper powder, extra virgin olive oil, salt, mango (raw), onion, red bell pepper (capsicum), pickled jalapenos, english cucumbers, lemon juice, salt
# 7958                       baby potatoes, green peas (matar), carrots (gajjar), green beans (french beans), red bell pepper (capsicum), yellow bell pepper (capsicum), raisins, tomato, onion, garlic, ginger, red chilli powder, turmeric powder (haldi), coriander powder (dhania), cumin powder (jeera), bay leaves (tej patta), cashew nuts, fresh cream, coriander (dhania) leaves, salt, sunflower oil
# 7975                                                                                                                                                                                                                      coriander (dhania) leaves, gram flour (besan), potato, turmeric powder (haldi), salt, sesame (gingelly) oil, mustard seeds, green chillies, cumin seeds (jeera), asafoetida (hing)
# 7976                                                                                               potato, onion, ginger, garlic, turmeric powder (haldi), sunflower oil, salt, coriander (dhania) leaves, chana dal (bengal gram dal), dry red chillies, fennel seeds (saunf), cumin seeds (jeera), whole black peppercorns, cloves (laung), cinnamon stick (dalchini), bay leaf (tej patta), fresh coconut
# 7997                                                                                                whole eggs, potato, onion, tomatoes, green chillies, salt, oil, coriander (dhania) leaves, bay leaf (tej patta), dry red chilli, cumin seeds (jeera), cardamom (elaichi) pods/seeds, cloves (laung), cinnamon stick (dalchini), turmeric powder (haldi), cumin powder (jeera), coriander powder (dhania)
# Name: ingredients, Length: 736, dtype: object

# %%
df['ingredients'].value_counts()
# Out:
# lemons|sugar|salt|red chilli powder                                                                                                                                                                                                              3
# strawberries|sugar|lemon juice                                                                                                                                                                                                                   3
# गेहूं का आटा|नमक|तेल|घी                                                                                                                                                                                                                          3
# आलू|जीरा|सुखी लाल मिर्च|अदरक पाउडर|हल्दी पाउडर|लाल मिर्च पाउडर|गरम मसाला पाउडर|हींग|हरा धनिया                                                                                                                                                    2
# गवार फली|प्याज|टमाटर|लहसुन|अदरक|धनिया पाउडर|तेल|राइ|जीरा|लाल मिर्च पाउडर|हल्दी पाउडर|हींग|नमक|हरा धनिया                                                                                                                                          2
#                                                                                                                                                                                                                                                 ..
# बैंगन|बेसन|पानी|हींग|हल्दी पाउडर|लाल मिर्च पाउडर|धनिया पाउडर|जीरा पाउडर|बेकिंग सोडा|नमक|तेल                                                                                                                                                      1
# gingelly oil|mustard seeds|methi seeds (fenugreek seeds)|asafoetida (hing)|dry red chilli|pearl onions (sambar onions)|curry leaves|urad dal papad|jaggery|turmeric powder (haldi)|water|salt                                                    1
# all purpose flour (maida)|baking powder|salt|cardamom powder (elaichi)|cinnamon powder (dalchini)|sugar|carrots (gajjar)|sunflower oil|whole eggs|walnuts|dark chocolate                                                                         1
# चेरी टमाटर|ओलिव का तेल|लहसुन|रोसमैरी|नमक|काली मिर्च पाउडर                                                                                                                                                                                        1
# masoor dal (whole)|beetroot|onion|garlic|cumin powder (jeera)|coriander powder (dhania)|salt|whole wheat bread crumbs|sunflower oil|extra virgin olive oil|garlic|dried oregano|parsley leaves|red chilli flakes|basil leaves|parmesan cheese    1
# Name: ingredients, Length: 7953, dtype: int64

# %%
hindi = df[df['ingredients'].str.contains('potato')]
print (hindi['ingredients'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-520-65eb35a18263> in <module>
# ----> 1 hindi = df[df['ingredients'].str.contains('potato')]
#       2 print (hindi['ingredients'])
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              ...\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],\n             dtype='float64', length=7972)] are in the [columns]"

# %%
salt = df[df['ingredients'].str.contains('black salt')]
print (salt['ingredients'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-521-aafdda8f37ac> in <module>
# ----> 1 salt = df[df['ingredients'].str.contains('black salt')]
#       2 print (salt['ingredients'])
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              ...\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],\n             dtype='float64', length=7972)] are in the [columns]"

# %%
mustard = df[df['ingredients'].str.contains('mustard seeds')]
print (mustard['ingredients'])
# Out:
# 1                                                                                                                                                               sesame (gingelly) oil, mustard seeds, curry leaves, garlic, pearl onions (sambar onions), tomato, tamarind, turmeric powder (haldi), salt, jaggery
# 3                                                                                                                                                             arhar dal (split toor dal), turmeric powder (haldi), salt, dry red chilli, mustard seeds, asafoetida (hing), curry leaves, coriander (dhania) leaves
# 7                                                                                                                avarekalu / lilva beans, rice, turmeric powder (haldi), asafoetida (hing), green chilli, curry leaves, mustard seeds, white urad dal (split), lemon juice, coriander (dhania) leaves, onion, salt
# 16                                                                                                                                  kaddu (parangikai/ pumpkin), turmeric powder (haldi), salt, fresh coconut, cumin seeds (jeera), green chilli, oil, mustard seeds, curry leaves, dry red chilli, dry red chilli
# 17                                       bhindi (lady finger/okra), gram flour (besan), red chilli powder, turmeric powder (haldi), coriander powder (dhania), amchur (dry mango powder), salt, water, oil, cumin seeds (jeera), mustard seeds, asafoetida (hing), green chilli, onions, coriander (dhania) leaves
#                                                                                                                                                            ...
# 8002    small brinjal (baingan / eggplant), mustard seeds, oil, onion, green chilli, garlic, curry leaves, tomato, turmeric powder (haldi), red chilli powder, salt, coriander (dhania) leaves, gram flour (besan), rice flour, salt, turmeric powder (haldi), red chilli powder, garlic, green chilli, onion, oil
# 8003      bhindi (lady finger/okra), salt, sunflower oil, fresh coconut, methi seeds (fenugreek seeds), cumin (jeera) seeds, dry red chilli, coriander (dhania) seeds, sesame seeds (til seeds), rice, garlic, turmeric powder (haldi), jaggery, water, sunflower oil, mustard seeds, dry red chilli, curry leaves
# 8005                                                                                        arhar dal (split toor dal), tomato, turmeric powder (haldi), red chilli powder, garlic, ginger, green chilli, oil, mustard seeds, cumin seeds (jeera), dry red chilli, curry leaves, garlic, coriander (dhania) leaves
# 8006                                                                                                                                                  turmeric powder (haldi), sugar, salt, fresh coconut, dry red chilli, coriander (dhania) seeds, sunflower oil, mustard seeds, asafoetida (hing), curry leaves
# 8008                                                 cauliflower (gobi), pearl onions (sambar onions), garlic, turmeric powder (haldi), black pepper powder, red chilli powder, cinnamon powder (dalchini), cloves (laung), coriander powder (dhania), salt, mustard seeds, cumin seeds (jeera), curry leaves, oil
# Name: ingredients, Length: 1229, dtype: object

# %%
#setting all mustard seeds without the info in brackets..... need an escape character with every weird character that Python doesnt like!

df['ingredients'] = df['ingredients'].replace(r'mustard seeds \(rai\/ kadugu\)', 'mustard seeds', regex=True)

# %%
df2 = df['ingredients'].apply(lambda x: x.split('seeds')[0])

# %%
df2.head(50)
# Out:
# 0                                                                                                                                                                                                                   tortillas|extra virgin olive oil|garlic|mozzarella cheese|red yellow or green bell pepper (capsicum)|onions|kalmatta olives|button mushrooms
# 1                                                                                                                                                                                                                                                                                                                                 sesame (gingelly) oil|mustard
# 2                                                                                                                                                                     extra virgin olive oil|pineapple|white onion|red yellow and green bell peppers (capsicum)|pickled jalapenos|coriander (dhania) leaves|mint leaves (pudina)|salt|lemon juice|paprika powder
# 3                                                                                                                                                                                                                                                                                arhar dal (split toor dal)|turmeric powder (haldi)|salt|dry red chilli|mustard
# 4                                                                                                                                                                                                                                                                                rajma (large kidney beans)|cashew nuts|sultana raisins|asafoetida (hing)|cumin
# 5                                                                                                                                                                                                                                                                                              barnyard millet|oil|bay leaf (tej patta)|cardamom (elaichi) pods/
# 6                                                                                                                                                                                                                                                                          coriander (dhania) leaves|tahini|lemon juice|extra virgin olive oil|honey|ginger|salt
# 7                                                                                                                                                                                                                                                      avarekalu / lilva beans|rice|turmeric powder (haldi)|asafoetida (hing)|green chilli|curry leaves|mustard
# 8                                                                                                                                                                                                                                                                                                        whole wheat flour|sooji (semolina/ rava)|ajwain (carom
# 9                                                                                                                                                                                                                   butter (unsalted)|caster sugar|whole eggs|all purpose flour (maida)|salt|baking powder|canned pineapple (preserved & tinned)|canned cherries
# 10                                                                            cashew nuts|onions|ginger|garlic|green chilli|green peas (matar)|butter (salted)|bay leaf (tej patta)|turmeric powder (haldi)|kashmiri red chilli powder|coriander powder (dhania)|salt|tomatoes|sugar|fresh cream|kasuri methi (dried fenugreek leaves)|coriander (dhania) leaves
# 11                                                                                  butter (salted)|garlic|green chilli|onion|green capsicum|cooked rice|sweet corn|all purpose flour (maida)|mint leaves (pudina)|mozzarella cheese|black pepper powder|oil|salt|all purpose flour (maida)|water|whole wheat bread crumbs|mixed herbs (dried)|red chilli flakes
# 12                                                                                                                                                                                                                                                   shrimps|butter (salted)|orange color|lemon juice|honey|black pepper powder|garlic|ginger|fresh thyme leaves
# 13                                                                                                                                                                                                                                            oil|kokum (malabar tamarind)|green chilli|jaggery|salt|coriander (dhania) leaves|fresh coconut|onion|garlic|cumin
# 34                                                                                                                                                                                                       sabudana (tapioca pearls)|shallots|mixed vegetables|coriander (dhania) leaves|coriander (dhania) leaves|black pepper powder|garlic|oil|water|garlic|oil
# 35                                                                                                                                                                                                                                                                                      fresh coconut|whole black peppercorns|dry red chilli|coriander (dhania)
# 36                                                                                                chipotle peppers|onion|garlic|tomatoes|raw peanuts (moongphali)|star anise|cinnamon stick (dalchini)|cloves (laung)|dark chocolate|dried oregano|black pepper powder|sultana raisins|makki ka atta (yellow corn meal flour)|butter (salted)|chicken stock|salt
# 37                                                                                                                                                                            whole eggs|green capsicum|onion|britannia cheese block|whole eggs|salt|black pepper powder|milk|avocado|onion|tomato|green chilli|salt|coriander (dhania) leaves|lemon juice|sugar
# 38                                                                                                tofu|sesame (gingelly) oil|brown sugar (demerara sugar)|dried basil leaves|garlic powder|cayenne pepper|coconut milk|ginger|garlic|peanut butter|turmeric powder (haldi)|lemon juice|brown sugar (demerara sugar)|iceberg lettuce|roasted peanuts (moongphali)
# 39                                                                                                                                                                                                                             mutton|salt|lemon juice|turmeric powder (haldi)|onions|garlic|ginger|cloves (laung)|bay leaf (tej patta)|cardamom (elaichi) pods/
# 40                                                                                                                                                                                                                                                       avarekalu / lilva beans|tomatoes|fresh coconut|jaggery|turmeric powder (haldi)|salt|coriander (dhania)
# 41                                                                                                                                 french loaf|butter (salted)|extra virgin olive oil|red yellow and green bell peppers (capsicum)|sweet corn|pickled jalapenos|basil leaves|salt|mozzarella cheese|mixed herbs (dried)|red chilli flakes|garlic bread spice mix
# 42                                                                                                                                                                                                     cashew nuts|tomato|green bell pepper (capsicum)|turmeric powder (haldi)|oil|coriander (dhania) leaves|salt|fresh coconut|onion|garlic|coriander (dhania)
# 43                                                                                                                                                                                                                                                                                                                                                        methi
# 44                                                                                                                                                                                                                                                                                rice|yellow moong dal (split)|turmeric powder (haldi)|cardamom (elaichi) pods/
# 45                                                                                                                                                                                                                                              vellai poosanikai (ash gourd/white pumpkin)|turmeric powder (haldi)|salt|oil|dry red chilli|fresh coconut|methi
# 46                                                                                                                                                                                                                                                bajra flour ( pearl millet)|whole wheat flour|methi leaves (fenugreek leaves)|garlic|red chilli powder|sesame
# 47                                                                                                                                                                                                                                                                                                                  bhindi (lady finger/okra)|oil|ajwain (carom
# 48    whole egg|mutton|ginger|garlic|coriander powder (dhania)|turmeric powder (haldi)|kashmiri red chilli powder|corn flour|mustard oil|salt|onion|turmeric powder (haldi)|green chilli paste|red chilli powder|garlic|ginger|coriander powder (dhania)|cumin powder (jeera)|kasuri methi (dried fenugreek leaves)|bay leaf (tej patta)|dry red chilli|salt|oil
# 49                                                                                                                                                                                                  tofu|orange zest (rind)|corn flour|whole black peppercorns|rice vinegar|brown sugar (demerara sugar)|fresh orange juice|ginger|sesame (gingelly) oil|sesame
# Name: ingredients, dtype: object

# %%
from collections import Counter

# %%
all_ingredients = str(df['ingredients'])

split_it = all_ingredients.split()

# %%
Counter2 = Counter(split_it)
most_occur = Counter2.most_common(10)
print(most_occur)
# Out:
# [('powder', 9), ('(dhania)', 5), ('leaves', 5), ('pepper', 4), ('virgin', 3), ('olive', 3), ('red', 3), ('seeds', 3), ('chilli', 3), ('yellow', 2)]

# %%
Counter(split_it)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input
# 6                                                                        Side Dish Recipes|Party Starter & Appetizer Recipes|Coriander Recipes|Tahini Recipes
# 7  South Indian Recipes|Indian Lunch Recipes|Festival Recipes|Ganesh Chaturthi Recipes|Lemon Recipes|Dussehra Festival Recipes|Avarakkai Recipes (Broad Bean)
# 8                Tea Party Recipes|Party Starter & Appetizer Recipes|Sooji Recipes (Rava/ Semolina)|Cabbage Recipes (Patta Gobi)|Samosa Recipe|Fusion Recipes
# 9                                                          Party Food Recipes|Tea Party Recipes|Birthday Party Cakes|Pineapple Recipes|Birthday Party Recipes
#
#                                             category
# 0                                      Pizza Recipes
# 1                               Indian Curry Recipes
# 2                                    Mexican Recipes
# 3                               Indian Curry Recipes
# 4                                      Kofta Recipes
# 5                                    Biryani Recipes
# 6               Homemade Jams, Sauce & Pesto Recipes
# 7  Variety Rice (Mixed Rice/ Flavoured Rice Recipes)
# 8                             Indian Chinese Recipes
# 9                                       Cake Recipes

# %%
df.to_pickle('backup2.pkl')

# %%
def user_ingredient():
    from random import randint
    #input from user
    ingredient_choice=input("Pick an ingredient")
    if len(ingredient_choice)==0:
        print("it looks like you can't think of an ingredient at the moment")
    else: 
        ingredient_choice=ingredient_choice.lower() #convert input to lowercase
        filter_ingredient=df[(df["ingredients"].str.lower()).str.contains(ingredient_choice)]# convert target to lowercase
        #check if its in the list we have
        
        
        
        
        if len(filter_ingredient) ==0:
            print("Poor choice")
            random_song2 = randint(0, len(filter_ingredient)-1)
            print("But check out '" + df["recipe_title"][random_song2] + df['ingredients'][random_song2])

        else:
            # if song is in billboard hot 100, confirm it, recommend another random hot song
            print("Now that's a hit")
            random_song = randint(0, len(filter_ingredient)-1)
            print("You might also like '" + df["recipe_title"][random_song] + df['ingredients'][random_song])

# %%
ingredient_choice=input("Pick an ingredient")
filter_ingredient=df[(df["ingredients"].str.lower()).str.contains(ingredient_choice)]
filter_ingredient.head()
# Out:
# Pick an ingredientsalt
#                                                           recipe_title  \
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy & Tangy Tomato Gravy
# 2                                 Spicy Grilled Pineapple Salsa Recipe
# 3                       Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4                      Rajma Kofta In Milk And Poppy Seed Gravy Recipe
# 5                              Barnyard Millet Mushroom Biryani Recipe
#
#                                                                                url  \
# 1     https://www.archanaskitchen.com/tomato-gotsu-recipe-spicy-tangy-tomato-gravy
# 2             https://www.archanaskitchen.com/spicy-grilled-pineapple-salsa-recipe
# 3     https://www.archanaskitchen.com/dali-thoy-recipe-karwar-style-toor-dal-curry
# 4  https://www.archanaskitchen.com/rajma-kofta-in-milk-and-poppy-seed-gravy-recipe
# 5         https://www.archanaskitchen.com/barnyard-millet-mushroom-biriyani-recipe
#
#    vote_count    rating               cuisine     course  \
# 1        3423  4.932223  South Indian Recipes      Lunch
# 2        2091  4.945959               Mexican  Side Dish
# 3         990  4.888889     Coastal Karnataka  Side Dish
# 4         345  4.828986  North Indian Recipes  Side Dish
# 5        2088  4.903736                Indian      Lunch
# 8008  Chettinad Cauliflower Pepper Fry Recipe - Chettinad Poo Kosu Poriyal
#
#                                                                                                   url  \
# 1                        https://www.archanaskitchen.com/tomato-gotsu-recipe-spicy-tangy-tomato-gravy
# 2                                https://www.archanaskitchen.com/spicy-grilled-pineapple-salsa-recipe
# 3                        https://www.archanaskitchen.com/dali-thoy-recipe-karwar-style-toor-dal-curry
# 4                     https://www.archanaskitchen.com/rajma-kofta-in-milk-and-poppy-seed-gravy-recipe
# 5                            https://www.archanaskitchen.com/barnyard-millet-mushroom-biriyani-recipe
# ...                                                                                               ...
# 8003      https://www.archanaskitchen.com/mangalorean-bhende-puli-kodel-recipe-okra-in-tamarind-gravy
# 8004                                 https://www.archanaskitchen.com/zucchini-and-carrot-pasta-recipe
# 8006                                   https://www.archanaskitchen.com/karwar-style-muga-ambat-recipe
# 8007                            https://www.archanaskitchen.com/beetroot-amla-and-pudina-juice-recipe
# 8008  https://www.archanaskitchen.com/chettinad-cauliflower-pepper-fry-recipe-milagu-pirattal-poriyal
#
#       vote_count    rating               cuisine     course  \
# 1           3423  4.932223  South Indian Recipes      Lunch
# 2           2091  4.945959               Mexican  Side Dish
# 3            990  4.888889     Coastal Karnataka  Side Dish
# 4            345  4.828986  North Indian Recipes  Side Dish
# 5           2088  4.903736                Indian      Lunch
# ...          ...       ...                   ...        ...
# 8003        2335  4.923340           Mangalorean  Side Dish
# 8004         738  4.934959       Italian Recipes     Dinner
# 8006        1202  4.946755             Karnataka  Side Dish
# 8007        1305  4.925670                Indian      Snack
# 8008        2167  4.815413            Tamil Nadu      Lunch
#
#                          diet  prep_time  cook_time  \
# 1                  Vegetarian       10.0       20.0
# 2                  Vegetarian       10.0        0.0
# 3     High Protein Vegetarian        5.0       20.0
# 4     High Protein Vegetarian       20.0       30.0
# 5                  Vegetarian       10.0       30.0
# ...                       ...        ...        ...
# 8003               Vegetarian       10.0       20.0
# 8004               Vegetarian       10.0       30.0
# 8006  High Protein Vegetarian       10.0       15.0
# 8007               Vegetarian       10.0        0.0
# 8008               Vegetarian       15.0       20.0
#
#                                                                                                                                                                                                                                                                                        ingredients  \
# 1                                                                                                                                                      sesame (gingelly) oil|mustard seeds|curry leaves|garlic|pearl onions (sambar onions)|tomatoes|tamarind|turmeric powder (haldi)|salt|jaggery
# 2                                                                                                       extra virgin olive oil|pineapple|white onion|red yellow and green bell peppers (capsicum)|pickled jalapenos|coriander (dhania) leaves|mint leaves (pudina)|salt|lemon juice|paprika powder
# 3                                                                                                                                                    arhar dal (split toor dal)|turmeric powder (haldi)|salt|dry red chilli|mustard seeds|asafoetida (hing)|curry leaves|coriander (dhania) leaves
# 4                                                                              rajma (large kidney beans)|cashew nuts|sultana raisins|asafoetida (hing)|cumin seeds (jeera)|gram flour (besan)|red chilli powder|coriander (dhania) leaves|poppy seeds|fresh cream|milk|water|salt|saffron strands
# 5     barnyard millet|oil|bay leaf (tej patta)|cardamom (elaichi) pods/seeds|cloves (laung)|cinnamon stick (dalchini)|star anise|curry leaves|green chilli|garlic|ginger|onions|button mushrooms|salt|coriander (dhania) powder|black pepper powder|coriander (dhania) leaves|mint leaves (pudina)
# 8004                         Pasta Recipes
# 8006                  Indian Curry Recipes
# 8007                  Indian Drink Recipes
# 8008  Poriyal Recipes (South Indian Sabzi)
#
# [5429 rows x 13 columns]

# %%
x = len(filter_ingredient)

# %%
from random import randint
y =randint(1, x)
y
# Out:
# 237

# %%
type(filter_ingredient["ingredients"].loc[30])
# Out:
# str

# %%
first_recipe_index = filter_ingredient.index.values.tolist()[y]
first_recipe_index
# Out:
# 266

# %%
filter_ingredient.loc[first_recipe_index]
# Out:
# recipe_title                                                                                        Beetroot Dip Recipe Served With Crackers
# url                                                                                             https://www.archanaskitchen.com/beetroot-dip
# vote_count                                                                                                                              1306
# rating                                                                                                                              4.777182
# cuisine                                                                                                                          Continental
# course                                                                                                                             Side Dish
# diet                                                                                                                              Vegetarian
# prep_time                                                                                                                               15.0
# cook_time                                                                                                                               20.0
# ingredients     beetroots|basil leaves|whole wheat bread crumbs|ginger|garlic|raisins|salt|cayenne pepper|lemon juice|extra virgin olive oil
# author                                                                                                                         Archana Doshi
# tags                                                                    Beetroot Recipes|Party Starter & Appetizer Recipes|Party Dip Recipes
# category                                                                                       Continental Party Appetizer & Starter Recipes
# Name: 266, dtype: object

# %%
#Kosta
#### First iteration. Gives a random recipe based on the index. Choosing an ingredient creates a new dataframe.
#Create a range of random integers based on length of new dataframe

from random import randint

ingredient_choice=input("Pick an ingredient")
filter_ingredient=df[(df["ingredients"].str.lower()).str.contains(ingredient_choice)]
# filter_ingredient.head()

x = len(filter_ingredient)

y =randint(1, x)
y
first_recipe_index = filter_ingredient.index.values.tolist()[y]
filter_ingredient.loc[first_recipe_index]
# Out:
# Pick an ingredientpotato
# recipe_title                                                                                                                                                                                                                                                           Potato Puff Pastry Recipe
# url                                                                                                                                                                                                                                    https://www.archanaskitchen.com/potato-puff-pastry-recipe
# vote_count                                                                                                                                                                                                                                                                                 10360
# rating                                                                                                                                                                                                                                                                                  4.914479
# cuisine                                                                                                                                                                                                                                                                     North Indian Recipes
# course                                                                                                                                                                                                                                                                                     Snack
# diet                                                                                                                                                                                                                                                                                  Vegetarian
# prep_time                                                                                                                                                                                                                                                                                   10.0
# cook_time                                                                                                                                                                                                                                                                                  120.0
# ingredients     potatoes (aloo)|onion|coriander (dhania) leaves|ginger|red chilli powder|chaat masala powder|cumin seeds (jeera)|coriander (dhania) seeds|green chilli|sunflower oil|salt|all purpose flour (maida)|all purpose flour (maida)|butter (unsalted)|chilled water|white vinegar|salt
# author                                                                                                                                                                                                                                                                                      Roop
# tags                                                                                                                                                                                                                               Aloo Recipes (Potato & Baby Potato Recipes)|Tea Party Recipes
# category                                                                                                                                                                                                                                                                    Indian Snack Recipes
# Name: 5715, dtype: object

# %%
#Kosta more beautiful version

from random import randint
ingr = input("Which ingredient do you want to cook?").lower()
ingr2 = input("And another ingredient?").lower()
def get_recipes(ingr, ingr2):
    recipes = df[(df["ingredients"].str.contains(ingr) & df["ingredients"].str.contains(ingr2))]
    rng = randint(1, len(recipes))
    recipe = recipes.index.values.tolist()[0]
    return recipes.loc[recipe]
get_recipes(ingr, ingr2)
# Out:
# Which ingredient do you want to cook?mustard seeds
# And another ingredient?tomato
# recipe_title                                                                          Thakkali Gotsu Recipe | Thakkali Curry | Spicy & Tangy Tomato Gravy
# url                                                                          https://www.archanaskitchen.com/tomato-gotsu-recipe-spicy-tangy-tomato-gravy
# vote_count                                                                                                                                           3423
# rating                                                                                                                                           4.932223
# cuisine                                                                                                                              South Indian Recipes
# course                                                                                                                                              Lunch
# diet                                                                                                                                           Vegetarian
# prep_time                                                                                                                                            10.0
# cook_time                                                                                                                                            20.0
# ingredients     sesame (gingelly) oil|mustard seeds|curry leaves|garlic|pearl onions (sambar onions)|tomato|tamarind|turmeric powder (haldi)|salt|jaggery
# author                                                                                                                                      Archana Doshi
# tags                                                                        Vegetarian Recipes|Tomato Recipes|South Indian Recipes|Breakfast Recipe Ideas
# category                                                                                                                             Indian Curry Recipes
# Name: 1, dtype: object

# %%
type(df['ingredients'])
# Out:
# pandas.core.series.Series

# %%
type(df2['ingredients'][0])
# Out:
# str

# %%
df2 = df_backup

# %%
df2['ingredients'] = df2['ingredients'].replace("|", ",")

# %%
df2['ingredients'] = df2['ingredients'].replace(r'|', ',', regex=True)

# %%
df2.head()
# Out:
#                                                           recipe_title  \
# 0                   Roasted Peppers And Mushroom Tortilla Pizza Recipe
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy & Tangy Tomato Gravy
# 2                                 Spicy Grilled Pineapple Salsa Recipe
# 3                       Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4                      Rajma Kofta In Milk And Poppy Seed Gravy Recipe
#
#                                                                                   url  \
# 0  https://www.archanaskitchen.com/roasted-peppers-and-mushroom-tortilla-pizza-recipe
# 1        https://www.archanaskitchen.com/tomato-gotsu-recipe-spicy-tangy-tomato-gravy
# 2                https://www.archanaskitchen.com/spicy-grilled-pineapple-salsa-recipe
# 3        https://www.archanaskitchen.com/dali-thoy-recipe-karwar-style-toor-dal-curry
# 4     https://www.archanaskitchen.com/rajma-kofta-in-milk-and-poppy-seed-gravy-recipe
#
#    vote_count    rating               cuisine     course  \
# 0         434  4.958525               Mexican     Dinner
# 1        3423  4.932223  South Indian Recipes      Lunch
# 2        2091  4.945959               Mexican  Side Dish
# 3         990  4.888889     Coastal Karnataka  Side Dish
# 4         345  4.828986  North Indian Recipes  Side Dish
#
#                       diet  prep_time  cook_time  \
# 0               Vegetarian       15.0       15.0
# 1               Vegetarian       10.0       20.0
# 2               Vegetarian       10.0        0.0
# 3  High Protein Vegetarian        5.0       20.0
# 4  High Protein Vegetarian       20.0       30.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                ingredients  \
# 0                                                                                                                                                ,t,o,r,t,i,l,l,a,s,|,e,x,t,r,a, ,v,i,r,g,i,n, ,o,l,i,v,e, ,o,i,l,|,g,a,r,l,i,c,|,m,o,z,z,a,r,e,l,l,a, ,c,h,e,e,s,e,|,r,e,d, ,y,e,l,l,o,w, ,o,r, ,g,r,e,e,n, ,b,e,l,l, ,p,e,p,p,e,r, ,(,c,a,p,s,i,c,u,m,),|,o,n,i,o,n,s,|,k,a,l,m,a,t,t,a, ,o,l,i,v,e,s,|,b,u,t,t,o,n, ,m,u,s,h,r,o,o,m,s,
# 1                                                                                                                                                      ,s,e,s,a,m,e, ,(,g,i,n,g,e,l,l,y,), ,o,i,l,|,m,u,s,t,a,r,d, ,s,e,e,d,s,|,c,u,r,r,y, ,l,e,a,v,e,s,|,g,a,r,l,i,c,|,p,e,a,r,l, ,o,n,i,o,n,s, ,(,s,a,m,b,a,r, ,o,n,i,o,n,s,),|,t,o,m,a,t,o,|,t,a,m,a,r,i,n,d,|,t,u,r,m,e,r,i,c, ,p,o,w,d,e,r, ,(,h,a,l,d,i,),|,s,a,l,t,|,j,a,g,g,e,r,y,
# 2                                                    ,e,x,t,r,a, ,v,i,r,g,i,n, ,o,l,i,v,e, ,o,i,l,|,p,i,n,e,a,p,p,l,e,|,w,h,i,t,e, ,o,n,i,o,n,|,r,e,d, ,y,e,l,l,o,w, ,a,n,d, ,g,r,e,e,n, ,b,e,l,l, ,p,e,p,p,e,r,s, ,(,c,a,p,s,i,c,u,m,),|,p,i,c,k,l,e,d, ,j,a,l,a,p,e,n,o,s,|,c,o,r,i,a,n,d,e,r, ,(,d,h,a,n,i,a,), ,l,e,a,v,e,s,|,m,i,n,t, ,l,e,a,v,e,s, ,(,p,u,d,i,n,a,),|,s,a,l,t,|,l,e,m,o,n, ,j,u,i,c,e,|,p,a,p,r,i,k,a, ,p,o,w,d,e,r,
# 3                                                                                                                                              ,a,r,h,a,r, ,d,a,l, ,(,s,p,l,i,t, ,t,o,o,r, ,d,a,l,),|,t,u,r,m,e,r,i,c, ,p,o,w,d,e,r, ,(,h,a,l,d,i,),|,s,a,l,t,|,d,r,y, ,r,e,d, ,c,h,i,l,l,i,|,m,u,s,t,a,r,d, ,s,e,e,d,s,|,a,s,a,f,o,e,t,i,d,a, ,(,h,i,n,g,),|,c,u,r,r,y, ,l,e,a,v,e,s,|,c,o,r,i,a,n,d,e,r, ,(,d,h,a,n,i,a,), ,l,e,a,v,e,s,
# 4  ,r,a,j,m,a, ,(,l,a,r,g,e, ,k,i,d,n,e,y, ,b,e,a,n,s,),|,c,a,s,h,e,w, ,n,u,t,s,|,s,u,l,t,a,n,a, ,r,a,i,s,i,n,s,|,a,s,a,f,o,e,t,i,d,a, ,(,h,i,n,g,),|,c,u,m,i,n, ,s,e,e,d,s, ,(,j,e,e,r,a,),|,g,r,a,m, ,f,l,o,u,r, ,(,b,e,s,a,n,),|,r,e,d, ,c,h,i,l,l,i, ,p,o,w,d,e,r,|,c,o,r,i,a,n,d,e,r, ,(,d,h,a,n,i,a,), ,l,e,a,v,e,s,|,p,o,p,p,y, ,s,e,e,d,s,|,f,r,e,s,h, ,c,r,e,a,m,|,m,i,l,k,|,w,a,t,e,r,|,s,a,l,t,|,s,a,f,f,r,o,n, ,s,t,r,a,n,d,s,
#
#               author  \
# 0  Divya Shivaraman
# 1      Archana Doshi
# 2  Archana's Kitchen
# 3      Jyothi Rajesh
# 4        RUBY PATHAK
#
#                                                                                                                   tags  \
# 0            Party Food Recipes|Tea Party Recipes|Mushroom Recipes|Fusion Recipes|Tortilla Recipe|Bell Peppers Recipes
# 1                                        Vegetarian Recipes|Tomato Recipes|South Indian Recipes|Breakfast Recipe Ideas
# 2                                                    Party Starter & Appetizer Recipes|Pineapple Recipes|Salsa Recipes
# 3  Side Dish Recipes|South Indian Recipes|Indian Lunch Recipes|Indian Vegetarian Recipes|Toor Dal Recipes (Pigeon Pea)
# 4        Side Dish Recipes|Indian Lunch Recipes|Office Lunch Box Recipes|Rajma Kidney Bean Recipes|Poppy Seeds Recipes
#
#                category
# 0         Pizza Recipes
# 1  Indian Curry Recipes
# 2       Mexican Recipes
# 3  Indian Curry Recipes
# 4         Kofta Recipes

# %%
user_ingredient()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-270-95b92c07ef56> in <module>
# ----> 1 user_ingredient()
#
# <ipython-input-231-65b160132ddf> in user_ingredient()
#       2     from random import randint
#       3     #input from user
# ----> 4     ingredient_choice=input("Pick an ingredient")
#       5     if len(ingredient_choice)==0:
#       6         print("it looks like you can't think of an ingredient at the moment")
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def available_ingredient(ingredients):
    if ingredients.lower() in df['ingredients']:
        return(df['recipe_title'][random.randint(1,len(df)-1)].recipe_title())
    else:
        return("*")

# %%
#function to validate user input
import re

def validate_input(text):
    ''' Parameters: text entered by user in input
        Results: returns true if it's a possible song, false otherwise
    '''
    #the user entered nothing
    if len(text) == 0:
        return False
    #some songs start or contain numbers, ex: 4 Da Gang
    else:
        return True

# %%
while True:
    #ask the user for an ingredient
    user_ingredient = input(">> Enter an ingredient: ")
    if user_ingredient =='!':
        print("Guten appetit! Bye :)")
        break
    if validate_input(user_ingredient):
        #apply the recommendation function
        result = available_ingredient(user_ingredient)
        if result =="***":
            print("You're gonna like this recipe: ") 
            get_random_song_cluster(user_song)
        else:
            print("Recommended for you: ", result)
    else:
        print("That's not a song, try again!")
# Out:
# >> Enter an ingredient: salt
# Recommended for you:  *
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-dc7ad8241148> in <module>
#       1 while True:
#       2     #ask the user for an ingredient
# ----> 3     user_ingredient = input(">> Enter an ingredient: ")
#       4     if user_ingredient =='!':
#       5         print("Guten appetit! Bye :)")
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
df.to_pickle('backup3.pkl')
